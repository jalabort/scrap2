# %%
# %matplotlib inline
import numpy as np
import menpo.io as mio
from menpo.landmark import labeller, ibug_open_eye_points, ibug_open_eye_trimesh

# load training images
open_right_eye_images = []
for i in mio.import_images('/Users/joan/PhD/DataBases/eyes/Annotated/Open/Right/*', verbose=True):
    # crop image
    i.crop_to_landmarks_proportion_inplace(0.5)
    # label it
    labeller(i, 'PTS', ibug_open_eye_points)
    labeller(i, 'PTS', ibug_open_eye_trimesh)
    # convert it to grayscale if needed
    if i.n_channels == 3:
        i = i.as_greyscale(mode='luminosity')
    # append it to the list
    open_right_eye_images.append(i)
# Out:
# - Loading 200 assets: [                    ] 0%
# - Loading 200 assets: [                    ] 1%
# - Loading 200 assets: [                    ] 1%
# - Loading 200 assets: [                    ] 2%
# - Loading 200 assets: [                    ] 2%
# - Loading 200 assets: [                    ] 3%
# - Loading 200 assets: [                    ] 3%
# - Loading 200 assets: [                    ] 4%
# - Loading 200 assets: [                    ] 4%
# - Loading 200 assets: [=                   ] 5%
# - Loading 200 assets: [=                   ] 5%
# - Loading 200 assets: [=                   ] 6%
# - Loading 200 assets: [=                   ] 6%
# - Loading 200 assets: [=                   ] 7%
# - Loading 200 assets: [=                   ] 7%
# - Loading 200 assets: [=                   ] 8%
# - Loading 200 assets: [=                   ] 8%
# - Loading 200 assets: [=                   ] 9%
# - Loading 200 assets: [=                   ] 9%
# ...

# %%
# load training images
for i in mio.import_images('/Users/joan/PhD/DataBases/eyes/Annotated_Flip/Open/Right/*', verbose=True):
    # crop image
    i.crop_to_landmarks_proportion_inplace(0.5)
    # label it
    labeller(i, 'PTS', ibug_open_eye_points)
    labeller(i, 'PTS', ibug_open_eye_trimesh)
    # convert it to grayscale if needed
    if i.n_channels == 3:
        i = i.as_greyscale(mode='luminosity')
    # append it to the list
    open_right_eye_images.append(i)
# Out:
# - Loading 183 assets: [                    ] 0%
# - Loading 183 assets: [                    ] 1%
# - Loading 183 assets: [                    ] 1%
# - Loading 183 assets: [                    ] 2%
# - Loading 183 assets: [                    ] 2%
# - Loading 183 assets: [                    ] 3%
# - Loading 183 assets: [                    ] 3%
# - Loading 183 assets: [                    ] 4%
# - Loading 183 assets: [                    ] 4%
# - Loading 183 assets: [=                   ] 5%
# - Loading 183 assets: [=                   ] 6%
# - Loading 183 assets: [=                   ] 6%
# - Loading 183 assets: [=                   ] 7%
# - Loading 183 assets: [=                   ] 7%
# - Loading 183 assets: [=                   ] 8%
# - Loading 183 assets: [=                   ] 8%
# - Loading 183 assets: [=                   ] 9%
# - Loading 183 assets: [=                   ] 9%
# - Loading 183 assets: [==                  ] 10%
# ...

# %%
# %matplotlib inline
import menpo.io as mio
from menpo.landmark import labeller, ibug_close_eye_points, ibug_close_eye_trimesh

# load training images
close_right_eye_images = []
for i in mio.import_images('/Users/joan/PhD/DataBases/eyes/Annotated/Close/Right/*', verbose=True):
    # crop image
    i.crop_to_landmarks_proportion_inplace(0.5)
    # label it
    labeller(i, 'PTS', ibug_close_eye_points)
    labeller(i, 'PTS', ibug_close_eye_trimesh)
    # convert it to grayscale if needed
    if i.n_channels == 3:
        i = i.as_greyscale(mode='luminosity')
    # append it to the list
    close_right_eye_images.append(i)
# Out:
# - Loading 200 assets: [                    ] 0%
# - Loading 200 assets: [                    ] 1%
# - Loading 200 assets: [                    ] 1%
# - Loading 200 assets: [                    ] 2%
# - Loading 200 assets: [                    ] 2%
# - Loading 200 assets: [                    ] 3%
# - Loading 200 assets: [                    ] 3%
# - Loading 200 assets: [                    ] 4%
# - Loading 200 assets: [                    ] 4%
# - Loading 200 assets: [=                   ] 5%
# - Loading 200 assets: [=                   ] 5%
# - Loading 200 assets: [=                   ] 6%
# - Loading 200 assets: [=                   ] 6%
# - Loading 200 assets: [=                   ] 7%
# - Loading 200 assets: [=                   ] 7%
# - Loading 200 assets: [=                   ] 8%
# - Loading 200 assets: [=                   ] 8%
# - Loading 200 assets: [=                   ] 9%
# - Loading 200 assets: [=                   ] 9%
# ...

# %%
# load training images
for i in mio.import_images('/Users/joan/PhD/DataBases/eyes/Annotated_Flip/Close/Right/*', verbose=True):
    # crop image
    i.crop_to_landmarks_proportion_inplace(0.5)
    # label it
    labeller(i, 'PTS', ibug_close_eye_points)
    labeller(i, 'PTS', ibug_close_eye_trimesh)
    # convert it to grayscale if needed
    if i.n_channels == 3:
        i = i.as_greyscale(mode='luminosity')
    # append it to the list
    close_right_eye_images.append(i)
# Out:
# - Loading 200 assets: [                    ] 0%
# - Loading 200 assets: [                    ] 1%
# - Loading 200 assets: [                    ] 1%
# - Loading 200 assets: [                    ] 2%
# - Loading 200 assets: [                    ] 2%
# - Loading 200 assets: [                    ] 3%
# - Loading 200 assets: [                    ] 3%
# - Loading 200 assets: [                    ] 4%
# - Loading 200 assets: [                    ] 4%
# - Loading 200 assets: [=                   ] 5%
# - Loading 200 assets: [=                   ] 5%
# - Loading 200 assets: [=                   ] 6%
# - Loading 200 assets: [=                   ] 6%
# - Loading 200 assets: [=                   ] 7%
# - Loading 200 assets: [=                   ] 7%
# - Loading 200 assets: [=                   ] 8%
# - Loading 200 assets: [=                   ] 8%
# - Loading 200 assets: [=                   ] 9%
# - Loading 200 assets: [=                   ] 9%
# ...

# %%
from menpo.fitmultilevel.aam import AAMBuilder
from menpo.fitmultilevel.featurefunctions import sparse_hog

# save triangulation
open_trilist = open_right_eye_images[0].landmarks['ibug_open_eye_trimesh'].lms.trilist

open_aam_builder = AAMBuilder(feature_type=sparse_hog, downscale=1.1, trilist=open_trilist, normalization_diagonal=200)
open_aam = open_aam_builder.build(open_right_eye_images, group='PTS', verbose=True)
# Out:
# - Computing reference shape
# - Normalizing images size: 0%
# - Normalizing images size: 0%
# - Normalizing images size: 0%
# - Normalizing images size: 1%
# - Normalizing images size: 1%
# - Normalizing images size: 1%
# - Normalizing images size: 1%
# - Normalizing images size: 2%
# - Normalizing images size: 2%
# - Normalizing images size: 2%
# - Normalizing images size: 2%
# - Normalizing images size: 3%
# - Normalizing images size: 3%
# - Normalizing images size: 3%
# - Normalizing images size: 3%
# - Normalizing images size: 4%
# - Normalizing images size: 4%
# - Normalizing images size: 4%
# - Normalizing images size: 4%
# - Normalizing images size: 5%
# - Normalizing images size: 5%
# - Normalizing images size: 5%
# - Normalizing images size: 6%
# - Normalizing images size: 6%
# - Normalizing images size: 6%
# - Normalizing images size: 6%
# - Normalizing images size: 7%
# - Normalizing images size: 7%
# - Normalizing images size: 7%
# - Normalizing images size: 7%
# ...

# %%
import dill as pickle

pickle.dump(open_aam, open('/Users/joan/PhD/Models/open_aam.menpo', 'wb' ))

# %%
# save triangulation
close_trilist = close_right_eye_images[0].landmarks['ibug_close_eye_trimesh'].lms.trilist

close_aam_builder = AAMBuilder(feature_type=sparse_hog, downscale=1.1, trilist=close_trilist, normalization_diagonal=200)
close_aam = close_aam_builder.build(close_right_eye_images, group='PTS', verbose=True)
# Out:
# - Computing reference shape
# - Normalizing images size: 0%
# - Normalizing images size: 0%
# - Normalizing images size: 0%
# - Normalizing images size: 1%
# - Normalizing images size: 1%
# - Normalizing images size: 1%
# - Normalizing images size: 1%
# - Normalizing images size: 2%
# - Normalizing images size: 2%
# - Normalizing images size: 2%
# - Normalizing images size: 2%
# - Normalizing images size: 3%
# - Normalizing images size: 3%
# - Normalizing images size: 3%
# - Normalizing images size: 3%
# - Normalizing images size: 4%
# - Normalizing images size: 4%
# - Normalizing images size: 4%
# - Normalizing images size: 4%
# - Normalizing images size: 5%
# - Normalizing images size: 5%
# - Normalizing images size: 5%
# - Normalizing images size: 5%
# - Normalizing images size: 6%
# - Normalizing images size: 6%
# - Normalizing images size: 6%
# - Normalizing images size: 6%
# - Normalizing images size: 7%
# - Normalizing images size: 7%
# - Normalizing images size: 7%
# ...

# %%
import dill as pickle

pickle.dump(close_aam, open('/Users/joan/PhD/Models/close_aam.menpo', 'wb' ))

# %%
from menpo.fitmultilevel.clm import CLMBuilder
from menpo.fitmultilevel.featurefunctions import sparse_hog

open_clm_builder = CLMBuilder(feature_type=sparse_hog, normalization_diagonal=200, downscale=1.1)
open_clm = open_clm_builder.build(open_right_eye_images, group='PTS', verbose=True)
# Out:
# - Computing reference shape
# - Normalizing images size: 0%
# - Normalizing images size: 0%
# - Normalizing images size: 0%
# - Normalizing images size: 1%
# - Normalizing images size: 1%
# - Normalizing images size: 1%
# - Normalizing images size: 1%
# - Normalizing images size: 2%
# - Normalizing images size: 2%
# - Normalizing images size: 2%
# - Normalizing images size: 2%
# - Normalizing images size: 3%
# - Normalizing images size: 3%
# - Normalizing images size: 3%
# - Normalizing images size: 3%
# - Normalizing images size: 4%
# - Normalizing images size: 4%
# - Normalizing images size: 4%
# - Normalizing images size: 4%
# - Normalizing images size: 5%
# - Normalizing images size: 5%
# - Normalizing images size: 5%
# - Normalizing images size: 6%
# - Normalizing images size: 6%
# - Normalizing images size: 6%
# - Normalizing images size: 6%
# - Normalizing images size: 7%
# - Normalizing images size: 7%
# - Normalizing images size: 7%
# - Normalizing images size: 7%
# ...

# %%
import dill as pickle

pickle.dump(open_clm, open('/Users/joan/PhD/Models/open_clm.menpo', 'wb' ))

# %%
from menpo.fitmultilevel.clm import CLMBuilder
from menpo.fitmultilevel.featurefunctions import sparse_hog

close_clm_builder = CLMBuilder(feature_type=sparse_hog, normalization_diagonal=200, downscale=1.1)
close_clm = close_clm_builder.build(close_close_rclose_right_eye_images, group='PTS', verbose=True)
# Out:
# - Computing reference shape
# - Normalizing images size: 0%
# - Normalizing images size: 0%
# - Normalizing images size: 0%
# - Normalizing images size: 1%
# - Normalizing images size: 1%
# - Normalizing images size: 1%
# - Normalizing images size: 1%
# - Normalizing images size: 2%
# - Normalizing images size: 2%
# - Normalizing images size: 2%
# - Normalizing images size: 2%
# - Normalizing images size: 3%
# - Normalizing images size: 3%
# - Normalizing images size: 3%
# - Normalizing images size: 3%
# - Normalizing images size: 4%
# - Normalizing images size: 4%
# - Normalizing images size: 4%
# - Normalizing images size: 4%
# - Normalizing images size: 5%
# - Normalizing images size: 5%
# - Normalizing images size: 5%
# - Normalizing images size: 5%
# - Normalizing images size: 6%
# - Normalizing images size: 6%
# - Normalizing images size: 6%
# - Normalizing images size: 6%
# - Normalizing images size: 7%
# - Normalizing images size: 7%
# - Normalizing images size: 7%
# ...

# %%
import dill as pickle

pickle.dump(close_clm, open('/Users/joan/PhD/Models/close_clm.menpo', 'wb' ))

# %%
from menpo.shape import PointCloud
from menpo.image.feature.features import hog, igo
from menpo.fitmultilevel.functions import extract_local_patches_fast, mean_pointcloud, noisy_align

patch_shape = (16, 16)
feature_patch_length = 2*16*16
open_ind = np.array([0, 6, 22, 26, 30, 32, 34])
close_ind = np.hstack((np.array([0, 7]), np.arange(12, 17)))
feature_sample_length = len(open_ind) * feature_patch_length

open_shape_mean = mean_pointcloud([i.landmarks['PTS'].lms for i in open_right_eye_images])
close_shape_mean =  mean_pointcloud([i.landmarks['PTS'].lms for i in close_right_eye_images])

correct_samples = np.zeros((10*(len(open_right_eye_images) + len(close_right_eye_images)), feature_sample_length))
wrong_samples = np.zeros((10*(len(open_right_eye_images) + len(close_right_eye_images)), feature_sample_length))

count_correct = 0
count_wrong = 0
for k, i in enumerate(open_right_eye_images):
    for _ in range(10):
        correct_shape = i.landmarks['PTS'].lms
        correct_shape = noisy_align(correct_shape, correct_shape, noise_std=0.02).apply(correct_shape)
        correct_centers = PointCloud(correct_shape.points[open_ind, :])

        patches = extract_local_patches_fast(i, correct_centers, patch_shape)
        features = np.zeros((len(open_ind), feature_patch_length))
        for j, patch in enumerate(patches):
            features[j, ...] =igo(patch).ravel()
        correct_samples[count_correct, ...] = features.ravel()
        
        count_correct += 1
    
    for _ in range(10):
        wrong_shape = noisy_align(PointCloud(close_shape_mean.points[:12]), PointCloud(correct_shape.points[:12]),
                                  noise_std=0.02).apply(close_shape_mean)
        wrong_centers = PointCloud(wrong_shape.points[close_ind, :])

        patches = extract_local_patches_fast(i, wrong_centers, patch_shape)
        features = np.zeros((len(close_ind), feature_patch_length))
        for j, patch in enumerate(patches):
            features[j, ...] = igo(patch).ravel()
        wrong_samples[count_wrong, ...] = features.ravel()
        
        count_wrong += 1

# %%
from menpo.shape import PointCloud
from menpo.image.feature.features import hog, igo
from menpo.fitmultilevel.functions import extract_local_patches_fast, mean_pointcloud, noisy_align

close_ind = np.hstack((np.array([0, 6]), np.arange(12, 17)))
feature_patch_length = 2*16*16
feature_sample_length = len(open_ind) * feature_patch_length

for k, i in enumerate(close_right_eye_images):
    for _ in range(10):
        correct_shape = i.landmarks['PTS'].lms
        correct_shape = noisy_align(correct_shape, correct_shape, noise_std=0.02).apply(correct_shape)
        correct_centers = PointCloud(correct_shape.points[close_ind, :])

        patches = extract_local_patches_fast(i, correct_centers, patch_shape)
        features = np.zeros((len(close_ind), feature_patch_length))
        for j, patch in enumerate(patches):
            features[j, ...] = igo(patch).ravel()
        correct_samples[count_correct, ...] = features.ravel()

        count_correct += 1
    
    for _ in range(10):
        wrong_shape = noisy_align(PointCloud(open_shape_mean.points[:12]), PointCloud(correct_shape.points[:12]),
                                  noise_std=0.02).apply(open_shape_mean)
        wrong_centers = PointCloud(wrong_shape.points[open_ind, :])

        patches = extract_local_patches_fast(i, wrong_centers, patch_shape)
        features = np.zeros((len(close_ind), feature_patch_length))
        for j, patch in enumerate(patches):
            features[j, ...] = igo(patch).ravel()
        wrong_samples[count_wrong, ...] = features.ravel()
        
        count_wrong += 1

# %%
def extract_hog_features(img, centers, patch_shape=(16, 16)):
    patches = extract_local_patches_fast(img, centers, patch_shape)
    features = np.zeros((centers.n_points, 2*16*16))
    for j, patch in enumerate(patches):
        features[j, ...] = igo(patch).ravel()

    return features.ravel()

# %%
from sklearn import svm
from sklearn import linear_model

def linear_svm_lr(X, t):
    r"""
    Binary classifier that combines Linear Support Vector Machines and
    Logistic Regression.
    """
    clf1 = svm.LinearSVC(class_weight='auto')
    clf1.fit(X, t)
    t1 = clf1.decision_function(X)
    clf2 = linear_model.LogisticRegression(class_weight='auto')
    clf2.fit(t1[..., None], t)

    def predict(x):
        t1_pred = clf1.decision_function(x)
        return clf2.predict_proba(t1_pred[..., None])

    return predict

# %%
X = np.vstack((correct_samples, wrong_samples))
t = np.hstack((np.zeros(correct_samples.shape[0]), np.ones(wrong_samples.shape[0])))

classifier = linear_svm_lr(X, t)

# %%
classifier(X)
# Out:
# array([[  9.94746583e-01,   5.25341731e-03],
#        [  9.94747640e-01,   5.25236023e-03],
#        [  9.96411006e-01,   3.58899412e-03],
#        ...,
#        [  2.84668681e-08,   9.99999972e-01],
#        [  8.39177509e-08,   9.99999916e-01],
#        [  7.92317073e-08,   9.99999921e-01]])

# %%
import dill as pickle

pickle.dump(classifier, open('/Users/joan/PhD/Models/eye_classifier.menpo', 'wb' ))
