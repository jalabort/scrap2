# %%
# %matplotlib inline

# %% [markdown]
# # Understanding Active Appearance Models
# ---
#
# ## i·BUG group tutorial
#
# ### Joan Alabort-i-Medina
# <ja310@imperial.ac.uk>

# %% [markdown]
# ## Part 1: Building Active Appearance Models
# ---

# %% [markdown]
# > "**Active Apperance Models (AAMs)** are **non-linear**, **generative**, and **parametric** models of a certain visual phenomenon".
#
# > <div align="right"><font size="2">I. Matthews and S. Baker, 2004.</font></div>

# %% [markdown]
# - **non-linear**: they are non-linear in terms of *pixel intensities*.
#
# - **generative**: they generate images of a particular *object* class (e.g. the human face).
#
# - **parametric**: they are *controlled* by a set of parameters.

# %%
from menpofit.visualize import visualize_aam
from alabortcvpr2015.utils import pickle_load

aam = pickle_load('/Users/joan/PhD/Models/aam_int.menpo')

visualize_aam(aam)

# %% [markdown]
# A bit of history...
#
# They were originally proposed in **1998** by G. Edwards, C. J. Taylor, and T. F. Cootes from Department of Medical Biophysics (**not Computing!**) at University of Manchester.
#
# - *G. Edwards, C. J. Taylor, and T. F. Cootes, "Interpreting face images using active appearance models". FG 1998*.

# %% [markdown]
# Luckily for the original authors quite a lot of research stemmed from the original paper:
#
# - *T. F. Cootes, K. Walker, and C. J. Taylor, “View-based active appearance models,” in FG, 2000*
# - *T. F. Cootes, G. J. Edwards, and C. J. Taylor, “Active appearance models,” TPAMI, 2001*.
# - *T. F. Cootes and C. J. Taylor, “On representing edge structure for model matching,” in CVPR, 2001*
# - *I. Matthews and S. Baker, “Active appearance models revisited,” IJCV, 2004*.
# - *R. Gross, I. Matthews, and S. Baker, “Generic vs. person specific active appearance models,” IVC, 2005.*
# - *A. U. Batur and M. H. Hayes, “Adaptive active appearance models,” TIP, 2005*.
# - *G. Papandreou and P. Maragos, “Adaptive and constrained algorithms for inverse compositional active appearance model fitting,” CVPR, 2008*.
# - *J. Saragih and R. Gocke, “Learning aam fitting through simulation,” PR, 2009*.
# - *B. Amberg, A. Blake, and T. Vetter, “On compositional image alignment, with an application to active appearance models,” CVPR, 2009*.
# - *G. Tzimiropoulos, J. Alabort-i-Medina, S. Zafeiriou, and M. Pantic. "Generic active appearance models revisited". ACCV, 2012*.
# - *G. Tzimiropoulos and M. Pantic. "Optimization problems for fast aam fitting in-the-wild". ICCV, 2013*.
# - *G. Tzimiropoulos and M. Pantic. "Gauss-Newton deformable part models for face alignment in-the-wild". CVPR, 2014*.
# - *J. Alabort-i-Medina and S. Zafeiriou. "Bayesian active appearance models". CVPR, 2014.*
# - *E. Antonakos, J. Alabort-i-Medina, G. Tzimiropoulos, and S. Zafeiriou. "HOG active appearance models". ICIP 2014*.
# - *J. Kossaifi, G. Tzimiropoulos, M. Pantic. "Fast Newton Active Appearance Models". ICIP, 2014*.

# %% [markdown]
# - *J. Alabort-i-medina, E. Antonakos, J. Booth, P. Snape, S. Zafeiriou. "Menpo: A Comprehensive Platform for Parametric Image Alignment and Visual Deformable Models". ACM Multimedia, Open Source Software Competition, 2014.*

# %% [markdown]
# although, (typically) linear in terms of both shape and texture, the image formation process is non-linear in terms of *pixel intensities*

# %% [markdown]
# To get us started with AAMs, we will assume that the object we are interested in modelling is no other than the **human face**:

# %% [markdown]
# ![Alt text](http://static.comicvine.com/uploads/original/14/145290/3282321-5672922306-32822.jpg)

# %% [markdown]
# The first thing we will need is a **large** collection of face images:

# %%
import menpo.io as mio
from menpo.landmark import labeller, ibug_face_66

images = []
for i  in mio.import_images('/Users/joan/PhD/DataBases/faces/lfpw/trainset/', 
                            max_images=None, verbose=True):
    
    i.crop_to_landmarks_proportion_inplace(0.5)
    i = i.rescale_landmarks_to_diagonal_range(100)
    labeller(i, 'PTS', ibug_face_66)
    if i.n_channels == 3:
        i = i.as_greyscale(mode='luminosity')
    
    images.append(i)
# Out:
# - Loading 811 assets: [                    ] 0%
# - Loading 811 assets: [                    ] 0%
# - Loading 811 assets: [                    ] 0%
# - Loading 811 assets: [                    ] 0%
# - Loading 811 assets: [                    ] 0%
# - Loading 811 assets: [                    ] 0%
# - Loading 811 assets: [                    ] 0%
# - Loading 811 assets: [                    ] 0%
# - Loading 811 assets: [                    ] 1%
# - Loading 811 assets: [                    ] 1%
# - Loading 811 assets: [                    ] 1%
# - Loading 811 assets: [                    ] 1%
# - Loading 811 assets: [                    ] 1%
# - Loading 811 assets: [                    ] 1%
# - Loading 811 assets: [                    ] 1%
# - Loading 811 assets: [                    ] 1%
# - Loading 811 assets: [                    ] 2%
# - Loading 811 assets: [                    ] 2%
# - Loading 811 assets: [                    ] 2%
# - Loading 811 assets: [                    ] 2%
# - Loading 811 assets: [                    ] 2%
# - Loading 811 assets: [                    ] 2%
# - Loading 811 assets: [                    ] 2%
# - Loading 811 assets: [                    ] 2%
# - Loading 811 assets: [                    ] 3%
# - Loading 811 assets: [                    ] 3%
# - Loading 811 assets: [                    ] 3%
# - Loading 811 assets: [                    ] 3%
# - Loading 811 assets: [                    ] 3%
# - Loading 811 assets: [                    ] 3%
# - Loading 811 assets: [                    ] 3%
# - Loading 811 assets: [                    ] 3%
# - Loading 811 assets: [                    ] 4%
# - Loading 811 assets: [                    ] 4%
# - Loading 811 assets: [                    ] 4%
# - Loading 811 assets: [                    ] 4%
# - Loading 811 assets: [                    ] 4%
# - Loading 811 assets: [                    ] 4%
# - Loading 811 assets: [                    ] 4%
# - Loading 811 assets: [                    ] 4%
# - Loading 811 assets: [=                   ] 5%
# - Loading 811 assets: [=                   ] 5%
# - Loading 811 assets: [=                   ] 5%
# - Loading 811 assets: [=                   ] 5%
# - Loading 811 assets: [=                   ] 5%
# - Loading 811 assets: [=                   ] 5%
# - Loading 811 assets: [=                   ] 5%
# - Loading 811 assets: [=                   ] 5%
# - Loading 811 assets: [=                   ] 6%
# - Loading 811 assets: [=                   ] 6%
# - Loading 811 assets: [=                   ] 6%
# - Loading 811 assets: [=                   ] 6%
# - Loading 811 assets: [=                   ] 6%
# - Loading 811 assets: [=                   ] 6%
# - Loading 811 assets: [=                   ] 6%
# - Loading 811 assets: [=                   ] 6%
# - Loading 811 assets: [=                   ] 7%
# - Loading 811 assets: [=                   ] 7%
# - Loading 811 assets: [=                   ] 7%
# - Loading 811 assets: [=                   ] 7%
# - Loading 811 assets: [=                   ] 7%
# - Loading 811 assets: [=                   ] 7%
# - Loading 811 assets: [=                   ] 7%
# - Loading 811 assets: [=                   ] 7%
# - Loading 811 assets: [=                   ] 8%
# - Loading 811 assets: [=                   ] 8%
# - Loading 811 assets: [=                   ] 8%
# - Loading 811 assets: [=                   ] 8%
# - Loading 811 assets: [=                   ] 8%
# - Loading 811 assets: [=                   ] 8%
# - Loading 811 assets: [=                   ] 8%
# - Loading 811 assets: [=                   ] 8%
# - Loading 811 assets: [=                   ] 9%
# - Loading 811 assets: [=                   ] 9%
# - Loading 811 assets: [=                   ] 9%
# - Loading 811 assets: [=                   ] 9%
# - Loading 811 assets: [=                   ] 9%
# - Loading 811 assets: [=                   ] 9%
# - Loading 811 assets: [=                   ] 9%
# - Loading 811 assets: [=                   ] 9%
# - Loading 811 assets: [=                   ] 9%
# - Loading 811 assets: [==                  ] 10%
# - Loading 811 assets: [==                  ] 10%
# - Loading 811 assets: [==                  ] 10%
# - Loading 811 assets: [==                  ] 10%
# - Loading 811 assets: [==                  ] 10%
# - Loading 811 assets: [==                  ] 10%
# - Loading 811 assets: [==                  ] 10%
# - Loading 811 assets: [==                  ] 10%
# - Loading 811 assets: [==                  ] 11%
# - Loading 811 assets: [==                  ] 11%
# - Loading 811 assets: [==                  ] 11%
# - Loading 811 assets: [==                  ] 11%
# - Loading 811 assets: [==                  ] 11%
# - Loading 811 assets: [==                  ] 11%
# - Loading 811 assets: [==                  ] 11%
# - Loading 811 assets: [==                  ] 11%
# - Loading 811 assets: [==                  ] 12%
# - Loading 811 assets: [==                  ] 12%
# - Loading 811 assets: [==                  ] 12%
# - Loading 811 assets: [==                  ] 12%
# - Loading 811 assets: [==                  ] 12%
# - Loading 811 assets: [==                  ] 12%
# - Loading 811 assets: [==                  ] 12%
# - Loading 811 assets: [==                  ] 12%
# - Loading 811 assets: [==                  ] 13%
# - Loading 811 assets: [==                  ] 13%
# - Loading 811 assets: [==                  ] 13%
# - Loading 811 assets: [==                  ] 13%
# - Loading 811 assets: [==                  ] 13%
# - Loading 811 assets: [==                  ] 13%
# - Loading 811 assets: [==                  ] 13%
# - Loading 811 assets: [==                  ] 13%
# - Loading 811 assets: [==                  ] 14%
# - Loading 811 assets: [==                  ] 14%
# - Loading 811 assets: [==                  ] 14%
# - Loading 811 assets: [==                  ] 14%
# - Loading 811 assets: [==                  ] 14%
# - Loading 811 assets: [==                  ] 14%
# - Loading 811 assets: [==                  ] 14%
# - Loading 811 assets: [==                  ] 14%
# - Loading 811 assets: [===                 ] 15%
# - Loading 811 assets: [===                 ] 15%
# - Loading 811 assets: [===                 ] 15%
# - Loading 811 assets: [===                 ] 15%
# - Loading 811 assets: [===                 ] 15%
# - Loading 811 assets: [===                 ] 15%
# - Loading 811 assets: [===                 ] 15%
# - Loading 811 assets: [===                 ] 15%
# - Loading 811 assets: [===                 ] 16%
# - Loading 811 assets: [===                 ] 16%
# - Loading 811 assets: [===                 ] 16%
# - Loading 811 assets: [===                 ] 16%
# - Loading 811 assets: [===                 ] 16%
# - Loading 811 assets: [===                 ] 16%
# - Loading 811 assets: [===                 ] 16%
# - Loading 811 assets: [===                 ] 16%
# - Loading 811 assets: [===                 ] 17%
# - Loading 811 assets: [===                 ] 17%
# - Loading 811 assets: [===                 ] 17%
# - Loading 811 assets: [===                 ] 17%
# - Loading 811 assets: [===                 ] 17%
# - Loading 811 assets: [===                 ] 17%
# - Loading 811 assets: [===                 ] 17%
# - Loading 811 assets: [===                 ] 17%
# - Loading 811 assets: [===                 ] 18%
# - Loading 811 assets: [===                 ] 18%
# - Loading 811 assets: [===                 ] 18%
# - Loading 811 assets: [===                 ] 18%
# - Loading 811 assets: [===                 ] 18%
# - Loading 811 assets: [===                 ] 18%
# - Loading 811 assets: [===                 ] 18%
# - Loading 811 assets: [===                 ] 18%
# - Loading 811 assets: [===                 ] 18%
# - Loading 811 assets: [===                 ] 19%
# - Loading 811 assets: [===                 ] 19%
# - Loading 811 assets: [===                 ] 19%
# - Loading 811 assets: [===                 ] 19%
# - Loading 811 assets: [===                 ] 19%
# - Loading 811 assets: [===                 ] 19%
# - Loading 811 assets: [===                 ] 19%
# - Loading 811 assets: [===                 ] 19%
# - Loading 811 assets: [====                ] 20%
# - Loading 811 assets: [====                ] 20%
# - Loading 811 assets: [====                ] 20%
# - Loading 811 assets: [====                ] 20%
# - Loading 811 assets: [====                ] 20%
# - Loading 811 assets: [====                ] 20%
# - Loading 811 assets: [====                ] 20%
# - Loading 811 assets: [====                ] 20%
# - Loading 811 assets: [====                ] 21%
# - Loading 811 assets: [====                ] 21%
# - Loading 811 assets: [====                ] 21%
# - Loading 811 assets: [====                ] 21%
# - Loading 811 assets: [====                ] 21%
# - Loading 811 assets: [====                ] 21%
# - Loading 811 assets: [====                ] 21%
# - Loading 811 assets: [====                ] 21%
# - Loading 811 assets: [====                ] 22%
# - Loading 811 assets: [====                ] 22%
# - Loading 811 assets: [====                ] 22%
# - Loading 811 assets: [====                ] 22%
# - Loading 811 assets: [====                ] 22%
# - Loading 811 assets: [====                ] 22%
# - Loading 811 assets: [====                ] 22%
# - Loading 811 assets: [====                ] 22%
# - Loading 811 assets: [====                ] 23%
# - Loading 811 assets: [====                ] 23%
# - Loading 811 assets: [====                ] 23%
# - Loading 811 assets: [====                ] 23%
# - Loading 811 assets: [====                ] 23%
# - Loading 811 assets: [====                ] 23%
# - Loading 811 assets: [====                ] 23%
# - Loading 811 assets: [====                ] 23%
# - Loading 811 assets: [====                ] 24%
# - Loading 811 assets: [====                ] 24%
# - Loading 811 assets: [====                ] 24%
# - Loading 811 assets: [====                ] 24%
# - Loading 811 assets: [====                ] 24%
# - Loading 811 assets: [====                ] 24%
# - Loading 811 assets: [====                ] 24%
# - Loading 811 assets: [====                ] 24%
# - Loading 811 assets: [=====               ] 25%
# - Loading 811 assets: [=====               ] 25%
# - Loading 811 assets: [=====               ] 25%
# - Loading 811 assets: [=====               ] 25%
# - Loading 811 assets: [=====               ] 25%
# - Loading 811 assets: [=====               ] 25%
# - Loading 811 assets: [=====               ] 25%
# - Loading 811 assets: [=====               ] 25%
# - Loading 811 assets: [=====               ] 26%
# - Loading 811 assets: [=====               ] 26%
# - Loading 811 assets: [=====               ] 26%
# - Loading 811 assets: [=====               ] 26%
# - Loading 811 assets: [=====               ] 26%
# - Loading 811 assets: [=====               ] 26%
# - Loading 811 assets: [=====               ] 26%
# - Loading 811 assets: [=====               ] 26%
# - Loading 811 assets: [=====               ] 27%
# - Loading 811 assets: [=====               ] 27%
# - Loading 811 assets: [=====               ] 27%
# - Loading 811 assets: [=====               ] 27%
# - Loading 811 assets: [=====               ] 27%
# - Loading 811 assets: [=====               ] 27%
# - Loading 811 assets: [=====               ] 27%
# - Loading 811 assets: [=====               ] 27%
# - Loading 811 assets: [=====               ] 27%
# - Loading 811 assets: [=====               ] 28%
# - Loading 811 assets: [=====               ] 28%
# - Loading 811 assets: [=====               ] 28%
# - Loading 811 assets: [=====               ] 28%
# - Loading 811 assets: [=====               ] 28%
# - Loading 811 assets: [=====               ] 28%
# - Loading 811 assets: [=====               ] 28%
# - Loading 811 assets: [=====               ] 28%
# - Loading 811 assets: [=====               ] 29%
# - Loading 811 assets: [=====               ] 29%
# - Loading 811 assets: [=====               ] 29%
# - Loading 811 assets: [=====               ] 29%
# - Loading 811 assets: [=====               ] 29%
# - Loading 811 assets: [=====               ] 29%
# - Loading 811 assets: [=====               ] 29%
# - Loading 811 assets: [=====               ] 29%
# - Loading 811 assets: [======              ] 30%
# - Loading 811 assets: [======              ] 30%
# - Loading 811 assets: [======              ] 30%
# - Loading 811 assets: [======              ] 30%
# - Loading 811 assets: [======              ] 30%
# - Loading 811 assets: [======              ] 30%
# - Loading 811 assets: [======              ] 30%
# - Loading 811 assets: [======              ] 30%
# - Loading 811 assets: [======              ] 31%
# - Loading 811 assets: [======              ] 31%
# - Loading 811 assets: [======              ] 31%
# - Loading 811 assets: [======              ] 31%
# - Loading 811 assets: [======              ] 31%
# - Loading 811 assets: [======              ] 31%
# - Loading 811 assets: [======              ] 31%
# - Loading 811 assets: [======              ] 31%
# - Loading 811 assets: [======              ] 32%
# - Loading 811 assets: [======              ] 32%
# - Loading 811 assets: [======              ] 32%
# - Loading 811 assets: [======              ] 32%
# - Loading 811 assets: [======              ] 32%
# - Loading 811 assets: [======              ] 32%
# - Loading 811 assets: [======              ] 32%
# - Loading 811 assets: [======              ] 32%
# - Loading 811 assets: [======              ] 33%
# - Loading 811 assets: [======              ] 33%
# - Loading 811 assets: [======              ] 33%
# - Loading 811 assets: [======              ] 33%
# - Loading 811 assets: [======              ] 33%
# - Loading 811 assets: [======              ] 33%
# - Loading 811 assets: [======              ] 33%
# - Loading 811 assets: [======              ] 33%
# - Loading 811 assets: [======              ] 34%
# - Loading 811 assets: [======              ] 34%
# - Loading 811 assets: [======              ] 34%
# - Loading 811 assets: [======              ] 34%
# - Loading 811 assets: [======              ] 34%
# - Loading 811 assets: [======              ] 34%
# - Loading 811 assets: [======              ] 34%
# - Loading 811 assets: [======              ] 34%
# - Loading 811 assets: [=======             ] 35%
# - Loading 811 assets: [=======             ] 35%
# - Loading 811 assets: [=======             ] 35%
# - Loading 811 assets: [=======             ] 35%
# - Loading 811 assets: [=======             ] 35%
# - Loading 811 assets: [=======             ] 35%
# - Loading 811 assets: [=======             ] 35%
# - Loading 811 assets: [=======             ] 35%
# - Loading 811 assets: [=======             ] 36%
# - Loading 811 assets: [=======             ] 36%
# - Loading 811 assets: [=======             ] 36%
# - Loading 811 assets: [=======             ] 36%
# - Loading 811 assets: [=======             ] 36%
# - Loading 811 assets: [=======             ] 36%
# - Loading 811 assets: [=======             ] 36%
# - Loading 811 assets: [=======             ] 36%
# - Loading 811 assets: [=======             ] 36%
# - Loading 811 assets: [=======             ] 37%
# - Loading 811 assets: [=======             ] 37%
# - Loading 811 assets: [=======             ] 37%
# - Loading 811 assets: [=======             ] 37%
# - Loading 811 assets: [=======             ] 37%
# - Loading 811 assets: [=======             ] 37%
# - Loading 811 assets: [=======             ] 37%
# - Loading 811 assets: [=======             ] 37%
# - Loading 811 assets: [=======             ] 38%
# - Loading 811 assets: [=======             ] 38%
# - Loading 811 assets: [=======             ] 38%
# - Loading 811 assets: [=======             ] 38%
# - Loading 811 assets: [=======             ] 38%
# - Loading 811 assets: [=======             ] 38%
# - Loading 811 assets: [=======             ] 38%
# - Loading 811 assets: [=======             ] 38%
# - Loading 811 assets: [=======             ] 39%
# - Loading 811 assets: [=======             ] 39%
# - Loading 811 assets: [=======             ] 39%
# - Loading 811 assets: [=======             ] 39%
# - Loading 811 assets: [=======             ] 39%
# - Loading 811 assets: [=======             ] 39%
# - Loading 811 assets: [=======             ] 39%
# - Loading 811 assets: [=======             ] 39%
# - Loading 811 assets: [========            ] 40%
# - Loading 811 assets: [========            ] 40%
# - Loading 811 assets: [========            ] 40%
# - Loading 811 assets: [========            ] 40%
# - Loading 811 assets: [========            ] 40%
# - Loading 811 assets: [========            ] 40%
# - Loading 811 assets: [========            ] 40%
# - Loading 811 assets: [========            ] 40%
# - Loading 811 assets: [========            ] 41%
# - Loading 811 assets: [========            ] 41%
# - Loading 811 assets: [========            ] 41%
# - Loading 811 assets: [========            ] 41%
# - Loading 811 assets: [========            ] 41%
# - Loading 811 assets: [========            ] 41%
# - Loading 811 assets: [========            ] 41%
# - Loading 811 assets: [========            ] 41%
# - Loading 811 assets: [========            ] 42%
# - Loading 811 assets: [========            ] 42%
# - Loading 811 assets: [========            ] 42%
# - Loading 811 assets: [========            ] 42%
# - Loading 811 assets: [========            ] 42%
# - Loading 811 assets: [========            ] 42%
# - Loading 811 assets: [========            ] 42%
# - Loading 811 assets: [========            ] 42%
# - Loading 811 assets: [========            ] 43%
# - Loading 811 assets: [========            ] 43%
# - Loading 811 assets: [========            ] 43%
# - Loading 811 assets: [========            ] 43%
# - Loading 811 assets: [========            ] 43%
# - Loading 811 assets: [========            ] 43%
# - Loading 811 assets: [========            ] 43%
# - Loading 811 assets: [========            ] 43%
# - Loading 811 assets: [========            ] 44%
# - Loading 811 assets: [========            ] 44%
# - Loading 811 assets: [========            ] 44%
# - Loading 811 assets: [========            ] 44%
# - Loading 811 assets: [========            ] 44%
# - Loading 811 assets: [========            ] 44%
# - Loading 811 assets: [========            ] 44%
# - Loading 811 assets: [========            ] 44%
# - Loading 811 assets: [=========           ] 45%
# - Loading 811 assets: [=========           ] 45%
# - Loading 811 assets: [=========           ] 45%
# - Loading 811 assets: [=========           ] 45%
# - Loading 811 assets: [=========           ] 45%
# - Loading 811 assets: [=========           ] 45%
# - Loading 811 assets: [=========           ] 45%
# - Loading 811 assets: [=========           ] 45%
# - Loading 811 assets: [=========           ] 45%
# - Loading 811 assets: [=========           ] 46%
# - Loading 811 assets: [=========           ] 46%
# - Loading 811 assets: [=========           ] 46%
# - Loading 811 assets: [=========           ] 46%
# - Loading 811 assets: [=========           ] 46%
# - Loading 811 assets: [=========           ] 46%
# - Loading 811 assets: [=========           ] 46%
# - Loading 811 assets: [=========           ] 46%
# - Loading 811 assets: [=========           ] 47%
# - Loading 811 assets: [=========           ] 47%
# - Loading 811 assets: [=========           ] 47%
# - Loading 811 assets: [=========           ] 47%
# - Loading 811 assets: [=========           ] 47%
# - Loading 811 assets: [=========           ] 47%
# - Loading 811 assets: [=========           ] 47%
# - Loading 811 assets: [=========           ] 47%
# - Loading 811 assets: [=========           ] 48%
# - Loading 811 assets: [=========           ] 48%
# - Loading 811 assets: [=========           ] 48%
# - Loading 811 assets: [=========           ] 48%
# - Loading 811 assets: [=========           ] 48%
# - Loading 811 assets: [=========           ] 48%
# - Loading 811 assets: [=========           ] 48%
# - Loading 811 assets: [=========           ] 48%
# - Loading 811 assets: [=========           ] 49%
# - Loading 811 assets: [=========           ] 49%
# - Loading 811 assets: [=========           ] 49%
# - Loading 811 assets: [=========           ] 49%
# - Loading 811 assets: [=========           ] 49%
# - Loading 811 assets: [=========           ] 49%
# - Loading 811 assets: [=========           ] 49%
# - Loading 811 assets: [=========           ] 49%
# - Loading 811 assets: [==========          ] 50%
# - Loading 811 assets: [==========          ] 50%
# - Loading 811 assets: [==========          ] 50%
# - Loading 811 assets: [==========          ] 50%
# - Loading 811 assets: [==========          ] 50%
# - Loading 811 assets: [==========          ] 50%
# - Loading 811 assets: [==========          ] 50%
# - Loading 811 assets: [==========          ] 50%
# - Loading 811 assets: [==========          ] 51%
# - Loading 811 assets: [==========          ] 51%
# - Loading 811 assets: [==========          ] 51%
# - Loading 811 assets: [==========          ] 51%
# - Loading 811 assets: [==========          ] 51%
# - Loading 811 assets: [==========          ] 51%
# - Loading 811 assets: [==========          ] 51%
# - Loading 811 assets: [==========          ] 51%
# - Loading 811 assets: [==========          ] 52%
# - Loading 811 assets: [==========          ] 52%
# - Loading 811 assets: [==========          ] 52%
# - Loading 811 assets: [==========          ] 52%
# - Loading 811 assets: [==========          ] 52%
# - Loading 811 assets: [==========          ] 52%
# - Loading 811 assets: [==========          ] 52%
# - Loading 811 assets: [==========          ] 52%
# - Loading 811 assets: [==========          ] 53%
# - Loading 811 assets: [==========          ] 53%
# - Loading 811 assets: [==========          ] 53%
# - Loading 811 assets: [==========          ] 53%
# - Loading 811 assets: [==========          ] 53%
# - Loading 811 assets: [==========          ] 53%
# - Loading 811 assets: [==========          ] 53%
# - Loading 811 assets: [==========          ] 53%
# - Loading 811 assets: [==========          ] 54%
# - Loading 811 assets: [==========          ] 54%
# - Loading 811 assets: [==========          ] 54%
# - Loading 811 assets: [==========          ] 54%
# - Loading 811 assets: [==========          ] 54%
# - Loading 811 assets: [==========          ] 54%
# - Loading 811 assets: [==========          ] 54%
# - Loading 811 assets: [==========          ] 54%
# - Loading 811 assets: [==========          ] 54%
# - Loading 811 assets: [===========         ] 55%
# - Loading 811 assets: [===========         ] 55%
# - Loading 811 assets: [===========         ] 55%
# - Loading 811 assets: [===========         ] 55%
# - Loading 811 assets: [===========         ] 55%
# - Loading 811 assets: [===========         ] 55%
# - Loading 811 assets: [===========         ] 55%
# - Loading 811 assets: [===========         ] 55%
# - Loading 811 assets: [===========         ] 56%
# - Loading 811 assets: [===========         ] 56%
# - Loading 811 assets: [===========         ] 56%
# - Loading 811 assets: [===========         ] 56%
# - Loading 811 assets: [===========         ] 56%
# - Loading 811 assets: [===========         ] 56%
# - Loading 811 assets: [===========         ] 56%
# - Loading 811 assets: [===========         ] 56%
# - Loading 811 assets: [===========         ] 57%
# - Loading 811 assets: [===========         ] 57%
# - Loading 811 assets: [===========         ] 57%
# - Loading 811 assets: [===========         ] 57%
# - Loading 811 assets: [===========         ] 57%
# - Loading 811 assets: [===========         ] 57%
# - Loading 811 assets: [===========         ] 57%
# - Loading 811 assets: [===========         ] 57%
# - Loading 811 assets: [===========         ] 58%
# - Loading 811 assets: [===========         ] 58%
# - Loading 811 assets: [===========         ] 58%
# - Loading 811 assets: [===========         ] 58%
# - Loading 811 assets: [===========         ] 58%
# - Loading 811 assets: [===========         ] 58%
# - Loading 811 assets: [===========         ] 58%
# - Loading 811 assets: [===========         ] 58%
# - Loading 811 assets: [===========         ] 59%
# - Loading 811 assets: [===========         ] 59%
# - Loading 811 assets: [===========         ] 59%
# - Loading 811 assets: [===========         ] 59%
# - Loading 811 assets: [===========         ] 59%
# - Loading 811 assets: [===========         ] 59%
# - Loading 811 assets: [===========         ] 59%
# - Loading 811 assets: [===========         ] 59%
# - Loading 811 assets: [============        ] 60%
# - Loading 811 assets: [============        ] 60%
# - Loading 811 assets: [============        ] 60%
# - Loading 811 assets: [============        ] 60%
# - Loading 811 assets: [============        ] 60%
# - Loading 811 assets: [============        ] 60%
# - Loading 811 assets: [============        ] 60%
# - Loading 811 assets: [============        ] 60%
# - Loading 811 assets: [============        ] 61%
# - Loading 811 assets: [============        ] 61%
# - Loading 811 assets: [============        ] 61%
# - Loading 811 assets: [============        ] 61%
# - Loading 811 assets: [============        ] 61%
# - Loading 811 assets: [============        ] 61%
# - Loading 811 assets: [============        ] 61%
# - Loading 811 assets: [============        ] 61%
# - Loading 811 assets: [============        ] 62%
# - Loading 811 assets: [============        ] 62%
# - Loading 811 assets: [============        ] 62%
# - Loading 811 assets: [============        ] 62%
# - Loading 811 assets: [============        ] 62%
# - Loading 811 assets: [============        ] 62%
# - Loading 811 assets: [============        ] 62%
# - Loading 811 assets: [============        ] 62%
# - Loading 811 assets: [============        ] 63%
# - Loading 811 assets: [============        ] 63%
# - Loading 811 assets: [============        ] 63%
# - Loading 811 assets: [============        ] 63%
# - Loading 811 assets: [============        ] 63%
# - Loading 811 assets: [============        ] 63%
# - Loading 811 assets: [============        ] 63%
# - Loading 811 assets: [============        ] 63%
# - Loading 811 assets: [============        ] 63%
# - Loading 811 assets: [============        ] 64%
# - Loading 811 assets: [============        ] 64%
# - Loading 811 assets: [============        ] 64%
# - Loading 811 assets: [============        ] 64%
# - Loading 811 assets: [============        ] 64%
# - Loading 811 assets: [============        ] 64%
# - Loading 811 assets: [============        ] 64%
# - Loading 811 assets: [============        ] 64%
# - Loading 811 assets: [=============       ] 65%
# - Loading 811 assets: [=============       ] 65%
# - Loading 811 assets: [=============       ] 65%
# - Loading 811 assets: [=============       ] 65%
# - Loading 811 assets: [=============       ] 65%
# - Loading 811 assets: [=============       ] 65%
# - Loading 811 assets: [=============       ] 65%
# - Loading 811 assets: [=============       ] 65%
# - Loading 811 assets: [=============       ] 66%
# - Loading 811 assets: [=============       ] 66%
# - Loading 811 assets: [=============       ] 66%
# - Loading 811 assets: [=============       ] 66%
# - Loading 811 assets: [=============       ] 66%
# - Loading 811 assets: [=============       ] 66%
# - Loading 811 assets: [=============       ] 66%
# - Loading 811 assets: [=============       ] 66%
# - Loading 811 assets: [=============       ] 67%
# - Loading 811 assets: [=============       ] 67%
# - Loading 811 assets: [=============       ] 67%
# - Loading 811 assets: [=============       ] 67%
# - Loading 811 assets: [=============       ] 67%
# - Loading 811 assets: [=============       ] 67%
# - Loading 811 assets: [=============       ] 67%
# - Loading 811 assets: [=============       ] 67%
# - Loading 811 assets: [=============       ] 68%
# - Loading 811 assets: [=============       ] 68%
# - Loading 811 assets: [=============       ] 68%
# - Loading 811 assets: [=============       ] 68%
# - Loading 811 assets: [=============       ] 68%
# - Loading 811 assets: [=============       ] 68%
# - Loading 811 assets: [=============       ] 68%
# - Loading 811 assets: [=============       ] 68%
# - Loading 811 assets: [=============       ] 69%
# - Loading 811 assets: [=============       ] 69%
# - Loading 811 assets: [=============       ] 69%
# - Loading 811 assets: [=============       ] 69%
# - Loading 811 assets: [=============       ] 69%
# - Loading 811 assets: [=============       ] 69%
# - Loading 811 assets: [=============       ] 69%
# - Loading 811 assets: [=============       ] 69%
# - Loading 811 assets: [==============      ] 70%
# - Loading 811 assets: [==============      ] 70%
# - Loading 811 assets: [==============      ] 70%
# - Loading 811 assets: [==============      ] 70%
# - Loading 811 assets: [==============      ] 70%
# - Loading 811 assets: [==============      ] 70%
# - Loading 811 assets: [==============      ] 70%
# - Loading 811 assets: [==============      ] 70%
# - Loading 811 assets: [==============      ] 71%
# - Loading 811 assets: [==============      ] 71%
# - Loading 811 assets: [==============      ] 71%
# - Loading 811 assets: [==============      ] 71%
# - Loading 811 assets: [==============      ] 71%
# - Loading 811 assets: [==============      ] 71%
# - Loading 811 assets: [==============      ] 71%
# - Loading 811 assets: [==============      ] 71%
# - Loading 811 assets: [==============      ] 72%
# - Loading 811 assets: [==============      ] 72%
# - Loading 811 assets: [==============      ] 72%
# - Loading 811 assets: [==============      ] 72%
# - Loading 811 assets: [==============      ] 72%
# - Loading 811 assets: [==============      ] 72%
# - Loading 811 assets: [==============      ] 72%
# - Loading 811 assets: [==============      ] 72%
# - Loading 811 assets: [==============      ] 72%
# - Loading 811 assets: [==============      ] 73%
# - Loading 811 assets: [==============      ] 73%
# - Loading 811 assets: [==============      ] 73%
# - Loading 811 assets: [==============      ] 73%
# - Loading 811 assets: [==============      ] 73%
# - Loading 811 assets: [==============      ] 73%
# - Loading 811 assets: [==============      ] 73%
# - Loading 811 assets: [==============      ] 73%
# - Loading 811 assets: [==============      ] 74%
# - Loading 811 assets: [==============      ] 74%
# - Loading 811 assets: [==============      ] 74%
# - Loading 811 assets: [==============      ] 74%
# - Loading 811 assets: [==============      ] 74%
# - Loading 811 assets: [==============      ] 74%
# - Loading 811 assets: [==============      ] 74%
# - Loading 811 assets: [==============      ] 74%
# - Loading 811 assets: [===============     ] 75%
# - Loading 811 assets: [===============     ] 75%
# - Loading 811 assets: [===============     ] 75%
# - Loading 811 assets: [===============     ] 75%
# - Loading 811 assets: [===============     ] 75%
# - Loading 811 assets: [===============     ] 75%
# - Loading 811 assets: [===============     ] 75%
# - Loading 811 assets: [===============     ] 75%
# - Loading 811 assets: [===============     ] 76%
# - Loading 811 assets: [===============     ] 76%
# - Loading 811 assets: [===============     ] 76%
# - Loading 811 assets: [===============     ] 76%
# - Loading 811 assets: [===============     ] 76%
# - Loading 811 assets: [===============     ] 76%
# - Loading 811 assets: [===============     ] 76%
# - Loading 811 assets: [===============     ] 76%
# - Loading 811 assets: [===============     ] 77%
# - Loading 811 assets: [===============     ] 77%
# - Loading 811 assets: [===============     ] 77%
# - Loading 811 assets: [===============     ] 77%
# - Loading 811 assets: [===============     ] 77%
# - Loading 811 assets: [===============     ] 77%
# - Loading 811 assets: [===============     ] 77%
# - Loading 811 assets: [===============     ] 77%
# - Loading 811 assets: [===============     ] 78%
# - Loading 811 assets: [===============     ] 78%
# - Loading 811 assets: [===============     ] 78%
# - Loading 811 assets: [===============     ] 78%
# - Loading 811 assets: [===============     ] 78%
# - Loading 811 assets: [===============     ] 78%
# - Loading 811 assets: [===============     ] 78%
# - Loading 811 assets: [===============     ] 78%
# - Loading 811 assets: [===============     ] 79%
# - Loading 811 assets: [===============     ] 79%
# - Loading 811 assets: [===============     ] 79%
# - Loading 811 assets: [===============     ] 79%
# - Loading 811 assets: [===============     ] 79%
# - Loading 811 assets: [===============     ] 79%
# - Loading 811 assets: [===============     ] 79%
# - Loading 811 assets: [===============     ] 79%
# - Loading 811 assets: [================    ] 80%
# - Loading 811 assets: [================    ] 80%
# - Loading 811 assets: [================    ] 80%
# - Loading 811 assets: [================    ] 80%
# - Loading 811 assets: [================    ] 80%
# - Loading 811 assets: [================    ] 80%
# - Loading 811 assets: [================    ] 80%
# - Loading 811 assets: [================    ] 80%
# - Loading 811 assets: [================    ] 81%
# - Loading 811 assets: [================    ] 81%
# - Loading 811 assets: [================    ] 81%
# - Loading 811 assets: [================    ] 81%
# - Loading 811 assets: [================    ] 81%
# - Loading 811 assets: [================    ] 81%
# - Loading 811 assets: [================    ] 81%
# - Loading 811 assets: [================    ] 81%
# - Loading 811 assets: [================    ] 81%
# - Loading 811 assets: [================    ] 82%
# - Loading 811 assets: [================    ] 82%
# - Loading 811 assets: [================    ] 82%
# - Loading 811 assets: [================    ] 82%
# - Loading 811 assets: [================    ] 82%
# - Loading 811 assets: [================    ] 82%
# - Loading 811 assets: [================    ] 82%
# - Loading 811 assets: [================    ] 82%
# - Loading 811 assets: [================    ] 83%
# - Loading 811 assets: [================    ] 83%
# - Loading 811 assets: [================    ] 83%
# - Loading 811 assets: [================    ] 83%
# - Loading 811 assets: [================    ] 83%
# - Loading 811 assets: [================    ] 83%
# - Loading 811 assets: [================    ] 83%
# - Loading 811 assets: [================    ] 83%
# - Loading 811 assets: [================    ] 84%
# - Loading 811 assets: [================    ] 84%
# - Loading 811 assets: [================    ] 84%
# - Loading 811 assets: [================    ] 84%
# - Loading 811 assets: [================    ] 84%
# - Loading 811 assets: [================    ] 84%
# - Loading 811 assets: [================    ] 84%
# - Loading 811 assets: [================    ] 84%
# - Loading 811 assets: [=================   ] 85%
# - Loading 811 assets: [=================   ] 85%
# - Loading 811 assets: [=================   ] 85%
# - Loading 811 assets: [=================   ] 85%
# - Loading 811 assets: [=================   ] 85%
# - Loading 811 assets: [=================   ] 85%
# - Loading 811 assets: [=================   ] 85%
# - Loading 811 assets: [=================   ] 85%
# - Loading 811 assets: [=================   ] 86%
# - Loading 811 assets: [=================   ] 86%
# - Loading 811 assets: [=================   ] 86%
# - Loading 811 assets: [=================   ] 86%
# - Loading 811 assets: [=================   ] 86%
# - Loading 811 assets: [=================   ] 86%
# - Loading 811 assets: [=================   ] 86%
# - Loading 811 assets: [=================   ] 86%
# - Loading 811 assets: [=================   ] 87%
# - Loading 811 assets: [=================   ] 87%
# - Loading 811 assets: [=================   ] 87%
# - Loading 811 assets: [=================   ] 87%
# - Loading 811 assets: [=================   ] 87%
# - Loading 811 assets: [=================   ] 87%
# - Loading 811 assets: [=================   ] 87%
# - Loading 811 assets: [=================   ] 87%
# - Loading 811 assets: [=================   ] 88%
# - Loading 811 assets: [=================   ] 88%
# - Loading 811 assets: [=================   ] 88%
# - Loading 811 assets: [=================   ] 88%
# - Loading 811 assets: [=================   ] 88%
# - Loading 811 assets: [=================   ] 88%
# - Loading 811 assets: [=================   ] 88%
# - Loading 811 assets: [=================   ] 88%
# - Loading 811 assets: [=================   ] 89%
# - Loading 811 assets: [=================   ] 89%
# - Loading 811 assets: [=================   ] 89%
# - Loading 811 assets: [=================   ] 89%
# - Loading 811 assets: [=================   ] 89%
# - Loading 811 assets: [=================   ] 89%
# - Loading 811 assets: [=================   ] 89%
# - Loading 811 assets: [=================   ] 89%
# - Loading 811 assets: [==================  ] 90%
# - Loading 811 assets: [==================  ] 90%
# - Loading 811 assets: [==================  ] 90%
# - Loading 811 assets: [==================  ] 90%
# - Loading 811 assets: [==================  ] 90%
# - Loading 811 assets: [==================  ] 90%
# - Loading 811 assets: [==================  ] 90%
# - Loading 811 assets: [==================  ] 90%
# - Loading 811 assets: [==================  ] 90%
# - Loading 811 assets: [==================  ] 91%
# - Loading 811 assets: [==================  ] 91%
# - Loading 811 assets: [==================  ] 91%
# - Loading 811 assets: [==================  ] 91%
# - Loading 811 assets: [==================  ] 91%
# - Loading 811 assets: [==================  ] 91%
# - Loading 811 assets: [==================  ] 91%
# - Loading 811 assets: [==================  ] 91%
# - Loading 811 assets: [==================  ] 92%
# - Loading 811 assets: [==================  ] 92%
# - Loading 811 assets: [==================  ] 92%
# - Loading 811 assets: [==================  ] 92%
# - Loading 811 assets: [==================  ] 92%
# - Loading 811 assets: [==================  ] 92%
# - Loading 811 assets: [==================  ] 92%
# - Loading 811 assets: [==================  ] 92%
# - Loading 811 assets: [==================  ] 93%
# - Loading 811 assets: [==================  ] 93%
# - Loading 811 assets: [==================  ] 93%
# - Loading 811 assets: [==================  ] 93%
# - Loading 811 assets: [==================  ] 93%
# - Loading 811 assets: [==================  ] 93%
# - Loading 811 assets: [==================  ] 93%
# - Loading 811 assets: [==================  ] 93%
# - Loading 811 assets: [==================  ] 94%
# - Loading 811 assets: [==================  ] 94%
# - Loading 811 assets: [==================  ] 94%
# - Loading 811 assets: [==================  ] 94%
# - Loading 811 assets: [==================  ] 94%
# - Loading 811 assets: [==================  ] 94%
# - Loading 811 assets: [==================  ] 94%
# - Loading 811 assets: [==================  ] 94%
# - Loading 811 assets: [=================== ] 95%
# - Loading 811 assets: [=================== ] 95%
# - Loading 811 assets: [=================== ] 95%
# - Loading 811 assets: [=================== ] 95%
# - Loading 811 assets: [=================== ] 95%
# - Loading 811 assets: [=================== ] 95%
# - Loading 811 assets: [=================== ] 95%
# - Loading 811 assets: [=================== ] 95%
# - Loading 811 assets: [=================== ] 96%
# - Loading 811 assets: [=================== ] 96%
# - Loading 811 assets: [=================== ] 96%
# - Loading 811 assets: [=================== ] 96%
# - Loading 811 assets: [=================== ] 96%
# - Loading 811 assets: [=================== ] 96%
# - Loading 811 assets: [=================== ] 96%
# - Loading 811 assets: [=================== ] 96%
# - Loading 811 assets: [=================== ] 97%
# - Loading 811 assets: [=================== ] 97%
# - Loading 811 assets: [=================== ] 97%
# - Loading 811 assets: [=================== ] 97%
# - Loading 811 assets: [=================== ] 97%
# - Loading 811 assets: [=================== ] 97%
# - Loading 811 assets: [=================== ] 97%
# - Loading 811 assets: [=================== ] 97%
# - Loading 811 assets: [=================== ] 98%
# - Loading 811 assets: [=================== ] 98%
# - Loading 811 assets: [=================== ] 98%
# - Loading 811 assets: [=================== ] 98%
# - Loading 811 assets: [=================== ] 98%
# - Loading 811 assets: [=================== ] 98%
# - Loading 811 assets: [=================== ] 98%
# - Loading 811 assets: [=================== ] 98%
# - Loading 811 assets: [=================== ] 99%
# - Loading 811 assets: [=================== ] 99%
# - Loading 811 assets: [=================== ] 99%
# - Loading 811 assets: [=================== ] 99%
# - Loading 811 assets: [=================== ] 99%
# - Loading 811 assets: [=================== ] 99%
# - Loading 811 assets: [=================== ] 99%
# - Loading 811 assets: [=================== ] 99%
# - Loading 811 assets: [====================] 100%

# %%
from menpo.visualize import visualize_images

visualize_images(images)

# %% [markdown]
# Wait a moment... What are these points!

# %% [markdown]
# Fair enough, I kind of lied before...
#
# What we really need is a large collection of carefully ** annotated** face images.

# %% [markdown]
# The previous annotations try to encode the notion face **shape**...
#
# > A shape is the form of an object or its external boundary, outline, or external surface, as opposed to other properties such as colour, texture or material composition.
#
# > <div align="right"><font size="2">Wikipedia</font></div>

# %% [markdown]
# ...by consistently identifying the positions of a small set of **landmarks** defining the faces in all images.
#
# > In morphometrics, landmark point or shortly landmark is a point in a shape object in which correspondences between and within the populations of the object are preserved.
#
# > <div align="right"><font size="2">Wikipedia</font></div>

# %% [markdown]
# Mathematically, a shape can be defined as:
#
# $$\mathbf{s} = (x_1, y_1, \cdots, x_v, y_v)^T \in \mathcal{R}^{2v \times 1}$$

# %%
from menpo.visualize import visualize_shapes

visualize_shapes([i.landmarks for i in images])

# %% [markdown]
# In AAMs, images of a particular object are generated by combining **linear models** describing the **shape** and **texture** of the object using a specific **motion** model (also referred to as *the warp*).

# %% [markdown]
# Let us start by *formally* defining the **shape model**:
#
# $$\mathbf{s} = \bar{\mathbf{s}} + \sum_{i=1}^{n_s} p_i \mathbf{s}_i = \bar{\mathbf{s}} + \mathbf{S} \mathbf{p}$$

# %% [markdown]
# where:
#
# $$\bar{\mathbf{s}} = (\bar{x_1}, \bar{y_1}, \cdots, \bar{x_v}, \bar{y_v})^T\in \mathcal{R}^{2v}$$
#
# $$\mathbf{p} = (p_1, \cdots, p_{n_s})^T \in \mathcal{R}^{n_s}$$
#
# $$\mathbf{S} = (\mathbf{s}_1, \cdots, \mathbf{s}_{n_s} )\in \mathcal{R}^{2v \, \times \, n_s}$$

# %% [markdown]
# The previous shape model can be learned by applying **Principal Component Analysis (PCA)** to the set of manually annotated points defining the object shape in the images (usually after registering all shapes using **Procrustes Analysis**).

# %%
from menpo.transform import Translation, GeneralizedProcrustesAnalysis
from menpo.model import PCAModel

# extract shapes from images
shapes = [i.landmarks['ibug_face_66'].lms for i in images] 

# centralize shapes
centered_shapes = [Translation(-s.centre()).apply(s) for s in shapes]
# align centralized shape using Procrustes Analysis
gpa = GeneralizedProcrustesAnalysis(centered_shapes)
aligned_shapes = [s.aligned_source() for s in gpa.transforms]

# build shape model
shape_model = PCAModel(aligned_shapes)

# %%
from menpofit.visualize import visualize_shape_model

visualize_shape_model(shape_model)

# %% [markdown]
# Note that because the shapes were normalized using Procrustes Analysis before we applied PCA, the previous shape model has mainly learned **nonrigid** facial deformations and lacks the ability of placing shapes at arbitrary positions on the image plane.

# %% [markdown]
# Luckly, this problem can be solved by composing the model with a 2d similarity transform:
#
# $$\mathbf{x} = s \mathbf{R} \left( \bar{\mathbf{x}} + \sum_{i=1}^{n_s} p_i \mathbf{x}_i \right) +\mathbf{t}$$

# %% [markdown]
# where:
#
# $$\mathbf{x} = (x_i, y_i)^T \in \mathcal{R}^{2}$$
#
# $$s \in \mathcal{R}$$
#
# $$\mathbf{R} \in \mathcal{R}^{2 \, \times \, 2}$$
#
# $$\mathbf{t} = (t_x, t_y)^T \in \mathcal{R}^{2}$$

# %% [markdown]
# Luckily after some clever reparameterization (Matthews and Baker, 2004) the shape model can still be concisely expressed as before:
#
# $$\mathbf{s} = \bar{\mathbf{s}} + \sum_{i=1}^{4} p^*_i \mathbf{s}^*_i + \sum_{i=1}^{n_s} p_i \mathbf{s}_i = \bar{\mathbf{s}} + \mathbf{S}^* \mathbf{p}^* + \mathbf{S} \mathbf{p} = \bar{\mathbf{s}} + \tilde{\mathbf{S}} \tilde{\mathbf{p}}$$

# %% [markdown]
# where:
#
# $$\mathbf{p}^* = (p^*_1, \cdots,  p^*_4)^T \in \mathbf{R}^{4}$$
#
# $$\mathbf{S}^* = (s^*_1, \cdots, s^*_4)^T \in \mathbf{R}^{2v \, \times \, 4}$$
#
# $$\mathbf{s}^*_1 = \bar{\mathbf{s}} \in \mathbf{R}^{2v}$$
#
# $$\mathbf{s}^*_2 = (-y_1, x_1, \cdots, -y_v, x_v)^T \in \mathbf{R}^{2v}$$
#
# $$\mathbf{s}^*_3 = (1, 0, \cdots, 1, 0)^T \in \mathbf{R}^{2v}$$
#
# $$\mathbf{s}^*_4 = (0, 1, \cdots, 0, 1)^T \in \mathbf{R}^{2v}$$

# %%
import numpy as np
from menpo.transform import AlignmentSimilarity
from menpo.model import MeanInstanceLinearModel
from menpofit.modelinstance import OrthoPDM

# get shape model mean as numpy array
shape_vector = shape_model.mean().as_vector()

# initialize S star
S_star = np.zeros((4, shape_vector.shape[0]))
# first column is the mean
S_star[0, :] = shape_vector  # Comp. 1 - just the mean
# second column is the rotated mean
rotated_ccw = shape_model.mean().points[:, ::-1].copy()  # flip x,y -> y,x
rotated_ccw[:, 0] = -rotated_ccw[:, 0]  # negate (old) y
S_star[1, :] = rotated_ccw.flatten()  # C2 - the mean rotated 90 degs
# third column
S_star[2, ::2] = 1  # Tx
# fourth column
S_star[3, 1::2] = 1  # Ty

# build 2d similarity model
sim_2d_model = MeanInstanceLinearModel(S_star, shape_vector, shape_model.mean())

# orthogonalize and compose 2d similarity model with original shape model
augmented_sm = shape_model.copy()
augmented_sm.orthonormalize_against_inplace(sim_2d_model)

# %%
visualize_shape_model(augmented_sm.model)

# %%
from menpofit.transform import DifferentiableAlignmentSimilarity
from menpofit.modelinstance import OrthoPDM

augmented_sm = OrthoPDM(shape_model, AlignmentSimilarity)

# %%
visualize_shape_model(augmented_sm.model)

# %% [markdown]
# So far, so good ;-)
#
# Apart from that las bit...

# %% [markdown]
# Let us now switch our attention to the **appearance model**.
#
# We will shortly see how the appearance model is also learned using PCA. However, in order to be able to apply PCA we first need to introduce the **motion model** and the concept of **shape-free textures**.

# %% [markdown]
# PCA can only be applied to consistent vector space or, in other words, all vectors to which we want to apply PCA to must have the same lenght.

# %% [markdown]
# This is clearly not the case for the face images we just loaded:

# %%
print 'image 0 is:', images[0]
print 'image 1 is:', images[1]
# Out:
# image 0 is: 142W x 135H 2D Image with 1 channel
# image 1 is: 141W x 140H 2D Image with 1 channel

# %% [markdown]
# We could resize all images to a particular resolution but that is very likely to arbitrarily modify their original aspect ration and include a lot of backgorund information (even if images were tighly cropped).

# %% [markdown]
# Instead, the idea is to make use of the annotated landmarks (which are a requirement) to **define** the face appearance region in each image and **map** it to a consitent vector space.
#
# This can be done by:
#
# - Defining a **reference image frame** (typically build using the shape model mean shape).
#
# - Warping all images to the previous reference frame by using a **non-linear warping function**.

# %% [markdown]
# Note that, the non-linear warping function is referred to as the **motion model** and typical choices for this function include **Piece Wise Affine** and **Thin Plate Splines** warps.
#
# Once all images have been warped onto the reference frame they all have the same dimensionality (i.e. they all have the same number of pixels) and we are ready to apply PCA.
#
# Note that, after they have being warped, all images also **share** the same face shape and hence the name **shape-free textures**.

# %% [markdown]
# A shape free texture can be mathematically defined using the following expression:
#
# $$\mathcal{vec}\left(I(\mathcal{W}(\mathbf{x}; \mathbf{p}))\right) = \mathbf{t}$$

# %%
from menpo.transform import PiecewiseAffine
from menpofit.aam.builder import build_reference_frame 

# build reference frame
reference_frame = build_reference_frame(shape_model.mean())
reference_shape = reference_frame.landmarks['source'].lms

# build PiecewiseAffine transforms
transforms = [PiecewiseAffine(reference_shape, s) for s in shapes]

# warp images
warped_images = []
for (i, t) in zip(images, transforms):
    wi = i.warp_to_mask(reference_frame.mask, t) 
    wi.landmarks = reference_frame.landmarks
    warped_images.append(wi)

# %%
visualize_images(warped_images)

# %% [markdown]
# After introducing the **motion model** concept of shape-free textures, we are now ready to *formally* define the appearance model:

# %% [markdown]
# $$\mathbf{a} = \bar{\mathbf{a}} + \sum_{i=1}^{n_a} c_i \mathbf{a}_i = \bar{\mathbf{a}} + \mathbf{A} \mathbf{c}$$

# %% [markdown]
# where:
#
# $$\bar{\mathbf{a}} = (\bar{a_1}, \cdots, \bar{a_d})^T\in \mathcal{R}^{d}$$
#
# $$\mathbf{c} = (c_1, \cdots, c_{n_t})^T \in \mathcal{R}^{n_t}$$
#
# $$\mathbf{A} = (\mathbf{a}_1, \cdots, \mathbf{a}_{n_s} )\in \mathcal{R}^{d \, \times \, n_t}$$

# %%
appearance_model = PCAModel(warped_images)

# %%
from menpofit.visualize import visualize_appearance_model

visualize_appearance_model(appearance_model)

# %% [markdown]
# Well done!!! We have now almost covered the basics concepts defining **Active Appearance Models**.
#
# Only one bit is missing, and that is how to combine the previous three models (**shape**,  **appearance** and **motion**) so that we can effectively generate novel face images using AAMs.
#
# And the answer is:

# %% [markdown]
# - Generate a novel **shape instance**:
#
# $$\mathbf{s} = \bar{\mathbf{s}} + \mathbf{S} \mathbf{p}$$

# %% [markdown]
# - Generate a novel **appearance instance** and rearrange it back onto a shape-free texture form:
#
# $$\mathbf{a} = \bar{\mathbf{a}} + \mathbf{A} \mathbf{c}$$
#
# $$A(x) = \mathcal{matrix} \left( \mathbf{a} \right)$$

# %% [markdown]
# - Warp the shape-free appearance intance onto the shape instance using the motion model:
#
# $$A(\mathcal{W}(\mathbf{x}, p)) = I(\mathbf{x})$$

# %%
# choose shape parameters at random
p = np.random.randn(shape_model.n_components) * np.sqrt(shape_model.eigenvalues)
# generate shape instance
s = shape_model.instance(p)

# define image frame containing shape instance
I = build_reference_frame(s)
landmarks = I.landmarks['source'].lms

# %%
I.view_landmarks(group='source', render_numbering=False)

# %%
# choose appearance parameters at random
c = np.random.randn(appearance_model.n_components) * np.sqrt(appearance_model.eigenvalues)
# generate shape instance
A = appearance_model.instance(c)

# %%
A.view()

# %%
# compute PiecewiseAffine transform
transform = PiecewiseAffine(landmarks, A.landmarks['source'].lms)

I = A.warp_to_mask(I.mask, transform, warp_landmarks=True)

# %%
I.view_landmarks(group='source', render_numbering=False)

# %% [markdown]
# Things to take with you from this first part:
#
# - AAMs are **non-linear**, **generative**, and **parametric** models of visual phenomena.
#
# - They consists of three different sub-models:
#   - **Shape** model
#   - **Appearance** model
#   - **Motion** model
#
# - Shape and appearance models are **linear** models learned from annotated training data using **PCA**.
#
# - The motion model **non-linearly** relates the shape and appearance models and is itself an essential part of the AAM formulation.

# %% [markdown]
# ###Questions?

# %% [markdown]
# I do have a question...
#
# So, how good are AAMs at modelling visual phenomena? And more specifically, are linear models of shape and appearance sufficient to accurately model in-the-wild human faces?

# %% [markdown]
# Let's try to answer it.
#
# As before, let us start with the shape model.

# %% [markdown]
# Is the previous also true for the appearance model?

# %% [markdown]
#  Let us reconstruct all

# %%
app_n_active = [5, 10, 25, 50, 100, 500, appearance_model.n_components]

# initialize parameters, reconstructions and error lists
app_param = []
app_recon = []
app_error = []
for n in app_n_active:
    # set active components
    appearance_model.n_active_components = n
    # project warped image onto appearance model
    param = [appearance_model.project(i) for i in warped_images]
    # reconstruct warped images
    recon = [appearance_model.instance(p) for p in param]
    # compute reconstruction errors
    error = [np.sum(i.as_vector() - r.as_vector())**2 
             for (i, r) in zip(warped_images, recon)]
    # save parameters, reconstructions and error
    app_param.append(param)
    app_recon.append(recon)
    app_error.append(error)

# %%
from menpofit.fittingresult import compute_cumulative_error

max_error = np.max(app_error[0]) / 100
app_error_range = np.arange(0, max_error, max_error / 1000)

# initialize cumulative error list
app_cumulative_error = []

for e in app_error:
    # compute cumulative error
    cumulative_error = compute_cumulative_error(e, app_error_range)
    # save it 
    app_cumulative_error.append(cumulative_error)

# %%
app_cumulative_error = np.asarray(app_cumulative_error)


legend = []
for n in app_n_active:
    legend.append('{} eigenvector'.format(n))
    
plt.plot(app_error_range, app_cumulative_error.T)
plt.hold(True)
plt.legend = legend

# %% [markdown]
# What about the distribution of appearance parameters?

# %%
from scipy.stats import norm

param_ind = 50

app_param_all = np.asarray(app_param[-1])

hist, bins, _ = plt.hist(app_param_all[:, param_ind], 40, normed=True,facecolor='green', alpha=0.75)


mu = 0
sigma = np.sqrt(appearance_model.eigenvalues[param_ind])
y = plt.normpdf(bins, mu, sigma)

plt.plot(bins, y, 'rs--')

# fit normal to parameters
mu, sigma = norm.fit(app_param_all[:, param_ind])
y = plt.normpdf(bins, mu, sigma)

plt.plot(bins, y, 'bx--')

# %%
c = np.zeros(appearance_model.n_components) 
c[param_ind] = -2
appearance_model.instance(c).view()

# %%
visualize_appearance_model(appearance_model)

# %%
error_type = 'rmse'

n = np.arange(8)
n_active = np.hstack((2 ** n, sm.n_components))

#err = np.empty((len(n_active), len(shapes)) + shapes[0].points.shape)
r = []
r2 = []
for i, n in enumerate(n_active):
    pdm.model.n_active_components = n

    e = []
    e2 = []
    for j, s in enumerate(shapes):
        pdm.set_target(s)
        #err[i, j] = compute_error(s, pdm.target)
        e.append(s.as_vector() - pdm.target.as_vector())
        e2.append(compute_error(s, pdm.target, error_type=error_type))
        
    r.append(e)   
    r2.append(e2)

# %%
# %matplotlib inline

from __future__ import division
import numpy as np
import matplotlib.pylab as plt

# %%
import menpo.io as mio
from menpo.landmark import labeller, ibug_face_66

path = '/Users/joan/PhD/DataBases/faces/lfpw/trainset/'

shapes = []
for lg in mio.import_landmark_files(path, verbose=True):
    s = lg.lms
    s.landmarks['all'] = s
    labeller(s, 'all', ibug_face_66)
    shapes.append(s)

# %%
from menpo.visualize import visualize_shapes

lm = [s.landmarks for s in shapes]

visualize_shapes(lm)

# %%
from menpofit.builder import build_shape_model

# build shape model
sm = build_shape_model(shapes)

# %%
from menpofit.visualize import visualize_shape_model

visualize_shape_model(sm)

# %%
from menpofit.modelinstance import OrthoPDM
from menpofit.transform import DifferentiableAlignmentSimilarity

# append similairty bases
pdm = OrthoPDM(sm, DifferentiableAlignmentSimilarity)

# %%
from menpofit.fittingresult import compute_error 

error_type = 'rmse'

n = np.arange(8)
n_active = np.hstack((2 ** n, sm.n_components))

#err = np.empty((len(n_active), len(shapes)) + shapes[0].points.shape)
r = []
r2 = []
for i, n in enumerate(n_active):
    pdm.model.n_active_components = n

    e = []
    e2 = []
    for j, s in enumerate(shapes):
        pdm.set_target(s)
        #err[i, j] = compute_error(s, pdm.target)
        e.append(s.as_vector() - pdm.target.as_vector())
        e2.append(compute_error(s, pdm.target, error_type=error_type))
        
    r.append(e)   
    r2.append(e2)

# %%
plt.hist(np.asarray(r[5]).ravel(), 100, normed=None, facecolor='green', alpha=0.75);

# %%
np.asarray(cumulative_errors).shape

# %%
from menpofit.fittingresult import compute_cumulative_error

error_range = np.arange(0, 10, 0.01)

cumulative_errors = []
for e in r2:
    cumulative_error = compute_cumulative_error(e, error_range)
    cumulative_errors.append(cumulative_error)
    
cumulative_errors = np.asarray(cumulative_errors).T

legend = []
for n in n_active:
    legend.append('{} eigenvector'.format(n))
    
plt.plot(error_range, cumulative_errors)
plt.hold(True)
plt.legend = legend
legend

# %% [markdown]
# How good is the model at reconstructing the data?

# %%
pdm.model.n_active_components = pdm.model.n_components

parameters = []

for j, s in enumerate(shapes):
    pdm.set_target(s)
    parameters.append(pdm.as_vector())

# %%
P = np.asarray(parameters)

print P.shape

# %%
n = 12
p0 = P[:, n]
p1 = P[:, n+1]
n, bins_x, bins_y, img = plt.hist2d(p0, p1, bins=100, normed=1);

# %%
n = 130
p = P[:, n]
l = sm.eigenvalues[n-4]
n_bins = 100

# %%
from scipy.stats import norm

plt.hold(True)

# best fit of data
(mu, sigma) = norm.fit(p)

# the histogram of the data
n, bins, patches = plt.hist(p, 100, normed=1, facecolor='green', alpha=0.75)

# add a 'best fit' line
y = plt.normpdf(bins, mu, sigma)
plt.plot(bins, y, 'r--', linewidth=2)

# add a 'best fit' line
y = plt.normpdf(bins, 0, np.sqrt(l))
plt.plot(bins, y, 'b--', linewidth=2)

# %%
sm.instance([0, 0, 0, 0, -3000] / np.sqrt(sm.eigenvalues[4])).view_landmarks()

# %%
sm.template_instance.view()

# %%
hist, bin_edges = np.histogram(param, bins=100, normed=True)

bin_center = 0.5*(bin_edges[1:] + bin_edges[:-1])
plt.stem(bin_center, hist * dx, where='mid')

m = np.mean(p)
sigma = np.std(p)

plt.plot(x, plt.normpdf(x, m, sigma) * 0.1, 'r')

# %%
np.sum(hist * dx)

# %%
param = params[:, 3]
n_bins = 100

# %%
max_p = np.max(param)
min_p = np.min(param)
r = max_p - min_p
dx = r / n_bins

# %%
dx

# %%
print np.sum(a[0] * dx)
print np.sum(plt.normpdf(x, m, sigma) / 10)

# %%
np.where([params[:, 3] / np.sqrt(sm.eigenvalues[3]) < -20])[-1]

# %%
3*np.sqrt(sm.eigenvalues[3])

# %%
sm.instance([0, 0, 0, -16]).view()

# %%
shapes[524].view()

# %% [markdown]
# ## Part 2: Fitting Active Appearance Models
# ---

# %% [markdown]
# AAMs were originally developed for solving **non-rigid object alignment** problems. And up until now they remain quite popular in the domains of *face alignment* and *medical image registration*.
#
# As we did in part one, we will find it useful to restrict the problem to the domain faces, i.e. we will use AAMs to specifically tackle the **face alignment** problem.

# %% [markdown]
# Let us start by defining the problem:
#
# > Fitting an Active Appearance Model consists of finding the optimal parameters for which its shape and appearance models accurately describe the object being modelled in an image.

# %% [markdown]
# Note that the only available information at test time is:

# %% [markdown]
# - The input **image** which we want to fit.

# %%
# load image
img = mio.import_image('/Users/joan/PhD/DataBases/faces/lfpw/testset/image_0001.png')

# pre-processing
img.crop_to_landmarks_proportion_inplace(0.5)
img = img.rescale_landmarks_to_diagonal_range(100)
labeller(img, 'PTS', ibug_face_66)
if img.n_channels == 3:
    img = img.as_greyscale(mode='luminosity')

# %%
img.view()

# %% [markdown]
# - An **initial guess** for the face shape.

# %%
from menpofit.base import noisy_align

# noisy aligned the shape model's mean with the ground truth
transform = noisy_align(shape_model.mean(), 
                        img.landmarks['ibug_face_66'].lms)
initial_shape = transform.apply(shape_model.mean())

# add the initial shape as landmarks to the image
img.landmarks['initial_guess'] = initial_shape

# %%
img.view_landmarks(group='initial_guess', render_numbering=False);

# %% [markdown]
# - The **AAM** that we will use to fit the image.

# %%
visualize_aam(aam)

# %% [markdown]
# The problem of fitting AAMs to input images can be *formally* defined as:

# %% [markdown]
# $$\mathbf{p}_o, \mathbf{c}_o = \underset{\mathbf{p}, \mathbf{c}}{\mathrm{arg\,min\;}} \, \frac{1}{2}\sum_{\mathbf{x} \in \Omega} \left\| I(\mathcal{W}(\mathbf{x}; \mathbf{p})) -  \bar{A}(\mathbf{x}) + \sum_{i=1}^{n_s} \mathbf{c}_i A_i(\mathbf{x}) \right\|^2 $$

# %% [markdown]
# which can be concisely rewritten in vector form as:

# %% [markdown]
# $$\mathbf{p}_o, \mathbf{c}_o = \underset{\mathbf{p}, \mathbf{c}}{\mathrm{arg\,min\;}} \, \mathcal{f}(\mathbf{p}, \mathbf{c}) = \underset{\mathbf{p}, \mathbf{c}}{\mathrm{arg\,min\;}} \, \frac{1}{2} \left\| \mathbf{i}[\mathbf{p}] -  \bar{\mathbf{a}} - \mathbf{A}\mathbf{c} \right\|^2 $$

# %% [markdown]
# Therefore, fitting an AAM to novel image consists of finding the optimal shape and appearance parameters for which the previous expression is minimized.
#
# Note that:

# %% [markdown]
# - The shape parameters control the way in which the input image is warped.

# %% [markdown]
# - The reconstruction error of the warped input image by the appearance model is the quantity to be minimized and, consequently, is what drives the optimization.

# %% [markdown]
# - Ideally, the reconstruction error should be minimized when the shape parameters correctly place the face landmarks onto the input image.
#
#     When that happens, the input image is correctly warped onto the reference frame and its appearance model reconsturction should be optimal (hence, the error minimized).

# %% [markdown]
# Let us define the residual:
#
# $$ \mathbf{r}(\mathbf{p}, \mathbf{c}) = \mathbf{i}[\mathbf{p}] -  \bar{\mathbf{a}} - \mathbf{A}\mathbf{c}$$

# %% [markdown]
# note that the problem can now also be written as:
#
# $$\mathbf{p}_o, \mathbf{c}_o = \underset{\mathbf{p}, \mathbf{c}}{\mathrm{arg\,min\;}} \, \frac{1}{2} \mathbf{r}(\mathbf{p}, \mathbf{c})^T \mathbf{r}(\mathbf{p}, \mathbf{c}) $$
#
# or
#
# $$\mathbf{b}_o = \underset{\mathbf{b}}{\mathrm{arg\,min\;}} \, \frac{1}{2} \mathbf{r}(\mathbf{b})^T \mathbf{r}(\mathbf{b}) \quad \text{where} \quad \mathbf{b} = (\mathbf{p}^T, \mathbf{c}^T)^T$$

# %% [markdown]
# We can see that the residual is **linear** with respect to the appearance parameters but **nonlinear** with respect to shape parameters through the motion model.

# %% [markdown]
# If the residual was linear with respect to both shape and appearance parameters, the previous optimization problem would reduce to a linear least squares problems. The problem would then have a closed-form solution.

# %% [markdown]
# Unfortunately this is not the case and fitting AAMs involves solving a **non-linear least squares** problem.

# %% [markdown]
# The most common way of solving the previous problem is by using the **Gauss-Newton** algorithm:

# %% [markdown]
# 1) Perform a **first order** Taylor expansion of the residual:
#
# $$ \mathbf{r}(\mathbf{b} + \Delta \mathbf{b}) \approx \mathbf{r}(\mathbf{b}) + \frac{\partial \mathbf{r}}{\partial \mathbf{b}} \Delta \mathbf{b} $$

# %% [markdown]
# 2) **Plug it** into the cost function:
#
# $$ \mathcal{f}(\mathbf{b}, \Delta \mathbf{b}) = \frac{1}{2} \left\| \mathbf{r}(\mathbf{b}) + \frac{\partial \mathbf{r}^T}{\partial \mathbf{b}} \Delta \mathbf{b} \right\|^2$$

# %% [markdown]
# 3) Solve for the **increments** on the parameters:
#
# $$\Delta \mathbf{b}_o = \underset{\mathbf{b}}{\mathrm{arg\,min\;}} \, \mathcal{f}(\Delta \mathbf{b}) = \underset{\mathbf{b}}{\mathrm{arg\,min\;}} \, \frac{1}{2} \left\| \mathbf{r}(\mathbf{b}) + \frac{\partial \mathbf{r}^T}{\partial \mathbf{b}} \Delta \mathbf{b} \right\|^2 $$
#
# $$\frac{\partial\mathcal{f}}{\partial\Delta\mathbf{b}} = \frac{\partial \left(\frac{1}{2} \left\| \mathbf{r}(\mathbf{b}) + \frac{\partial \mathbf{r}}{\partial \mathbf{b}} \Delta \mathbf{b} \right\|^2\right)}{\partial\Delta\mathbf{b}} = \left( \mathbf{r}(\mathbf{b}) + \frac{\partial \mathbf{r}}{\partial \mathbf{b}} \Delta \mathbf{b} \right) \frac{\partial \mathbf{r}}{\partial \mathbf{b}}^T =0$$
#
# $$\Delta \mathbf{b} = - \left( \frac{\partial \mathbf{r}}{\partial \mathbf{b}}^T \frac{\partial \mathbf{r}}{\partial \mathbf{b}} \right)^{-1} \frac{\partial \mathbf{r}}{\partial \mathbf{b}}^T \mathbf{r}(\mathbf{b})$$
#
# $$\Delta \mathbf{b} = - \mathbf{R} \mathbf{r}(\mathbf{b}) \quad \text{where} \quad \mathbf{R} = \left( \frac{\partial \mathbf{r}}{\partial \mathbf{b}}^T \frac{\partial \mathbf{r}}{\partial \mathbf{b}} \right)^{-1} \frac{\partial \mathbf{r}}{\partial \mathbf{b}}^T$$

# %% [markdown]
# 4) Update the parameters using the following **update rule**:
#
# $$\mathbf{b} \leftarrow \mathbf{b} + \mathbf{\Delta\mathbf{b}}$$

# %% [markdown]
# 5) If not **converged**, go to 1.
#
# $$ \left\| \mathbf{b}_k - \mathbf{b}_{k-1} \right\|^2 < \text{tol} $$

# %% [markdown]
# Note that other algorithms have also been used to fit AAMs:
#
# - **Steepest Descent** algorithm (Amberg et al. 2009)
# - **Newton** algorithm (Kossaifi et al. 2014)
# - **Efficient Second Order Methods** (hopefully, my next paper if I ever finish it...)
#
# There derivations are slightly different but very related to the Gauss-Newton one. For more details on these algorithms I refer you to the previous papers.

# %% [markdown]
# Or... we can always try to quickly derive them on the whiteboard...

# %% [markdown]
# At this point we will concetrate on the previous Gauss-Newton algorithm and, in particular, look at two different techniques that one can use to compute the derivative of the residual with respect to the parameters.
#
# Note that, in principle, the derivative depends on the parameters and needs to be **recomputed** at each iteration of the Gauss-Newton algorithm and so does its pseudo-inverse:
#
# $$\mathbf{R}(\mathbf{b}) = \left( \frac{\partial \mathbf{r}(\mathbf{b})}{\partial \mathbf{b}}^T \frac{\partial \mathbf{r}(\mathbf{b})}{\partial \mathbf{b}} \right)^{-1} \frac{\partial \mathbf{r}(\mathbf{b})}{\partial \mathbf{b}}^T$$

# %% [markdown]
# - **Numerical approximation**:
#
# This is the approach proposed in the original paper AAM paper (Edwards et al. 1998).

# %% [markdown]
# Remember the definition of derivative from those glorious high school days...
#
# $$f^\prime(a) = \underset{h \rightarrow 0}{\lim} \frac{f(a+h) - f(a)}{h}$$
#
# which can be approximated by:
#
# $$m = \frac{\text{change in} \,\, f(x)}{\text{change in} \,\, x} = \frac{\Delta f(x)}{\Delta x}$$

# %% [markdown]
# So that is the basis for numerically approximating the derivative of the residual with respect to the parameters:
#
# $$\frac{\partial \mathbf{r}}{\partial \mathbf{b}_i} \approx \frac{1}{NN_p}\sum_{j=1}^N \sum_{k=1}^{N_p} \frac{\mathbf{r}_j(\tilde{\mathbf{b}}_i^k) - \mathbf{r}_j(\mathbf{b}_i^*)}{\tilde{\mathbf{b}}_i^k -\mathbf{b}_i^*} $$

# %% [markdown]
# This is a **linear** approximation to the derivative learned from training data by perturbing the residuals around the optimal values for the parameters.
#
# In the original paper the authors used the **combined-AAM** formulation which greatly reduces the total number of parameters for which the derivative needs to be estimated. However the same approximation could also be used for **independent-AAMs**.
#
# The biggest advantage of this approach is the fact that the derivative is only estimated once from training data and considered **fixed** throughout the optimization. Consequently, in this case, the derivative of the residual with respect to the parameters does not need to be re-estimated at each iteration of the Gauss-Newton algorithm and neither does its pseudo-inverse.

# %%
from __future__ import division
from menpofit.transform import (OrthoMDTransform, 
                                DifferentiablePiecewiseAffine, 
                                DifferentiableAlignmentSimilarity)

# choose shape parameter
param_ind = 0

# initialize residual derivative and counter
dr_db0 = 0
count = 0

for i in images:
    # build warp transform
    W = OrthoMDTransform(shape_model, DifferentiablePiecewiseAffine,
                         DifferentiableAlignmentSimilarity, 
                         source=reference_frame.landmarks['source'].lms)
    # extract image ground truth shape
    shape = i.landmarks['ibug_face_66'].lms
    # set warp tranform target to the previous shape
    W.set_target(shape)
    # save the otimal shape parameters for the ground truth shape
    b_star = W.as_vector()
    # warp image to the reference frame
    IWxp = i.warp_to_mask(reference_frame.mask, W)
    # compute residual
    r_star = IWxp.as_vector() - appearance_model.mean().as_vector()
    for delta in np.arange(-10, 10, 0.1):
        if delta != 0:
            # perturb shape parameter
            b_tilde = b_star.copy()
            b_tilde[param_ind] = b_tilde[param_ind] + delta
            # set transform to the pertubed position
            W.from_vector_inplace(b_tilde)
            # warp image to the reference frame using perturbed transform
            IWxp = i.warp_to_mask(reference_frame.mask, W)
            # compute perturbed residual
            r_tilde = IWxp.as_vector() - appearance_model.mean().as_vector()
            # add to approximation
            dr_db0 += (r_tilde - r_star) / delta
            count += 1

# normalize by the total number of iterations
dr_db0 = dr_db0 / count

# %%
reference_frame.from_vector(dr_db0).view()

# %% [markdown]
# - **Analytical derivation**:
#
# The analytical derivation is derived by applying the chain rule:
#
# $$ \frac{\partial\mathbf{r}}{\partial\mathbf{b}} = \left( \frac{\partial\mathbf{r}}{\partial\mathbf{c}}, \frac{\partial\mathbf{r}}{\partial\mathbf{p}} \right) $$

# %% [markdown]
# $$ \frac{\partial\mathbf{r}}{\partial\mathbf{c}} = \frac{\partial \left( \mathbf{i}[\mathbf{p}] -  \bar{\mathbf{a}} - \mathbf{A}\mathbf{c} \right)}{\partial\mathbf{c}} = \mathbf{A}$$
#
# Note that the derivative of the residual with respect to appearance parameters is **fixed**, i.e. it does not depend on the current shape or appearance parameters. In fact, it is equal to appearance model bases.

# %% [markdown]
# $$\frac{\partial\mathbf{r}}{\partial\mathbf{p}} = \frac{\partial \left( \mathbf{i}[\mathbf{p}] -  \bar{\mathbf{a}} - \mathbf{A}\mathbf{c} \right)}{\partial\mathbf{p}} = \nabla I(\mathcal{W}(\mathbf{x};\mathbf{p})) \frac{\partial \mathcal{W}}{\partial \mathbf{p}}$$
#
# On the contrary, the derivative of the residual with respect to shape parameters does depend on the current shape parameters and will have to be estimated at every iteration of the algorithm.

# %%
from menpo.feature import gradient

# reset warp tranform to img initial shape
W.set_target(initial_shape)

# warp image to reference frame
IWxp = img.warp_to_mask(reference_frame.mask, W)
# compute gradient of warped image
VI_image = gradient(IWxp)
VI_image.set_boundary_pixels()
# reshape gradient
VI = VI_image.as_vector().reshape((2, -1))

# %%
VI_image.view();

# %%
# compute derivative of the warp with respect to shape parameters
dW_dp = W.d_dp(reference_frame.mask.true_indices())
dW_dp = np.rollaxis(dW_dp, -1)

# make them menpo images for visualization
template = reference_frame.copy()
template.pixels = np.concatenate((template.pixels, template.pixels), axis=0)
dW_dp_image = [template.from_vector(dW_dp[:, :, p].flatten()) 
               for p in xrange(W.n_parameters)]

# %%
visualize_images(dW_dp_image)

# %%
# compute steepest descent images
sdi = 0
a = VI[..., None] * dW_dp
for d in a:
    sdi += d
# make them menpo images for visualization
sdi_image = [reference_frame.from_vector(sdi[:, p].flatten()) 
             for p in xrange(W.n_parameters)]

# %%
visualize_images(sdi_image)

# %% [markdown]
# Iain Matthews and Simon Baker were the first to make use of the analytical computation of the residual derivative. A very detailed explanation of all the terms involving the derivation of the derivative is given in their paper (Matthews and Baker, 2003).

# %% [markdown]
# The Gauss-Newton algorithm we just described is known as the **Simultaneous Forward Additive (SFA)** algorithm. It is just one algorithm of a whole family of Gauss-Newton algorithm for solving the AAM fitting problem using the analytical derivation of the residual derivative.
#
# Some algorithm of the same family are:

# %% [markdown]
# - **Project Out Inverse Compositional (PIC)** algorithm:
#
# This algorithm divides the original cost function in two different terms:
#
# - One that acts on the linear subspace spanned by the appearance bases.
# - One that acts on its **orthogonal complement**.

# %% [markdown]
# $$\left\| \mathbf{i}[\mathbf{p}] -  \bar{\mathbf{a}} - \mathbf{A}\mathbf{c} \right\|^2 =  \left\| \mathbf{i}[\mathbf{p}] -  \bar{\mathbf{a}} - \mathbf{A}\mathbf{c} \right\|^2_{\mathbf{A}^\perp} + \left\| \mathbf{i}[\mathbf{p}] -  \bar{\mathbf{a}} - \mathbf{A}\mathbf{c} \right\|^2_{\mathbf{A}} $$
#
# $$\left\| \mathbf{i}[\mathbf{p}] -  \bar{\mathbf{a}} - \mathbf{A}\mathbf{c} \right\|^2 =  \left\| \mathbf{i}[\mathbf{p}] -  \bar{\mathbf{a}} \right\|^2_{\mathbf{A}^\perp} + \left\| \mathbf{i}[\mathbf{p}] -  \bar{\mathbf{a}} - \mathbf{A}\mathbf{c} \right\|^2_{\mathbf{A}} $$

# %% [markdown]
# How can we compute the orthogonal complement to the appearance subspace?
#
# $$\mathbf{A}^\perp = \mathbf{I} - \mathbf{A}\mathbf{A}^T$$

# %% [markdown]
# A one dimensional example proving that the above is true:

# %%
from __future__ import division
import numpy as np
import matplotlib.pyplot as plt

a = np.array([1, 1])
a = a / np.sqrt(a.T.dot(a))

r = np.array([0.3, 0.7])

a_perp = np.eye(2) - a.dot(a.T)

r_proj = a.dot(a.T.dot(r))
r_perp = r - r_proj


soa =np.array( [ [0,0,3,2], [0,0,1,1],[0,0,9,9]]) 
X,Y,U,V = zip(*soa)
plt.figure()
ax = plt.gca()
ax.quiver([0, 0, 0, r_proj[0]], [0, 0, 0, r_proj[1]], 
          [a[0], r[0], r_proj[0], r_perp[0]],
          [a[1], r[1], r_proj[1], r_perp[1]], 
          angles='xy', scale_units='xy', scale=1,
          color=['k', 'r', 'g', 'b'])
ax.set_xlim([0, 1])
ax.set_ylim([0, 1])
ax.set_aspect('equal')

plt.show()

# %% [markdown]
# The optimal value for the shape parameters can be obtained by solving the following optimization problem:
#
# $$\mathbf{p}_o = \underset{\mathbf{p}}{\mathrm{arg\,min\;}} \, \frac{1}{2} \left\| \mathbf{i}[\mathbf{p}] -  \bar{\mathbf{a}} \right\|^2_{(\mathbf{I} -\mathbf{A}\mathbf{A}^T)}$$
#
# $$\mathbf{p}_o = \underset{\mathbf{p}}{\mathrm{arg\,min\;}} \, \frac{1}{2} \mathbf{r}^T(\mathbf{I} -\mathbf{A}\mathbf{A}^T)\mathbf{r}$$
#
# Note that working on the orthogonal complement of the appearance bases accounts for the **Project Out** in the algorithm's name.

# %% [markdown]
# The **Inverse** bit comes from the fact that the algorithm switches the roles of the image and the template by introducing an incremental warp onto the the model's part:
#
# $$\mathbf{p}_o = \underset{\mathbf{p}}{\mathrm{arg\,min\;}} \, \frac{1}{2} \left\| \mathbf{i}[\mathbf{p}] -  \bar{\mathbf{a}}[\Delta\mathbf{p}] \right\|^2_{(\mathbf{I} -\mathbf{A}\mathbf{A}^T)} $$
#
# Similarly as before, this new non-linear squares problem can be solve by using the Gauss-Newton algorithm.

# %% [markdown]
# In this case the, the first order Taylor expansion of the residual leads to:
#
# $$ \mathbf{r}(\mathbf{p} \circ \Delta \mathbf{p}^{-1}) \approx \mathbf{r}(\mathbf{p}) + \frac{\partial \mathbf{r}}{\partial \mathbf{p}} \Delta \mathbf{p} $$
#
# where:
#
# $$\frac{\partial\mathbf{r}}{\partial \mathbf{p}} = - \nabla \bar{A}(\mathbf{x}) \frac{\partial\mathcal{W}}{\partial\mathbf{p}} $$

# %% [markdown]
# Substituing back onto the cost function we arrive to very similar expression as before:
#
# $$\Delta \mathbf{p}_o = \underset{\Delta\mathbf{p}}{\mathrm{arg\,min\;}} \, \mathcal{f}(\Delta \mathbf{p}) = \underset{\Delta\mathbf{p}}{\mathrm{arg\,min\;}} \, \frac{1}{2} \left\| \mathbf{r}(\mathbf{p}) + \frac{\partial \mathbf{r}^T}{\partial \mathbf{p}} \Delta \mathbf{p} \right\|^2 $$

# %% [markdown]
# And the solution for the increments on the shape parameters is given by the now familiar expression:
#
# $$\Delta \mathbf{p}_o = \left(\frac{\partial\mathbf{r}}{\partial\mathbf{p}}^T \frac{\partial\mathbf{r}}{\partial\mathbf{p}}\right)^{-1} \frac{\partial\mathbf{r}}{\partial\mathbf{p}} \mathbf{r}(\mathbf{p}) $$
#
# $$\Delta \mathbf{p}_o = \mathbf{R} \mathbf{r}(\mathbf{p}) $$

# %% [markdown]
# Note that, as noted above, the previous increments on the shape parameters are placed on the model's side.
#
# This effectively means that the problem that we just solved was that of finding the shape parameters that best deform the **model** so that the difference between the warped image and the model was minimized.

# %% [markdown]
# Therefore, we cannot simply add these shape parameters increments to the current ones using and additive update rule.
#
# Instead, what we need to do is to **invert** the incremental warp and **compose** it to current warp. Giving rise to following updating rule:
#
# $$\mathcal{W}(\mathbf{x}; \mathbf{p}) \leftarrow \mathcal{W}(\mathbf{x}; \mathbf{p}) \circ \mathcal{W}(\mathbf{x}; \Delta \mathbf{p})^{-1}$$
#
# or slightly abusing the notation:
#
# $$\mathbf{p} \leftarrow \mathbf{p} \circ \Delta \mathbf{p}^{-1}$$
#
# And yes, as you have probably guessed by now, this accounts for the **Compositional** in the algorithm's name.

# %% [markdown]
# This algorithm has two main **advantages** with respect to the previous *SFA* algorithm we derived earlier:

# %% [markdown]
# - The appearance parameters have being completely **removed** from the optimization problem.

# %% [markdown]
# - The derivative of the residual with respect to the shape parameters is **constant** and, consequently, so is its pseudo-inverse which can now be completely **pre-computed**.

# %% [markdown]
# There are at least two other very well-known and widely used Gauss-Newton algorithms for fitting AAMs, i.e.:
#
# - **Alternating Inverse Compositional (AIC)** algorithm (Tzimiropoulos et al., 2012)
#
# - **Fast Simultaneous Inverse Compositional (Fast-SIC)** algorithm (Papandreou and Maragos, 2008)

# %% [markdown]
# There derivation is similar to that of the previous *SFA* and *PIC* algorithms but, unfortunately, I did not have enough time to prepare a full derivation of these algorithms.

# %% [markdown]
# We can still quickly do it on the whiteboard if you are interested... :-)

# %% [markdown]
# OK, **maths are over**!!!
#
# Let's see how each one of these algorithms perform!

# %% [markdown]
# We will start by loading some test images:

# %%
import menpo.io as mio
from menpo.landmark import labeller, ibug_face_66

test_images = []
for i  in mio.import_images('/Users/joan/PhD/DataBases/faces/lfpw/testset/', 
                            max_images=10, verbose=True):
    
    i.crop_to_landmarks_proportion_inplace(0.5)
    i = i.rescale_landmarks_to_diagonal_range(200)
    labeller(i, 'PTS', ibug_face_66)
    if i.n_channels == 3:
        i = i.as_greyscale(mode='luminosity')
    
    test_images.append(i)
# Out:
# - Loading 10 assets: [==                  ] 10%
# - Loading 10 assets: [====                ] 20%
# - Loading 10 assets: [======              ] 30%
# - Loading 10 assets: [========            ] 40%
# - Loading 10 assets: [==========          ] 50%
# - Loading 10 assets: [============        ] 60%
# - Loading 10 assets: [==============      ] 70%
# - Loading 10 assets: [================    ] 80%
# - Loading 10 assets: [==================  ] 90%
# - Loading 10 assets: [====================] 100%

# %% [markdown]
# Now let's load an AAM and fit it to the previous images using the following algorithms:
#
# - **Project Out Inverse Algorithm (PIC)**
# - **Alternating Inverse Algorithm (AIC)**
# - **Fast Simultaneous Inverse Algorithm (Fast-SIC)**.

# %%
# load a pre-trained AAM
aam = pickle_load('/Users/joan/PhD/Models/gaam_int.menpo')

# %%
from alabortijcv2015.aam import StandardAAMFitter
from alabortijcv2015.aam.algorithm import PIC, AIC, SIC 

# build aam fitter with PIC algorithm
pic_fitter = StandardAAMFitter(aam, algorithm_cls=PIC, n_shape=10, n_appearance=100)
# build aam fitter with AIC algorithm
aic_fitter = StandardAAMFitter(aam, algorithm_cls=AIC, n_shape=10, n_appearance=100)
# build aam fitter with Fast-SIC algorithm
sic_fitter = StandardAAMFitter(aam, algorithm_cls=SIC, n_shape=10, n_appearance=100)

# %%
# intialize list of fitter results
pic_fitter_results = []
aic_fitter_results = []
sic_fitter_results = []

np.random.seed(1)

for j, i in enumerate(test_images):  
    # get the ground truth landmark for the test image
    gt_s = i.landmarks['PTS'].lms
    # noisy align the model's mean shape to them
    s = pic_fitter.perturb_shape(gt_s, noise_std=0.02)
    
    # fit with PIC
    pic_fr = pic_fitter.fit(i, s, gt_shape=gt_s, max_iters=20)
    # fit with AIC
    aic_fr = aic_fitter.fit(i, s, gt_shape=gt_s, max_iters=20)
    # fit with Fast-SIC
    sic_fr = sic_fitter.fit(i, s, gt_shape=gt_s, max_iters=20)
    
    # this nonsense is due to a bug in my code!!!
    pic_fr.downscale = 0.5
    aic_fr.downscale = 0.5
    sic_fr.downscale = 0.5
    
    # add fitter results to their respective list
    pic_fitter_results.append(pic_fr)
    aic_fitter_results.append(aic_fr)
    sic_fitter_results.append(sic_fr)
    
    # print the error per fitting
    print 'Image: ', j
    print 'PIC:' 
    print pic_fr
    print 'AIC'
    print aic_fr
    print 'SIC'
    print sic_fr
# Out:
# r:  14.7089146823
# r2: 14.7089146823
# r:  11.2312656382
# r2: 10.220863344
# r:  9.5326638653
# r2: 9.02562679546
# r:  8.50010023943
# r2: 8.39594953911
# r:  8.1455541896
# r2: 8.08546574437
# r:  7.80034949531
# r2: 7.77378605246
# r:  7.75241871584
# r2: 7.73376783989
# r:  7.59530946428
# r2: 7.57025832632
# r:  7.70245918683
# r2: 7.67476566871
# r:  7.55808984132
# r2: 7.52154384674
# r:  7.71283706703
# r2: 7.6700088101
# r:  7.56177528217
# r2: 7.50703761227
# r:
#  7.74511162816
# r2: 7.68228572265
# r:  7.58397396513
# r2: 7.50641427132
# r:  7.78590166222
# r2: 7.69924481824
# r:  7.61477891353
# r2: 7.51238544504
# r:  7.82621479745
# r2: 7.71533272499
# r:  7.64884906223
# r2: 7.52340701207
# r:  7.86024666162
# r2: 7.72841226107
# r:  7.6784057382
# r2: 7.53548139627
# r:  7.88622133534
# r2: 7.73874816971
# Image:  0
# PIC:
# Initial error: 0.0424
# Final error: 0.0381
# AIC
# Initial error: 0.0424
# Final error: 0.0249
# SIC
# Initial error: 0.0424
# Final error: 0.0256
# r:
#  26.4573255018
# r2: 26.4573255018
# r:  22.1235900923
# r2: 20.1465422877
# r:  16.5718934342
# r2: 15.8954964896
# r:  11.0128640014
# r2: 9.91092995935
# r:  8.43422258942
# r2: 7.5617926524
# r:  7.19560200547
# r2: 6.87794470699
# r:  6.70779805077
# r2: 6.36510301793
# r:  6.2182398145
# r2: 6.12683341304
# r:  6.12092373108
# r2: 6.07616197339
# r:  6.091902204
# r2: 6.07574105068
# r:  6.08781831648
# r2: 6.07792600127
# r:  6.09668780404
# r2: 6.0894469708
# r:  6.09660183015
# r2: 6.09153610383
# r:
#  6.09693856713
# r2: 6.09368889163
# r:  6.09782749996
# r2: 6.09568987275
# r:  6.09734166347
# r2: 6.09573460139
# r:  6.0978558011
# r2: 6.09662545223
# r:  6.09686647631
# r2: 6.09588933565
# r:  6.09636414598
# r2: 6.09551401738
# r:  6.09750338399
# r2: 6.09674459273
# r:  6.0979055175
# r2: 6.09720424681
# Image:  1
# PIC:
# Initial error: 0.0720
# Final error: 0.0284
# AIC
# Initial error: 0.0720
# Final error: 0.0212
# SIC
# Initial error: 0.0720
# Final error: 0.0226
# r:
#  21.2893239845
# r2: 21.2893239845
# r:  13.9351834508
# r2: 12.339831473
# r:  10.5600938145
# r2: 9.97900291996
# r:  9.82342740056
# r2: 9.77428297657
# r:  9.75353629719
# r2: 9.72442885244
# r:  9.76023738969
# r2: 9.75049564801
# r:  9.81072392414
# r2: 9.80427725055
# r:  9.87377101518
# r2: 9.87024747322
# r:  9.9745284438
# r2: 9.97250328508
# r:  10.0859127927
# r2: 10.0846274981
# r:  10.1749047143
# r2: 10.1738775212
# r:  10.2219029684
# r2: 10.2210111077
# r:  10.2392564154
# r2: 10.2384866433
# r:  10.2388968232
# r2: 10.2382501107
# r:
#  10.2267885416
# r2: 10.2262643765
# r:  10.2142872588
# r2: 10.213941716
# r:  10.20517315
# r2: 10.204972542
# r:  10.196189229
# r2: 10.1960776398
# r:  10.1895121829
# r2: 10.1894497182
# r:  10.1842464242
# r2: 10.1842121088
# r:  10.1799267119
# r2: 10.1799079187
# Image:  2
# PIC:
# Initial error: 0.0550
# Final error: 0.0786
# AIC
# Initial error: 0.0550
# Final error: 0.0440
# SIC
# Initial error: 0.0550
# Final error: 0.0447
# r:
#  107.734041532
# r2: 107.734041532
# r:  81.3230013876
# r2: 60.0913043261
# r:  45.0437712469
# r2: 39.4659373461
# r:  38.1733444586
# r2: 37.2489528075
# r:  39.4802205274
# r2: 38.6869323399
# r:  41.3679603147
# r2: 40.6493913886
# r:  41.6477318167
# r2: 41.3868064144
# r:  41.6971914447
# r2: 41.6793166987
# r:  41.5920744297
# r2: 41.5778253957
# r:  41.6388097151
# r2: 41.6286283001
# r:  41.5933127179
# r2: 41.5860479295
# r:  41.5714727923
# r2: 41.5683874372
# r:  41.5255817397
# r2: 41.5235653671
# r:
#  41.4948958243
# r2: 41.4933874186
# r:  41.4263041456
# r2: 41.4250976963
# r:  41.3676250024
# r2: 41.3667943008
# r:  41.3047495736
# r2: 41.3041205585
# r:  41.2574782286
# r2: 41.2571320108
# r:  41.2117917208
# r2: 41.2115619522
# r:  41.1728965242
# r2: 41.1727482695
# r:  41.1429430633
# r2: 41.1428563695
# Image:  3
# PIC:
# Initial error: 0.0508
# Final error: 0.0607
# AIC
# Initial error: 0.0508
# Final error: 0.0326
# SIC
# Initial error: 0.0508
# Final error: 0.0324
# r:
#  67.5025173965
# r2: 67.5025173965
# r:  50.2529758157
# r2: 42.3199056239
# r:  35.8585544581
# r2: 34.7341886534
# r:  32.2442003989
# r2: 31.7865743501
# r:  26.3420256687
# r2: 25.7141170674
# r:  21.7334083618
# r2: 21.4437034131
# r:  19.4637597306
# r2: 19.3155657865
# r:  17.7648860199
# r2: 17.6883458577
# r:  16.6282585456
# r2: 16.5854456183
# r:  15.6698403279
# r2: 15.6451810311
# r:  15.0043414089
# r2: 14.9901493247
# r:  14.5444362975
# r2: 14.5358271548
# r:
#  14.4018552243
# r2: 14.3962990047
# r:  14.402585131
# r2: 14.398549891
# r:  14.5128123851
# r2: 14.5096062681
# r:  14.6574820039
# r2: 14.6541667607
# r:  14.6676874274
# r2: 14.6654756946
# r:  14.6673021394
# r2: 14.6657490676
# r:  14.6476243697
# r2: 14.6461675986
# r:  14.6186919146
# r2: 14.6174206204
# r:  14.605097121
# r2: 14.6040322503
# Image:  4
# PIC:
# Initial error: 0.0703
# Final error: 0.1334
# AIC
# Initial error: 0.0703
# Final error: 0.0647
# SIC
# Initial error: 0.0703
# Final error: 0.0320
# r:
#  66.4782615349
# r2: 66.4782615349
# r:  53.4744975508
# r2: 48.4430819415
# r:  51.5722799374
# r2: 44.549669872
# r:  41.3024937759
# r2: 40.7796592808
# r:  37.2980707493
# r2: 36.6159348345
# r:  33.7040336065
# r2: 33.4891429471
# r:  32.9893487985
# r2: 32.8084399549
# r:  32.5692351883
# r2: 32.4953781864
# r:  32.6283403593
# r2: 32.5745877404
# r:  32.6974908342
# r2: 32.6627792153
# r:  32.8132063291
# r2: 32.787236452
# r:  32.962877671
# r2: 32.944534177
# r:
#  33.1686677476
# r2: 33.1543198747
# r:  33.3647348858
# r2: 33.3534419638
# r:  33.5066833032
# r2: 33.497226171
# r:  33.5990175193
# r2: 33.591322904
# r:  33.6594072057
# r2: 33.6530069096
# r:  33.6981906379
# r2: 33.6930397985
# r:  33.739449714
# r2: 33.7353330824
# r:  33.7813257846
# r2: 33.7776570366
# r:  33.8110902882
# r2: 33.8075119104
# Image:  5
# PIC:
# Initial error: 0.0506
# Final error: 0.0636
# AIC
# Initial error: 0.0506
# Final error: 0.0454
# SIC
# Initial error: 0.0506
# Final error: 0.0375
# r:
#  39.2049147691
# r2: 39.2049147691
# r:  24.5056907488
# r2: 19.1088190159
# r:  17.4180897486
# r2: 14.6632338523
# r:  15.2562036996
# r2: 14.604987925
# r:  14.5982292536
# r2: 14.5564576687
# r:  14.5263606863
# r2: 14.5094637604
# r:  14.4802580863
# r2: 14.4719098591
# r:  14.4587116226
# r2: 14.4518676525
# r:  14.4575726442
# r2: 14.4536551147
# r:  14.4582825932
# r2: 14.454828081
# r:  14.462321987
# r2: 14.4599654299
# r:  14.4614495249
# r2: 14.4594097135
# r:  14.46298287
# r2: 14.4615634525
# r:
#  14.4636812341
# r2: 14.4625908971
# r:  14.4658508137
# r2: 14.4651058133
# r:  14.4671087084
# r2: 14.4665519177
# r:  14.4685017715
# r2: 14.4681197028
# r:  14.4695232982
# r2: 14.4692422158
# r:  14.4705067572
# r2: 14.4703113617
# r:  14.4712740759
# r2: 14.4711320311
# r:  14.4720582952
# r2: 14.4719607071
# Image:  6
# PIC:
# Initial error: 0.0561
# Final error: 0.2106
# AIC
# Initial error: 0.0561
# Final error: 0.0305
# SIC
# Initial error: 0.0561
# Final error: 0.0353
# r:
#  21.4526107381
# r2: 21.4526107381
# r:  18.311232515
# r2: 15.5829167787
# r:  13.7446812997
# r2: 12.9647123122
# r:  11.8555739122
# r2: 11.6549279654
# r:  11.055729119
# r2: 10.866760181
# r:  10.3845049906
# r2: 10.2291045879
# r:  10.1155269905
# r2: 9.99782479048
# r:  9.74314453234
# r2: 9.65349180393
# r:  9.41103869056
# r2: 9.28969711917
# r:  9.17971065271
# r2: 9.07491209424
# r:  9.15445674347
# r2: 9.07950939065
# r:  9.27419793048
# r2: 9.21907544728
# r:  9.39925851236
# r2: 9.37003887588
# r:
#  9.44360192293
# r2: 9.43673833901
# r:  9.49209535418
# r2: 9.49046713282
# r:  9.51208630999
# r2: 9.51120252112
# r:  9.54247662384
# r2: 9.54211950317
# r:  9.54779306599
# r2: 9.54750832428
# r:  9.56540515327
# r2: 9.56524332852
# r:  9.56801030549
# r2: 9.56787906771
# r:  9.57955214029
# r2: 9.57947180734
# Image:  7
# PIC:
# Initial error: 0.0853
# Final error: 0.0720
# AIC
# Initial error: 0.0853
# Final error: 0.0389
# SIC
# Initial error: 0.0853
# Final error: 0.0423
# r:
#  19.7580127041
# r2: 19.7580127041
# r:  15.9684670338
# r2: 14.7867508322
# r:  8.68463695234
# r2: 5.07065946617
# r:  4.29509042526
# r2: 3.8582709472
# r:  4.03789107212
# r2: 3.89146963674
# r:  3.95272171444
# r2: 3.84443521238
# r:  3.892502943
# r2: 3.82091174064
# r:  3.92613992841
# r2: 3.83092444151
# r:  3.88616516083
# r2: 3.8128949906
# r:  3.94817601401
# r2: 3.85457303917
# r:  3.88923564157
# r2: 3.81170410095
# r:  3.97410626364
# r2: 3.87807849282
# r:
#  3.89380925391
# r2: 3.81144947821
# r:  3.98904175489
# r2: 3.88842996347
# r:  3.89860719446
# r2: 3.81197749297
# r:  3.99798089047
# r2: 3.89327889086
# r:  3.90253669632
# r2: 3.81272552175
# r:  4.00382638767
# r2: 3.89599683167
# r:  3.90554895095
# r2: 3.8134994519
# r:  4.00782267839
# r2: 3.89775045942
# r:  3.90773942077
# r2: 3.81414548839
# Image:  8
# PIC:
# Initial error: 0.0657
# Final error: 0.0448
# AIC
# Initial error: 0.0657
# Final error: 0.0301
# SIC
# Initial error: 0.0657
# Final error: 0.0308
# r:
#  19.989279509
# r2: 19.989279509
# r:  22.4428233743
# r2: 21.261843264
# r:  20.4476678989
# r2: 19.5077435967
# r:  20.7041956441
# r2: 20.267787631
# r:  20.5108095749
# r2: 20.2891283678
# r:  19.7089151384
# r2: 19.5961296693
# r:  19.1046344198
# r2: 19.0386040513
# r:  18.0695864696
# r2: 18.017863593
# r:  17.4829582711
# r2: 17.4529082382
# r:  17.186080954
# r2: 17.1671871304
# r:  17.0279600439
# r2: 17.0120061784
# r:  16.854314924
# r2: 16.8397647997
# r:  16.6828985289
# r2: 16.6691710901
# r:
#  16.5396680004
# r2: 16.5269038571
# r:  16.4283998044
# r2: 16.4170506641
# r:  16.3756394849
# r2: 16.3663402384
# r:  16.3564473517
# r2: 16.3487742145
# r:  16.3711535934
# r2: 16.3657873805
# r:  16.4060758492
# r2: 16.4025954601
# r:  16.447873196
# r2: 16.4457687163
# r:  16.4953402465
# r2: 16.4940082573
# Image:  9
# PIC:
# Initial error: 0.0341
# Final error: 0.0274
# AIC
# Initial error: 0.0341
# Final error: 0.0537
# SIC
# Initial error: 0.0341
# Final error: 0.0513

# %% [markdown]
# We can also check the results visually:

# %%
from menpofit.visualize import visualize_fitting_results

visualize_fitting_results(pic_fitter_results)

# %%
from menpofit.visualize import visualize_fitting_results

visualize_fitting_results(aic_fitter_results)

# %%
from menpofit.visualize import visualize_fitting_results

visualize_fitting_results(sic_fitter_results)

# %% [markdown]
# Finally, let us also quickly compare the speed of each algorithm:

# %%
# %timeit pic_fitter.fit(i, s, gt_shape=gt_s, max_iters=20)
# Out:
# 10 loops, best of 3: 36.8 ms per loop

# %%
# %timeit aic_fitter.fit(i, s, gt_shape=gt_s, max_iters=20)
# Out:
# 10 loops, best of 3: 59.7 ms per loop

# %%
# %timeit sic_fitter.fit(i, s, gt_shape=gt_s, max_iters=20)
# Out:
# r:  19.989279509
# r2: 19.989279509
# r:  22.4428233743
# r2: 21.261843264
# r:  20.4476678989
# r2: 19.5077435967
# r:  20.7041956441
# r2: 20.267787631
# r:  20.5108095749
# r2: 20.2891283678
# r:  19.7089151384
# r2: 19.5961296693
# r:  19.1046344198
# r2: 19.0386040513
# r:  18.0695864696
# r2: 18.017863593
# r:  17.4829582711
# r2: 17.4529082382
# r:  17.186080954
# r2: 17.1671871304
# r:  17.0279600439
# r2: 17.0120061784
# r:  16.854314924
# r2: 16.8397647997
# r:  16.6828985289
# r2: 16.6691710901
# r:
#  16.5396680004
# r2: 16.5269038571
# r:  16.4283998044
# r2: 16.4170506641
# r:  16.3756394849
# r2: 16.3663402384
# r:  16.3564473517
# r2: 16.3487742145
# r:  16.3711535934
# r2: 16.3657873805
# r:  16.4060758492
# r2: 16.4025954601
# r:  16.447873196
# r2: 16.4457687163
# r:  16.4953402465
# r2: 16.4940082573
# r:  19.989279509
# r2: 19.989279509
# r:  22.4428233743
# r2: 21.261843264
# r:  20.4476678989
# r2: 19.5077435967
# r:
#  20.7041956441
# r2: 20.267787631
# r:  20.5108095749
# r2: 20.2891283678
# r:  19.7089151384
# r2: 19.5961296693
# r:  19.1046344198
# r2: 19.0386040513
# r:  18.0695864696
# r2: 18.017863593
# r:  17.4829582711
# r2: 17.4529082382
# r:  17.186080954
# r2: 17.1671871304
# r:  17.0279600439
# r2: 17.0120061784
# r:  16.854314924
# r2: 16.8397647997
# r:  16.6828985289
# r2: 16.6691710901
# r:  16.5396680004
# r2: 16.5269038571
# r:  16.4283998044
# r2: 16.4170506641
# r:  16.3756394849
# r2: 16.3663402384
# r:
#  16.3564473517
# r2: 16.3487742145
# r:  16.3711535934
# r2: 16.3657873805
# r:  16.4060758492
# r2: 16.4025954601
# r:  16.447873196
# r2: 16.4457687163
# r:  16.4953402465
# r2: 16.4940082573
# r:  19.989279509
# r2: 19.989279509
# r:  22.4428233743
# r2: 21.261843264
# r:  20.4476678989
# r2: 19.5077435967
# r:  20.7041956441
# r2: 20.267787631
# r:  20.5108095749
# r2: 20.2891283678
# r:  19.7089151384
# r2: 19.5961296693
# r:  19.1046344198
# r2: 19.0386040513
# r:
#  18.0695864696
# r2: 18.017863593
# r:  17.4829582711
# r2: 17.4529082382
# r:  17.186080954
# r2: 17.1671871304
# r:  17.0279600439
# r2: 17.0120061784
# r:  16.854314924
# r2: 16.8397647997
# r:  16.6828985289
# r2: 16.6691710901
# r:  16.5396680004
# r2: 16.5269038571
# r:  16.4283998044
# r2: 16.4170506641
# r:  16.3756394849
# r2: 16.3663402384
# r:  16.3564473517
# r2: 16.3487742145
# r:  16.3711535934
# r2: 16.3657873805
# r:  16.4060758492
# r2: 16.4025954601
# r:  16.447873196
# r2: 16.4457687163
# r:
#  16.4953402465
# r2: 16.4940082573
# r:  19.989279509
# r2: 19.989279509
# r:  22.4428233743
# r2: 21.261843264
# r:  20.4476678989
# r2: 19.5077435967
# r:  20.7041956441
# r2: 20.267787631
# r:  20.5108095749
# r2: 20.2891283678
# r:  19.7089151384
# r2: 19.5961296693
# r:  19.1046344198
# r2: 19.0386040513
# r:  18.0695864696
# r2: 18.017863593
# r:  17.4829582711
# r2: 17.4529082382
# r:  17.186080954
# r2: 17.1671871304
# r:  17.0279600439
# r2: 17.0120061784
# r:
#  16.854314924
# r2: 16.8397647997
# r:  16.6828985289
# r2: 16.6691710901
# r:  16.5396680004
# r2: 16.5269038571
# r:  16.4283998044
# r2: 16.4170506641
# r:  16.3756394849
# r2: 16.3663402384
# r:  16.3564473517
# r2: 16.3487742145
# r:  16.3711535934
# r2: 16.3657873805
# r:  16.4060758492
# r2: 16.4025954601
# r:  16.447873196
# r2: 16.4457687163
# r:  16.4953402465
# r2: 16.4940082573
# r:  19.989279509
# r2: 19.989279509
# r:  22.4428233743
# r2: 21.261843264
# r:
#  20.4476678989
# r2: 19.5077435967
# r:  20.7041956441
# r2: 20.267787631
# r:  20.5108095749
# r2: 20.2891283678
# r:  19.7089151384
# r2: 19.5961296693
# r:  19.1046344198
# r2: 19.0386040513
# r:  18.0695864696
# r2: 18.017863593
# r:  17.4829582711
# r2: 17.4529082382
# r:  17.186080954
# r2: 17.1671871304
# r:  17.0279600439
# r2: 17.0120061784
# r:  16.854314924
# r2: 16.8397647997
# r:  16.6828985289
# r2: 16.6691710901
# r:  16.5396680004
# r2: 16.5269038571
# r:  16.4283998044
# r2: 16.4170506641
# r:
#  16.3756394849
# r2: 16.3663402384
# r:  16.3564473517
# r2: 16.3487742145
# r:  16.3711535934
# r2: 16.3657873805
# r:  16.4060758492
# r2: 16.4025954601
# r:  16.447873196
# r2: 16.4457687163
# r:  16.4953402465
# r2: 16.4940082573
# r:  19.989279509
# r2: 19.989279509
# r:  22.4428233743
# r2: 21.261843264
# r:  20.4476678989
# r2: 19.5077435967
# r:  20.7041956441
# r2: 20.267787631
# r:  20.5108095749
# r2: 20.2891283678
# r:  19.7089151384
# r2: 19.5961296693
# r:
#  19.1046344198
# r2: 19.0386040513
# r:  18.0695864696
# r2: 18.017863593
# r:  17.4829582711
# r2: 17.4529082382
# r:  17.186080954
# r2: 17.1671871304
# r:  17.0279600439
# r2: 17.0120061784
# r:  16.854314924
# r2: 16.8397647997
# r:  16.6828985289
# r2: 16.6691710901
# r:  16.5396680004
# r2: 16.5269038571
# r:  16.4283998044
# r2: 16.4170506641
# r:  16.3756394849
# r2: 16.3663402384
# r:  16.3564473517
# r2: 16.3487742145
# r:  16.3711535934
# r2: 16.3657873805
# r:  16.4060758492
# r2: 16.4025954601
# r:
#  16.447873196
# r2: 16.4457687163
# r:  16.4953402465
# r2: 16.4940082573
# r:  19.989279509
# r2: 19.989279509
# r:  22.4428233743
# r2: 21.261843264
# r:  20.4476678989
# r2: 19.5077435967
# r:  20.7041956441
# r2: 20.267787631
# r:  20.5108095749
# r2: 20.2891283678
# r:  19.7089151384
# r2: 19.5961296693
# r:  19.1046344198
# r2: 19.0386040513
# r:  18.0695864696
# r2: 18.017863593
# r:  17.4829582711
# r2: 17.4529082382
# r:  17.186080954
# r2: 17.1671871304
# r:  17.0279600439
# r2: 17.0120061784
# r:
#  16.854314924
# r2: 16.8397647997
# r:  16.6828985289
# r2: 16.6691710901
# r:  16.5396680004
# r2: 16.5269038571
# r:  16.4283998044
# r2: 16.4170506641
# r:  16.3756394849
# r2: 16.3663402384
# r:  16.3564473517
# r2: 16.3487742145
# r:  16.3711535934
# r2: 16.3657873805
# r:  16.4060758492
# r2: 16.4025954601
# r:  16.447873196
# r2: 16.4457687163
# r:  16.4953402465
# r2: 16.4940082573
# r:  19.989279509
# r2: 19.989279509
# r:  22.4428233743
# r2: 21.261843264
# r:  20.4476678989
# r2: 19.5077435967
# r:
#  20.7041956441
# r2: 20.267787631
# r:  20.5108095749
# r2: 20.2891283678
# r:  19.7089151384
# r2: 19.5961296693
# r:  19.1046344198
# r2: 19.0386040513
# r:  18.0695864696
# r2: 18.017863593
# r:  17.4829582711
# r2: 17.4529082382
# r:  17.186080954
# r2: 17.1671871304
# r:  17.0279600439
# r2: 17.0120061784
# r:  16.854314924
# r2: 16.8397647997
# r:  16.6828985289
# r2: 16.6691710901
# r:  16.5396680004
# r2: 16.5269038571
# r:  16.4283998044
# r2: 16.4170506641
# r:  16.3756394849
# r2: 16.3663402384
# r:
#  16.3564473517
# r2: 16.3487742145
# r:  16.3711535934
# r2: 16.3657873805
# r:  16.4060758492
# r2: 16.4025954601
# r:  16.447873196
# r2: 16.4457687163
# r:  16.4953402465
# r2: 16.4940082573
# r:  19.989279509
# r2: 19.989279509
# r:  22.4428233743
# r2: 21.261843264
# r:  20.4476678989
# r2: 19.5077435967
# r:  20.7041956441
# r2: 20.267787631
# r:  20.5108095749
# r2: 20.2891283678
# r:  19.7089151384
# r2: 19.5961296693
# r:  19.1046344198
# r2: 19.0386040513
# r:
# 18.0695864696
# r2: 18.017863593
# r:  17.4829582711
# r2: 17.4529082382
# r:  17.186080954
# r2: 17.1671871304
# r:  17.0279600439
# r2: 17.0120061784
# r:  16.854314924
# r2: 16.8397647997
# r:  16.6828985289
# r2: 16.6691710901
# r:  16.5396680004
# r2: 16.5269038571
# r:  16.4283998044
# r2: 16.4170506641
# r:  16.3756394849
# r2: 16.3663402384
# r:  16.3564473517
# r2: 16.3487742145
# r:  16.3711535934
# r2: 16.3657873805
# r:  16.4060758492
# r2: 16.4025954601
# r:  16.447873196
# r2: 16.4457687163
# r:
#  16.4953402465
# r2: 16.4940082573
# r:  19.989279509
# r2: 19.989279509
# r:  22.4428233743
# r2: 21.261843264
# r:  20.4476678989
# r2: 19.5077435967
# r:  20.7041956441
# r2: 20.267787631
# r:  20.5108095749
# r2: 20.2891283678
# r:  19.7089151384
# r2: 19.5961296693
# r:  19.1046344198
# r2: 19.0386040513
# r:  18.0695864696
# r2: 18.017863593
# r:  17.4829582711
# r2: 17.4529082382
# r:  17.186080954
# r2: 17.1671871304
# r:  17.0279600439
# r2: 17.0120061784
# r:  16.854314924
# r2: 16.8397647997
# r:
#  16.6828985289
# r2: 16.6691710901
# r:  16.5396680004
# r2: 16.5269038571
# r:  16.4283998044
# r2: 16.4170506641
# r:  16.3756394849
# r2: 16.3663402384
# r:  16.3564473517
# r2: 16.3487742145
# r:  16.3711535934
# r2: 16.3657873805
# r:  16.4060758492
# r2: 16.4025954601
# r:  16.447873196
# r2: 16.4457687163
# r:  16.4953402465
# r2: 16.4940082573
# r:  19.989279509
# r2: 19.989279509
# r:  22.4428233743
# r2: 21.261843264
# r:  20.4476678989
# r2: 19.5077435967
# r:  20.7041956441
# r2: 20.267787631
# r:
#  20.5108095749
# r2: 20.2891283678
# r:  19.7089151384
# r2: 19.5961296693
# r:  19.1046344198
# r2: 19.0386040513
# r:  18.0695864696
# r2: 18.017863593
# r:  17.4829582711
# r2: 17.4529082382
# r:  17.186080954
# r2: 17.1671871304
# r:  17.0279600439
# r2: 17.0120061784
# r:  16.854314924
# r2: 16.8397647997
# r:  16.6828985289
# r2: 16.6691710901
# r:  16.5396680004
# r2: 16.5269038571
# r:  16.4283998044
# r2: 16.4170506641
# r:  16.3756394849
# r2: 16.3663402384
# r:
#  16.3564473517
# r2: 16.3487742145
# r:  16.3711535934
# r2: 16.3657873805
# r:  16.4060758492
# r2: 16.4025954601
# r:  16.447873196
# r2: 16.4457687163
# r:  16.4953402465
# r2: 16.4940082573
# r:  19.989279509
# r2: 19.989279509
# r:  22.4428233743
# r2: 21.261843264
# r:  20.4476678989
# r2: 19.5077435967
# r:  20.7041956441
# r2: 20.267787631
# r:  20.5108095749
# r2: 20.2891283678
# r:  19.7089151384
# r2: 19.5961296693
# r:  19.1046344198
# r2: 19.0386040513
# r:
#  18.0695864696
# r2: 18.017863593
# r:  17.4829582711
# r2: 17.4529082382
# r:  17.186080954
# r2: 17.1671871304
# r:  17.0279600439
# r2: 17.0120061784
# r:  16.854314924
# r2: 16.8397647997
# r:  16.6828985289
# r2: 16.6691710901
# r:  16.5396680004
# r2: 16.5269038571
# r:  16.4283998044
# r2: 16.4170506641
# r:  16.3756394849
# r2: 16.3663402384
# r:  16.3564473517
# r2: 16.3487742145
# r:  16.3711535934
# r2: 16.3657873805
# r:  16.4060758492
# r2: 16.4025954601
# r:
#  16.447873196
# r2: 16.4457687163
# r:  16.4953402465
# r2: 16.4940082573
# r:  19.989279509
# r2: 19.989279509
# r:  22.4428233743
# r2: 21.261843264
# r:  20.4476678989
# r2: 19.5077435967
# r:  20.7041956441
# r2: 20.267787631
# r:  20.5108095749
# r2: 20.2891283678
# r:  19.7089151384
# r2: 19.5961296693
# r:  19.1046344198
# r2: 19.0386040513
# r:  18.0695864696
# r2: 18.017863593
# r:  17.4829582711
# r2: 17.4529082382
# r:  17.186080954
# r2: 17.1671871304
# r:
#  17.0279600439
# r2: 17.0120061784
# r:  16.854314924
# r2: 16.8397647997
# r:  16.6828985289
# r2: 16.6691710901
# r:  16.5396680004
# r2: 16.5269038571
# r:  16.4283998044
# r2: 16.4170506641
# r:  16.3756394849
# r2: 16.3663402384
# r:  16.3564473517
# r2: 16.3487742145
# r:  16.3711535934
# r2: 16.3657873805
# r:  16.4060758492
# r2: 16.4025954601
# r:  16.447873196
# r2: 16.4457687163
# r:  16.4953402465
# r2: 16.4940082573
# r:  19.989279509
# r2: 19.989279509
# r:
#  22.4428233743
# r2: 21.261843264
# r:  20.4476678989
# r2: 19.5077435967
# r:  20.7041956441
# r2: 20.267787631
# r:  20.5108095749
# r2: 20.2891283678
# r:  19.7089151384
# r2: 19.5961296693
# r:  19.1046344198
# r2: 19.0386040513
# r:  18.0695864696
# r2: 18.017863593
# r:  17.4829582711
# r2: 17.4529082382
# r:  17.186080954
# r2: 17.1671871304
# r:  17.0279600439
# r2: 17.0120061784
# r:  16.854314924
# r2: 16.8397647997
# r:  16.6828985289
# r2: 16.6691710901
# r:  16.5396680004
# r2: 16.5269038571
# r:
#  16.4283998044
# r2: 16.4170506641
# r:  16.3756394849
# r2: 16.3663402384
# r:  16.3564473517
# r2: 16.3487742145
# r:  16.3711535934
# r2: 16.3657873805
# r:  16.4060758492
# r2: 16.4025954601
# r:  16.447873196
# r2: 16.4457687163
# r:  16.4953402465
# r2: 16.4940082573
# r:  19.989279509
# r2: 19.989279509
# r:  22.4428233743
# r2: 21.261843264
# r:  20.4476678989
# r2: 19.5077435967
# r:  20.7041956441
# r2: 20.267787631
# r:  20.5108095749
# r2: 20.2891283678
# r:
#  19.7089151384
# r2: 19.5961296693
# r:  19.1046344198
# r2: 19.0386040513
# r:  18.0695864696
# r2: 18.017863593
# r:  17.4829582711
# r2: 17.4529082382
# r:  17.186080954
# r2: 17.1671871304
# r:  17.0279600439
# r2: 17.0120061784
# r:  16.854314924
# r2: 16.8397647997
# r:  16.6828985289
# r2: 16.6691710901
# r:  16.5396680004
# r2: 16.5269038571
# r:  16.4283998044
# r2: 16.4170506641
# r:  16.3756394849
# r2: 16.3663402384
# r:  16.3564473517
# r2: 16.3487742145
# r:  16.3711535934
# r2: 16.3657873805
# r:
#  16.4060758492
# r2: 16.4025954601
# r:  16.447873196
# r2: 16.4457687163
# r:  16.4953402465
# r2: 16.4940082573
# r:  19.989279509
# r2: 19.989279509
# r:  22.4428233743
# r2: 21.261843264
# r:  20.4476678989
# r2: 19.5077435967
# r:  20.7041956441
# r2: 20.267787631
# r:  20.5108095749
# r2: 20.2891283678
# r:  19.7089151384
# r2: 19.5961296693
# r:  19.1046344198
# r2: 19.0386040513
# r:  18.0695864696
# r2: 18.017863593
# r:  17.4829582711
# r2: 17.4529082382
# r:  17.186080954
# r2: 17.1671871304
# r:
#  17.0279600439
# r2: 17.0120061784
# r:  16.854314924
# r2: 16.8397647997
# r:  16.6828985289
# r2: 16.6691710901
# r:  16.5396680004
# r2: 16.5269038571
# r:  16.4283998044
# r2: 16.4170506641
# r:  16.3756394849
# r2: 16.3663402384
# r:  16.3564473517
# r2: 16.3487742145
# r:  16.3711535934
# r2: 16.3657873805
# r:  16.4060758492
# r2: 16.4025954601
# r:  16.447873196
# r2: 16.4457687163
# r:  16.4953402465
# r2: 16.4940082573
# r:  19.989279509
# r2: 19.989279509
# r:
#  22.4428233743
# r2: 21.261843264
# r:  20.4476678989
# r2: 19.5077435967
# r:  20.7041956441
# r2: 20.267787631
# r:  20.5108095749
# r2: 20.2891283678
# r:  19.7089151384
# r2: 19.5961296693
# r:  19.1046344198
# r2: 19.0386040513
# r:  18.0695864696
# r2: 18.017863593
# r:  17.4829582711
# r2: 17.4529082382
# r:  17.186080954
# r2: 17.1671871304
# r:  17.0279600439
# r2: 17.0120061784
# r:  16.854314924
# r2: 16.8397647997
# r:  16.6828985289
# r2: 16.6691710901
# r:  16.5396680004
# r2: 16.5269038571
# r:
#  16.4283998044
# r2: 16.4170506641
# r:  16.3756394849
# r2: 16.3663402384
# r:  16.3564473517
# r2: 16.3487742145
# r:  16.3711535934
# r2: 16.3657873805
# r:  16.4060758492
# r2: 16.4025954601
# r:  16.447873196
# r2: 16.4457687163
# r:  16.4953402465
# r2: 16.4940082573
# r:  19.989279509
# r2: 19.989279509
# r:  22.4428233743
# r2: 21.261843264
# r:  20.4476678989
# r2: 19.5077435967
# r:  20.7041956441
# r2: 20.267787631
# r:  20.5108095749
# r2: 20.2891283678
# r:  19.7089151384
# r2: 19.5961296693
# r:
#  19.1046344198
# r2: 19.0386040513
# r:  18.0695864696
# r2: 18.017863593
# r:  17.4829582711
# r2: 17.4529082382
# r:  17.186080954
# r2: 17.1671871304
# r:  17.0279600439
# r2: 17.0120061784
# r:  16.854314924
# r2: 16.8397647997
# r:  16.6828985289
# r2: 16.6691710901
# r:  16.5396680004
# r2: 16.5269038571
# r:  16.4283998044
# r2: 16.4170506641
# r:  16.3756394849
# r2: 16.3663402384
# r:  16.3564473517
# r2: 16.3487742145
# r:  16.3711535934
# r2: 16.3657873805
# r:  16.4060758492
# r2: 16.4025954601
# r:
#  16.447873196
# r2: 16.4457687163
# r:  16.4953402465
# r2: 16.4940082573
# r:  19.989279509
# r2: 19.989279509
# r:  22.4428233743
# r2: 21.261843264
# r:  20.4476678989
# r2: 19.5077435967
# r:  20.7041956441
# r2: 20.267787631
# r:  20.5108095749
# r2: 20.2891283678
# r:  19.7089151384
# r2: 19.5961296693
# r:  19.1046344198
# r2: 19.0386040513
# r:  18.0695864696
# r2: 18.017863593
# r:  17.4829582711
# r2: 17.4529082382
# r:  17.186080954
# r2: 17.1671871304
# r:
#  17.0279600439
# r2: 17.0120061784
# r:  16.854314924
# r2: 16.8397647997
# r:  16.6828985289
# r2: 16.6691710901
# r:  16.5396680004
# r2: 16.5269038571
# r:  16.4283998044
# r2: 16.4170506641
# r:  16.3756394849
# r2: 16.3663402384
# r:  16.3564473517
# r2: 16.3487742145
# r:  16.3711535934
# r2: 16.3657873805
# r:  16.4060758492
# r2: 16.4025954601
# r:  16.447873196
# r2: 16.4457687163
# r:  16.4953402465
# r2: 16.4940082573
# r:  19.989279509
# r2: 19.989279509
# r:
#  22.4428233743
# r2: 21.261843264
# r:  20.4476678989
# r2: 19.5077435967
# r:  20.7041956441
# r2: 20.267787631
# r:  20.5108095749
# r2: 20.2891283678
# r:  19.7089151384
# r2: 19.5961296693
# r:  19.1046344198
# r2: 19.0386040513
# r:  18.0695864696
# r2: 18.017863593
# r:  17.4829582711
# r2: 17.4529082382
# r:  17.186080954
# r2: 17.1671871304
# r:  17.0279600439
# r2: 17.0120061784
# r:  16.854314924
# r2: 16.8397647997
# r:  16.6828985289
# r2: 16.6691710901
# r:  16.5396680004
# r2: 16.5269038571
# r:
#  16.4283998044
# r2: 16.4170506641
# r:  16.3756394849
# r2: 16.3663402384
# r:  16.3564473517
# r2: 16.3487742145
# r:  16.3711535934
# r2: 16.3657873805
# r:  16.4060758492
# r2: 16.4025954601
# r:  16.447873196
# r2: 16.4457687163
# r:  16.4953402465
# r2: 16.4940082573
# r:  19.989279509
# r2: 19.989279509
# r:  22.4428233743
# r2: 21.261843264
# r:  20.4476678989
# r2: 19.5077435967
# r:  20.7041956441
# r2: 20.267787631
# r:  20.5108095749
# r2: 20.2891283678
# r:  19.7089151384
# r2: 19.5961296693
# r:
#  19.1046344198
# r2: 19.0386040513
# r:  18.0695864696
# r2: 18.017863593
# r:  17.4829582711
# r2: 17.4529082382
# r:  17.186080954
# r2: 17.1671871304
# r:  17.0279600439
# r2: 17.0120061784
# r:  16.854314924
# r2: 16.8397647997
# r:  16.6828985289
# r2: 16.6691710901
# r:  16.5396680004
# r2: 16.5269038571
# r:  16.4283998044
# r2: 16.4170506641
# r:  16.3756394849
# r2: 16.3663402384
# r:  16.3564473517
# r2: 16.3487742145
# r:  16.3711535934
# r2: 16.3657873805
# r:
#  16.4060758492
# r2: 16.4025954601
# r:  16.447873196
# r2: 16.4457687163
# r:  16.4953402465
# r2: 16.4940082573
# r:  19.989279509
# r2: 19.989279509
# r:  22.4428233743
# r2: 21.261843264
# r:  20.4476678989
# r2: 19.5077435967
# r:  20.7041956441
# r2: 20.267787631
# r:  20.5108095749
# r2: 20.2891283678
# r:  19.7089151384
# r2: 19.5961296693
# r:  19.1046344198
# r2: 19.0386040513
# r:  18.0695864696
# r2: 18.017863593
# r:  17.4829582711
# r2: 17.4529082382
# r:  17.186080954
# r2: 17.1671871304
# r:
#  17.0279600439
# r2: 17.0120061784
# r:  16.854314924
# r2: 16.8397647997
# r:  16.6828985289
# r2: 16.6691710901
# r:  16.5396680004
# r2: 16.5269038571
# r:  16.4283998044
# r2: 16.4170506641
# r:  16.3756394849
# r2: 16.3663402384
# r:  16.3564473517
# r2: 16.3487742145
# r:  16.3711535934
# r2: 16.3657873805
# r:  16.4060758492
# r2: 16.4025954601
# r:  16.447873196
# r2: 16.4457687163
# r:  16.4953402465
# r2: 16.4940082573
# r:  19.989279509
# r2: 19.989279509
# r:  22.4428233743
# r2: 21.261843264
# r:
#  20.4476678989
# r2: 19.5077435967
# r:  20.7041956441
# r2: 20.267787631
# r:  20.5108095749
# r2: 20.2891283678
# r:  19.7089151384
# r2: 19.5961296693
# r:  19.1046344198
# r2: 19.0386040513
# r:  18.0695864696
# r2: 18.017863593
# r:  17.4829582711
# r2: 17.4529082382
# r:  17.186080954
# r2: 17.1671871304
# r:  17.0279600439
# r2: 17.0120061784
# r:  16.854314924
# r2: 16.8397647997
# r:  16.6828985289
# r2: 16.6691710901
# r:  16.5396680004
# r2: 16.5269038571
# r:  16.4283998044
# r2: 16.4170506641
# r:
#  16.3756394849
# r2: 16.3663402384
# r:  16.3564473517
# r2: 16.3487742145
# r:  16.3711535934
# r2: 16.3657873805
# r:  16.4060758492
# r2: 16.4025954601
# r:  16.447873196
# r2: 16.4457687163
# r:  16.4953402465
# r2: 16.4940082573
# r:  19.989279509
# r2: 19.989279509
# r:  22.4428233743
# r2: 21.261843264
# r:  20.4476678989
# r2: 19.5077435967
# r:  20.7041956441
# r2: 20.267787631
# r:  20.5108095749
# r2: 20.2891283678
# r:  19.7089151384
# r2: 19.5961296693
# r:  19.1046344198
# r2: 19.0386040513
# r:
#  18.0695864696
# r2: 18.017863593
# r:  17.4829582711
# r2: 17.4529082382
# r:  17.186080954
# r2: 17.1671871304
# r:  17.0279600439
# r2: 17.0120061784
# r:  16.854314924
# r2: 16.8397647997
# r:  16.6828985289
# r2: 16.6691710901
# r:  16.5396680004
# r2: 16.5269038571
# r:  16.4283998044
# r2: 16.4170506641
# r:  16.3756394849
# r2: 16.3663402384
# r:  16.3564473517
# r2: 16.3487742145
# r:  16.3711535934
# r2: 16.3657873805
# r:  16.4060758492
# r2: 16.4025954601
# r:
#  16.447873196
# r2: 16.4457687163
# r:  16.4953402465
# r2: 16.4940082573
# r:  19.989279509
# r2: 19.989279509
# r:  22.4428233743
# r2: 21.261843264
# r:  20.4476678989
# r2: 19.5077435967
# r:  20.7041956441
# r2: 20.267787631
# r:  20.5108095749
# r2: 20.2891283678
# r:  19.7089151384
# r2: 19.5961296693
# r:  19.1046344198
# r2: 19.0386040513
# r:  18.0695864696
# r2: 18.017863593
# r:  17.4829582711
# r2: 17.4529082382
# r:  17.186080954
# r2: 17.1671871304
# r:
#  17.0279600439
# r2: 17.0120061784
# r:  16.854314924
# r2: 16.8397647997
# r:  16.6828985289
# r2: 16.6691710901
# r:  16.5396680004
# r2: 16.5269038571
# r:  16.4283998044
# r2: 16.4170506641
# r:  16.3756394849
# r2: 16.3663402384
# r:  16.3564473517
# r2: 16.3487742145
# r:  16.3711535934
# r2: 16.3657873805
# r:  16.4060758492
# r2: 16.4025954601
# r:  16.447873196
# r2: 16.4457687163
# r:  16.4953402465
# r2: 16.4940082573
# r:  19.989279509
# r2: 19.989279509
# r:  22.4428233743
# r2: 21.261843264
# r:
#  20.4476678989
# r2: 19.5077435967
# r:  20.7041956441
# r2: 20.267787631
# r:  20.5108095749
# r2: 20.2891283678
# r:  19.7089151384
# r2: 19.5961296693
# r:  19.1046344198
# r2: 19.0386040513
# r:  18.0695864696
# r2: 18.017863593
# r:  17.4829582711
# r2: 17.4529082382
# r:  17.186080954
# r2: 17.1671871304
# r:  17.0279600439
# r2: 17.0120061784
# r:  16.854314924
# r2: 16.8397647997
# r:  16.6828985289
# r2: 16.6691710901
# r:  16.5396680004
# r2: 16.5269038571
# r:  16.4283998044
# r2: 16.4170506641
# r:
#  16.3756394849
# r2: 16.3663402384
# r:  16.3564473517
# r2: 16.3487742145
# r:  16.3711535934
# r2: 16.3657873805
# r:  16.4060758492
# r2: 16.4025954601
# r:  16.447873196
# r2: 16.4457687163
# r:  16.4953402465
# r2: 16.4940082573
# r:  19.989279509
# r2: 19.989279509
# r:  22.4428233743
# r2: 21.261843264
# r:  20.4476678989
# r2: 19.5077435967
# r:  20.7041956441
# r2: 20.267787631
# r:  20.5108095749
# r2: 20.2891283678
# r:  19.7089151384
# r2: 19.5961296693
# r:
#  19.1046344198
# r2: 19.0386040513
# r:  18.0695864696
# r2: 18.017863593
# r:  17.4829582711
# r2: 17.4529082382
# r:  17.186080954
# r2: 17.1671871304
# r:  17.0279600439
# r2: 17.0120061784
# r:  16.854314924
# r2: 16.8397647997
# r:  16.6828985289
# r2: 16.6691710901
# r:  16.5396680004
# r2: 16.5269038571
# r:  16.4283998044
# r2: 16.4170506641
# r:  16.3756394849
# r2: 16.3663402384
# r:  16.3564473517
# r2: 16.3487742145
# r:  16.3711535934
# r2: 16.3657873805
# r:  16.4060758492
# r2: 16.4025954601
# r:
#  16.447873196
# r2: 16.4457687163
# r:  16.4953402465
# r2: 16.4940082573
# r:  19.989279509
# r2: 19.989279509
# r:  22.4428233743
# r2: 21.261843264
# r:  20.4476678989
# r2: 19.5077435967
# r:  20.7041956441
# r2: 20.267787631
# r:  20.5108095749
# r2: 20.2891283678
# r:  19.7089151384
# r2: 19.5961296693
# r:  19.1046344198
# r2: 19.0386040513
# r:  18.0695864696
# r2: 18.017863593
# r:  17.4829582711
# r2: 17.4529082382
# r:  17.186080954
# r2: 17.1671871304
# r:
#  17.0279600439
# r2: 17.0120061784
# r:  16.854314924
# r2: 16.8397647997
# r:  16.6828985289
# r2: 16.6691710901
# r:  16.5396680004
# r2: 16.5269038571
# r:  16.4283998044
# r2: 16.4170506641
# r:  16.3756394849
# r2: 16.3663402384
# r:  16.3564473517
# r2: 16.3487742145
# r:  16.3711535934
# r2: 16.3657873805
# r:  16.4060758492
# r2: 16.4025954601
# r:  16.447873196
# r2: 16.4457687163
# r:  16.4953402465
# r2: 16.4940082573
# r:  19.989279509
# r2: 19.989279509
# r:
#  22.4428233743
# r2: 21.261843264
# r:  20.4476678989
# r2: 19.5077435967
# r:  20.7041956441
# r2: 20.267787631
# r:  20.5108095749
# r2: 20.2891283678
# r:  19.7089151384
# r2: 19.5961296693
# r:  19.1046344198
# r2: 19.0386040513
# r:  18.0695864696
# r2: 18.017863593
# r:  17.4829582711
# r2: 17.4529082382
# r:  17.186080954
# r2: 17.1671871304
# r:  17.0279600439
# r2: 17.0120061784
# r:  16.854314924
# r2: 16.8397647997
# r:  16.6828985289
# r2: 16.6691710901
# r:
#  16.5396680004
# r2: 16.5269038571
# r:  16.4283998044
# r2: 16.4170506641
# r:  16.3756394849
# r2: 16.3663402384
# r:  16.3564473517
# r2: 16.3487742145
# r:  16.3711535934
# r2: 16.3657873805
# r:  16.4060758492
# r2: 16.4025954601
# r:  16.447873196
# r2: 16.4457687163
# r:  16.4953402465
# r2: 16.4940082573
# r:  19.989279509
# r2: 19.989279509
# r:  22.4428233743
# r2: 21.261843264
# r:  20.4476678989
# r2: 19.5077435967
# r:
#  20.7041956441
# r2: 20.267787631
# r:  20.5108095749
# r2: 20.2891283678
# r:  19.7089151384
# r2: 19.5961296693
# r:  19.1046344198
# r2: 19.0386040513
# r:  18.0695864696
# r2: 18.017863593
# r:  17.4829582711
# r2: 17.4529082382
# r:  17.186080954
# r2: 17.1671871304
# r:  17.0279600439
# r2: 17.0120061784
# r:  16.854314924
# r2: 16.8397647997
# r:  16.6828985289
# r2: 16.6691710901
# r:  16.5396680004
# r2: 16.5269038571
# r:  16.4283998044
# r2: 16.4170506641
# r:
#  16.3756394849
# r2: 16.3663402384
# r:  16.3564473517
# r2: 16.3487742145
# r:  16.3711535934
# r2: 16.3657873805
# r:  16.4060758492
# r2: 16.4025954601
# r:  16.447873196
# r2: 16.4457687163
# r:  16.4953402465
# r2: 16.4940082573
# r:  19.989279509
# r2: 19.989279509
# r:  22.4428233743
# r2: 21.261843264
# r:  20.4476678989
# r2: 19.5077435967
# r:  20.7041956441
# r2: 20.267787631
# r:  20.5108095749
# r2: 20.2891283678
# r:  19.7089151384
# r2: 19.5961296693
# r:
#  19.1046344198
# r2: 19.0386040513
# r:  18.0695864696
# r2: 18.017863593
# r:  17.4829582711
# r2: 17.4529082382
# r:  17.186080954
# r2: 17.1671871304
# r:  17.0279600439
# r2: 17.0120061784
# r:  16.854314924
# r2: 16.8397647997
# r:  16.6828985289
# r2: 16.6691710901
# r:  16.5396680004
# r2: 16.5269038571
# r:  16.4283998044
# r2: 16.4170506641
# r:  16.3756394849
# r2: 16.3663402384
# r:  16.3564473517
# r2: 16.3487742145
# r:  16.3711535934
# r2: 16.3657873805
# r:
#  16.4060758492
# r2: 16.4025954601
# r:  16.447873196
# r2: 16.4457687163
# r:  16.4953402465
# r2: 16.4940082573
# r:  19.989279509
# r2: 19.989279509
# r:  22.4428233743
# r2: 21.261843264
# r:  20.4476678989
# r2: 19.5077435967
# r:  20.7041956441
# r2: 20.267787631
# r:  20.5108095749
# r2: 20.2891283678
# r:  19.7089151384
# r2: 19.5961296693
# r:  19.1046344198
# r2: 19.0386040513
# r:  18.0695864696
# r2: 18.017863593
# r:
#  17.4829582711
# r2: 17.4529082382
# r:  17.186080954
# r2: 17.1671871304
# r:  17.0279600439
# r2: 17.0120061784
# r:  16.854314924
# r2: 16.8397647997
# r:  16.6828985289
# r2: 16.6691710901
# r:  16.5396680004
# r2: 16.5269038571
# r:  16.4283998044
# r2: 16.4170506641
# r:  16.3756394849
# r2: 16.3663402384
# r:  16.3564473517
# r2: 16.3487742145
# r:  16.3711535934
# r2: 16.3657873805
# r:  16.4060758492
# r2: 16.4025954601
# r:  16.447873196
# r2: 16.4457687163
# r:
#  16.4953402465
# r2: 16.4940082573
# r:  19.989279509
# r2: 19.989279509
# r:  22.4428233743
# r2: 21.261843264
# r:  20.4476678989
# r2: 19.5077435967
# r:  20.7041956441
# r2: 20.267787631
# r:  20.5108095749
# r2: 20.2891283678
# r:  19.7089151384
# r2: 19.5961296693
# r:  19.1046344198
# r2: 19.0386040513
# r:  18.0695864696
# r2: 18.017863593
# r:  17.4829582711
# r2: 17.4529082382
# r:  17.186080954
# r2: 17.1671871304
# r:
#  17.0279600439
# r2: 17.0120061784
# r:  16.854314924
# r2: 16.8397647997
# r:  16.6828985289
# r2: 16.6691710901
# r:  16.5396680004
# r2: 16.5269038571
# r:  16.4283998044
# r2: 16.4170506641
# r:  16.3756394849
# r2: 16.3663402384
# r:  16.3564473517
# r2: 16.3487742145
# r:  16.3711535934
# r2: 16.3657873805
# r:  16.4060758492
# r2: 16.4025954601
# r:  16.447873196
# r2: 16.4457687163
# r:  16.4953402465
# r2: 16.4940082573
# r:  19.989279509
# r2: 19.989279509
# r:
#  22.4428233743
# r2: 21.261843264
# r:  20.4476678989
# r2: 19.5077435967
# r:  20.7041956441
# r2: 20.267787631
# r:  20.5108095749
# r2: 20.2891283678
# r:  19.7089151384
# r2: 19.5961296693
# r:  19.1046344198
# r2: 19.0386040513
# r:  18.0695864696
# r2: 18.017863593
# r:  17.4829582711
# r2: 17.4529082382
# r:  17.186080954
# r2: 17.1671871304
# r:  17.0279600439
# r2: 17.0120061784
# r:  16.854314924
# r2: 16.8397647997
# r:  16.6828985289
# r2: 16.6691710901
# r:  16.5396680004
# r2: 16.5269038571
# r:
#  16.4283998044
# r2: 16.4170506641
# r:  16.3756394849
# r2: 16.3663402384
# r:  16.3564473517
# r2: 16.3487742145
# r:  16.3711535934
# r2: 16.3657873805
# r:  16.4060758492
# r2: 16.4025954601
# r:  16.447873196
# r2: 16.4457687163
# r:  16.4953402465
# r2: 16.4940082573
# r:  19.989279509
# r2: 19.989279509
# r:  22.4428233743
# r2: 21.261843264
# r:  20.4476678989
# r2: 19.5077435967
# r:  20.7041956441
# r2: 20.267787631
# r:  20.5108095749
# r2: 20.2891283678
# r:
#  19.7089151384
# r2: 19.5961296693
# r:  19.1046344198
# r2: 19.0386040513
# r:  18.0695864696
# r2: 18.017863593
# r:  17.4829582711
# r2: 17.4529082382
# r:  17.186080954
# r2: 17.1671871304
# r:  17.0279600439
# r2: 17.0120061784
# r:  16.854314924
# r2: 16.8397647997
# r:  16.6828985289
# r2: 16.6691710901
# r:  16.5396680004
# r2: 16.5269038571
# r:  16.4283998044
# r2: 16.4170506641
# r:  16.3756394849
# r2: 16.3663402384
# r:  16.3564473517
# r2: 16.3487742145
# r:
#  16.3711535934
# r2: 16.3657873805
# r:  16.4060758492
# r2: 16.4025954601
# r:  16.447873196
# r2: 16.4457687163
# r:  16.4953402465
# r2: 16.4940082573
# r:  19.989279509
# r2: 19.989279509
# r:  22.4428233743
# r2: 21.261843264
# r:  20.4476678989
# r2: 19.5077435967
# r:  20.7041956441
# r2: 20.267787631
# r:  20.5108095749
# r2: 20.2891283678
# r:  19.7089151384
# r2: 19.5961296693
# r:  19.1046344198
# r2: 19.0386040513
# r:
#  18.0695864696
# r2: 18.017863593
# r:  17.4829582711
# r2: 17.4529082382
# r:  17.186080954
# r2: 17.1671871304
# r:  17.0279600439
# r2: 17.0120061784
# r:  16.854314924
# r2: 16.8397647997
# r:  16.6828985289
# r2: 16.6691710901
# r:  16.5396680004
# r2: 16.5269038571
# r:  16.4283998044
# r2: 16.4170506641
# r:  16.3756394849
# r2: 16.3663402384
# r:  16.3564473517
# r2: 16.3487742145
# r:  16.3711535934
# r2: 16.3657873805
# r:  16.4060758492
# r2: 16.4025954601
# r:
#  16.447873196
# r2: 16.4457687163
# r:  16.4953402465
# r2: 16.4940082573
# r:  19.989279509
# r2: 19.989279509
# r:  22.4428233743
# r2: 21.261843264
# r:  20.4476678989
# r2: 19.5077435967
# r:  20.7041956441
# r2: 20.267787631
# r:  20.5108095749
# r2: 20.2891283678
# r:  19.7089151384
# r2: 19.5961296693
# r:  19.1046344198
# r2: 19.0386040513
# r:  18.0695864696
# r2: 18.017863593
# r:  17.4829582711
# r2: 17.4529082382
# r:  17.186080954
# r2: 17.1671871304
# r:
#  17.0279600439
# r2: 17.0120061784
# r:  16.854314924
# r2: 16.8397647997
# r:  16.6828985289
# r2: 16.6691710901
# r:  16.5396680004
# r2: 16.5269038571
# r:  16.4283998044
# r2: 16.4170506641
# r:  16.3756394849
# r2: 16.3663402384
# r:  16.3564473517
# r2: 16.3487742145
# r:  16.3711535934
# r2: 16.3657873805
# r:  16.4060758492
# r2: 16.4025954601
# r:  16.447873196
# r2: 16.4457687163
# r:  16.4953402465
# r2: 16.4940082573
# r:  19.989279509
# r2: 19.989279509
# r:
#  22.4428233743
# r2: 21.261843264
# r:  20.4476678989
# r2: 19.5077435967
# r:  20.7041956441
# r2: 20.267787631
# r:  20.5108095749
# r2: 20.2891283678
# r:  19.7089151384
# r2: 19.5961296693
# r:  19.1046344198
# r2: 19.0386040513
# r:  18.0695864696
# r2: 18.017863593
# r:  17.4829582711
# r2: 17.4529082382
# r:  17.186080954
# r2: 17.1671871304
# r:  17.0279600439
# r2: 17.0120061784
# r:  16.854314924
# r2: 16.8397647997
# r:  16.6828985289
# r2: 16.6691710901
# r:  16.5396680004
# r2: 16.5269038571
# r:
#  16.4283998044
# r2: 16.4170506641
# r:  16.3756394849
# r2: 16.3663402384
# r:  16.3564473517
# r2: 16.3487742145
# r:  16.3711535934
# r2: 16.3657873805
# r:  16.4060758492
# r2: 16.4025954601
# r:  16.447873196
# r2: 16.4457687163
# r:  16.4953402465
# r2: 16.4940082573
# r:  19.989279509
# r2: 19.989279509
# r:  22.4428233743
# r2: 21.261843264
# r:  20.4476678989
# r2: 19.5077435967
# r:  20.7041956441
# r2: 20.267787631
# r:  20.5108095749
# r2: 20.2891283678
# r:
#  19.7089151384
# r2: 19.5961296693
# r:  19.1046344198
# r2: 19.0386040513
# r:  18.0695864696
# r2: 18.017863593
# r:  17.4829582711
# r2: 17.4529082382
# r:  17.186080954
# r2: 17.1671871304
# r:  17.0279600439
# r2: 17.0120061784
# r:  16.854314924
# r2: 16.8397647997
# r:  16.6828985289
# r2: 16.6691710901
# r:  16.5396680004
# r2: 16.5269038571
# r:  16.4283998044
# r2: 16.4170506641
# r:  16.3756394849
# r2: 16.3663402384
# r:  16.3564473517
# r2: 16.3487742145
# r:
#  16.3711535934
# r2: 16.3657873805
# r:  16.4060758492
# r2: 16.4025954601
# r:  16.447873196
# r2: 16.4457687163
# r:  16.4953402465
# r2: 16.4940082573
# r:  19.989279509
# r2: 19.989279509
# r:  22.4428233743
# r2: 21.261843264
# r:  20.4476678989
# r2: 19.5077435967
# r:  20.7041956441
# r2: 20.267787631
# r:  20.5108095749
# r2: 20.2891283678
# r:  19.7089151384
# r2: 19.5961296693
# r:  19.1046344198
# r2: 19.0386040513
# r:  18.0695864696
# r2: 18.017863593
# r:
#  17.4829582711
# r2: 17.4529082382
# r:  17.186080954
# r2: 17.1671871304
# r:  17.0279600439
# r2: 17.0120061784
# r:  16.854314924
# r2: 16.8397647997
# r:  16.6828985289
# r2: 16.6691710901
# r:  16.5396680004
# r2: 16.5269038571
# r:  16.4283998044
# r2: 16.4170506641
# r:  16.3756394849
# r2: 16.3663402384
# r:  16.3564473517
# r2: 16.3487742145
# r:  16.3711535934
# r2: 16.3657873805
# r:  16.4060758492
# r2: 16.4025954601
# r:  16.447873196
# r2: 16.4457687163
# r:  16.4953402465
# r2: 16.4940082573
# r:
#  19.989279509
# r2: 19.989279509
# r:  22.4428233743
# r2: 21.261843264
# r:  20.4476678989
# r2: 19.5077435967
# r:  20.7041956441
# r2: 20.267787631
# r:  20.5108095749
# r2: 20.2891283678
# r:  19.7089151384
# r2: 19.5961296693
# r:  19.1046344198
# r2: 19.0386040513
# r:  18.0695864696
# r2: 18.017863593
# r:  17.4829582711
# r2: 17.4529082382
# r:  17.186080954
# r2: 17.1671871304
# r:  17.0279600439
# r2: 17.0120061784
# r:  16.854314924
# r2: 16.8397647997
# r:
#  16.6828985289
# r2: 16.6691710901
# r:  16.5396680004
# r2: 16.5269038571
# r:  16.4283998044
# r2: 16.4170506641
# r:  16.3756394849
# r2: 16.3663402384
# r:  16.3564473517
# r2: 16.3487742145
# r:  16.3711535934
# r2: 16.3657873805
# r:  16.4060758492
# r2: 16.4025954601
# r:  16.447873196
# r2: 16.4457687163
# r:  16.4953402465
# r2: 16.4940082573
# 10 loops, best of 3: 88.4 ms per loop

# %% [markdown]
# Things to take with you from this second part:
#
# - AAM fitting is defined as a **non-linear squares** problem.
#
# - The **Gauss-Newton** algorithm can be used to solve AAM fitting.
#   - **Numerical** approximation.
#   - **Analytical** derivation.
#
# - Analytical algorithms are defined by:
#   - The way in which they handle the appearance parameters:
#    - **Project out**.
#    - **Alternating**.
#    - **Simultaneous**.
#   - The roles that the input image and the appearance model problem play in the optimization:
#    - **Forward**.
#    - **Inverse**.
#   - The update rule:
#    - **Additive**.
#    - **Compositional**.

# %% [markdown]
# ##Questions?

# %% [markdown]
# ## Part 3: Feature-based Active Appearance Models
# ---

# %% [markdown]
# ##Part 4: Supervised Descent Method
# ---
