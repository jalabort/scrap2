# %%
import pybug.io as pio
from pybug.landmark import labeller, ibug_68_trimesh

training_images = []
# load landmarked imarges
for i in pio.import_images('/data/PhD/DataBases/lfpw/trainset/*.png',
                     max_images=811):
    i.crop_to_landmarks_proportion(0.3)
    if i.n_channels == 3:
        training_images.append(i.as_greyscale(mode='luminosity'))
    else:
        training_images.append(i)

# %%
# %matplotlib inline
#visualize the first image
training_images[0].landmarks['PTS'].view_new()

# %%
from skimage.feature import daisy, local_binary_pattern

# %%
a = local_binary_pattern(training_images[0].pixels[..., 0], 8, 8)

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as cm
plt.imshow(a[:,:], cmap=cm.Greys_r)

# %%
import numpy as np

# %%
a = daisy(np.squeeze(training_images[0].pixels[0:24,0:24,0]), radius=4, rings=4, step =4)

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as cm
plt.imshow(a[:,:,8], cmap=cm.Greys_r)

# %%
a.shape
# Out:
# (4, 4, 264)

# %%
patch_size = [(8, 8), (16,16), (24,24)]

# %%
patch_size[0]
# Out:
# (8, 8)

# %%
b = training_images[0].pixels[0:24,0:24,0]

# %%
24*24
# Out:
# 576
