# %%
# %matplotlib inline
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import menpo.io as mio
from menpo.landmark import labeller, ibug_face_66
from fg2015.utils import convert_from_menpo

images = []
for i in mio.import_images('/data/PhD/DataBases/faces/lfpw/trainset/', 
                           max_images=None, verbose=True):
    
    i = convert_from_menpo(i)
    
    labeller(i, 'PTS', ibug_face_66)
    i.crop_to_landmarks_proportion_inplace(0.5, group='ibug_face_66')
    if i.n_channels == 3:
        i = i.as_greyscale(mode='average')
    images.append(i)
# Out:
# - Loading 811 assets: [                    ] 0%
# - Loading 811 assets: [                    ] 0%
# - Loading 811 assets: [                    ] 0%
# - Loading 811 assets: [                    ] 0%
# - Loading 811 assets: [                    ] 0%
# - Loading 811 assets: [                    ] 0%
# - Loading 811 assets: [                    ] 0%
# - Loading 811 assets: [                    ] 0%
# - Loading 811 assets: [                    ] 1%
# - Loading 811 assets: [                    ] 1%
# - Loading 811 assets: [                    ] 1%
# - Loading 811 assets: [                    ] 1%
# - Loading 811 assets: [                    ] 1%
# - Loading 811 assets: [                    ] 1%
# - Loading 811 assets: [                    ] 1%
# - Loading 811 assets: [                    ] 1%
# - Loading 811 assets: [                    ] 2%
# - Loading 811 assets: [                    ] 2%
# - Loading 811 assets: [                    ] 2%
# - Loading 811 assets: [                    ] 2%
# ...

# %%
from fg2015.feature import dsift, aam_dsift, aam_daisy

norm_images = [i.rescale_landmarks_to_diagonal_range(100, group='ibug_face_66') for i in images]

n_channels = norm_images[0].n_channels

# %%
from menpo.visualize import browse_images

browse_images(norm_images)

# %%
sample_offsets = np.meshgrid(range(-4, 5, 2), range(-4, 5, 2)) # np.array((0, 0))[..., None]  #
sample_offsets = np.asarray([sample_offsets[0].flatten(), sample_offsets[1].flatten()]).T 
n_s = sample_offsets.shape[0]
print n_s
# Out:
# 25

# %%
from fg2015.image.cython import extract_patches

patch_shape = (17, 17)
lim_y = patch_shape[0] / 2
lim_x = patch_shape[1] / 2
training_parts_images = [extract_patches(i.pixels, i.landmarks['ibug_face_66'].lms.points, 
                                                np.array(patch_shape), sample_offsets) [:, :, :, :, :]
                         for i in norm_images]

# %%
import scipy

mask = sum(meshgrid(scipy.signal.cosine(patch_shape[0]), scipy.signal.cosine(patch_shape[1])), axis=0)

# %%
expanded_images = []
for i in training_parts_images:
    aux = np.zeros(i.shape[:-2] + (patch_shape[0],patch_shape[1]))
    for j in xrange(i.shape[1]):
        #aux[:, j, :, :, :] = np.zeros((n_channels, n_s, 2*patch_shape[0], 2*patch_shape[1]))
        #aux[:, j, :, -lim_y:, -lim_x:] = i[:, j, :, :lim_y, :lim_x]
        #aux[:, j, :, :lim_y+1, -lim_x:] = i[:, j, :, lim_y:, :lim_x]
        #aux[:, j, :, -lim_y:, :lim_x+1] = i[:, j, :, :lim_y, lim_x:]
        #aux[:, j, :, :lim_y+1, :lim_x+1] = i[:, j, :, lim_y:, lim_x:]
        for c in xrange(n_channels):
            for k in xrange(n_s):
                #aux[c, j, k, ...] = np.fft.fftshift(mask * aux[c, j, k, ...])
                aux[c, j, k, ...] = mask * i[c, j, k, ...]
    expanded_images.append(aux)

# %%
#expanded_images = training_parts_images

# %%
from fg2015.image import Image

Image(expanded_images[0][0, 36, ...]).view()

# %%
parts_images_hat = []
pixels_hat = np.zeros_like(expanded_images[0], dtype=np.complex)
for i in expanded_images:
    for j in xrange(images[0].landmarks['ibug_face_66'].lms.n_points):
        for c in xrange(n_channels):
            for k in xrange(n_s):
                pixels_hat[c, j, k, :, :] = np.fft.fft2(i[c, j, k, :, :])
    parts_images_hat.append(Image(pixels_hat))

# %%
from scipy.stats import multivariate_normal
from menpo.fitmultilevel.functions import build_sampling_grid

# Build the sampling grid associated to the patch shape
sampling_grid = build_sampling_grid(patch_shape)
# Define the 2-dimensional gaussian distribution
mean = np.zeros(2)
covariance = 1
mvn = multivariate_normal(mean=mean, cov=covariance)
# Compute Gaussian-KDE grid
kernel_grid = mvn.pdf(sampling_grid)




patch_shape = np.array(patch_shape)
patch_half_shape = np.require(np.floor(patch_shape / 2), dtype=int)
start = -patch_half_shape
end = patch_half_shape + 1
sampling_grid = np.mgrid[start[0]:end[0], start[1]:end[1]]
sampling_grid = sampling_grid.swapaxes(0, 2).swapaxes(0, 1)


kernel_grids = []
for sam_off in sample_offsets:
    kernel_grids.append(mvn.pdf(sampling_grid + sam_off))

# %%
imshow(kernel_grids[0])

# %%
imshow((np.random.rand(68,2) [..., None, None, :] + sampling_grid)[0,:,:,0])

# %%
y_hat = []
for k in kernel_grids:
    y_hat.append(np.fft.fft2(k))

imshow(np.abs(np.fft.fftshift(y_hat[0])))

# %%
y_hat[0].shape
patch_shape
# Out:
# array([17, 17])

# %%
l = 0.1
part = 37

# %%
sxx_hat = 0
syx_hat = 0
for xi_hat in parts_images_hat:
    xi_hat = xi_hat.pixels
    for s, yi_hat in enumerate(y_hat):
        sxx_hat = sxx_hat + xi_hat[:, part, s] * np.conj(xi_hat[:, part, s])
        syx_hat = syx_hat + yi_hat * np.conj(xi_hat[:, part, s])
h = syx_hat / (sxx_hat + l * np.eye(sxx_hat.shape[1]))

# %%
h.shape
# Out:
# (1, 17, 17)

# %%
imshow(np.abs(np.fft.fftshift(h[0, ...])))

# %%
Image(np.real(np.fft.fftshift(np.fft.ifft2(np.sum(h, axis=0))))).view()

# %%
#aux = np.fft.fftshift(h)
#aux[-lim_y:, -lim_x:] = 0
#aux[:lim_y, -lim_x:] = 0
#aux[-lim_y:, :lim_x] = 0
#aux[:lim_y, :lim_x] = 0
#h = np.fft.fftshift(aux)

# %%
parts_images_hat[0].pixels.shape
# Out:
# (1, 66, 25, 17, 17)

# %%
part_ = part+2
offset = 13
image = 10

rm = h * parts_images_hat[image].pixels[0, part_, offset]

imshow(np.real(np.fft.ifft2(rm))[0])

# %%
Image(np.real(np.fft.ifft2(parts_images_hat[image].pixels[0, part_, offset, ...]))).view()

# %%
Image(expanded_images[image][0, part_, offset, ...]).view()

# %%
Image(expanded_images[image][0, part_, ...]).view()

# %%
images[image].view()

# %%
import menpo.io as mio
from menpo.landmark import labeller, ibug_face_66
from fg2015.utils import convert_from_menpo

test_images = []
for i in mio.import_images('/data/PhD/DataBases/faces/afw/', 
                           max_images=20, verbose=True):
    
    i = convert_from_menpo(i)
    
    labeller(i, 'PTS', ibug_face_66)
    i.crop_to_landmarks_proportion_inplace(0.5, group='ibug_face_66')
    if i.n_channels == 3:
        i = i.as_greyscale(mode='average')
    test_images.append(i)
# Out:
# - Loading 20 assets: [=                   ] 5%
# - Loading 20 assets: [==                  ] 10%
# - Loading 20 assets: [===                 ] 15%
# - Loading 20 assets: [====                ] 20%
# - Loading 20 assets: [=====               ] 25%
# - Loading 20 assets: [======              ] 30%
# - Loading 20 assets: [=======             ] 35%
# - Loading 20 assets: [========            ] 40%
# - Loading 20 assets: [=========           ] 45%
# - Loading 20 assets: [==========          ] 50%
# - Loading 20 assets: [===========         ] 55%
# - Loading 20 assets: [============        ] 60%
# - Loading 20 assets: [=============       ] 65%
# - Loading 20 assets: [==============      ] 70%
# - Loading 20 assets: [===============     ] 75%
# - Loading 20 assets: [================    ] 80%
# - Loading 20 assets: [=================   ] 85%
# - Loading 20 assets: [==================  ] 90%
# - Loading 20 assets: [=================== ] 95%
# - Loading 20 assets: [====================] 100%

# %%
from fg2015.feature import dsift, aam_dsift, aam_daisy

test_norm_images = [i.rescale_landmarks_to_diagonal_range(100, group='ibug_face_66') for i in test_images]

# %%
from fg2015.image.cython import extract_patches

test_parts_images = [extract_patches(i.pixels, i.landmarks['ibug_face_66'].lms.points, 
                                            np.array(patch_shape), sample_offsets)
                     for i in test_norm_images]

# %%
part_ = part+0
offset = 12
image = 16

rm = h * np.fft.fft2(test_parts_images[image][0, part_, offset])

imshow(np.real(np.fft.ifft2(rm))[0])

# %%
# %%timeit 

rm = np.real(np.fft.ifft2(h * np.fft.fft2(test_parts_images[image][0, part_, offset])))
# Out:
# 10000 loops, best of 3: 138 µs per loop

# %%
Image(test_parts_images[image][0, part_, offset, ...]).view()

# %%
parts_images_hat[0].shape
# Out:
# (66, 25, 17, 17)

# %%
np.sum(parts_images_hat[0].pixels, axis=(-2, -1))[..., None, None]

# %%
(parts_images_hat[0].pixels / np.sum(parts_images_hat[0].pixels, axis=(-2, -1))[..., None, None]).shape
# Out:
# (1, 66, 25, 17, 17)

# %%
np.fft.ifft2(np.sum(h_ * i, axis=0))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-93-198a543fd6b3> in <module>()
# ----> 1 np.fft.ifft2(np.sum(h_ * i, axis=0))
#
# NameError: name 'h_' is not defined

# %%
h_ = np.conj(h)

rm = []
for i in parts_images_hat:
    i = i.pixels[:, part, ...]
    rm.append(Image(np.real(np.fft.ifft2(np.sum(h_ * i, axis=0)))))

browse_images(rm)

# %%
browse_images(training_images)

# %%
from __future__ import division

sampling_grid = np.mgrid[-pi/2:pi/2+pi/2/8:pi/2/8, -pi/2:pi/2+pi/2/8:pi/2/8]
mask = np.sum(np.abs(np.cos(sampling_grid)), axis=0)

# %%
mask.shape
# Out:
# (17, 17)

# %%
mask = np.cos(sum(np.abs(sampling_grid), axis=0)/2)

# %%
cos(-1)
# Out:
# 0.54030230586813977

# %%
sampling_grid = build_sampling_grid(patch_shape)

# %%
np.hanning(10)
# Out:
# array([ 0.        ,  0.11697778,  0.41317591,  0.75      ,  0.96984631,
#         0.96984631,  0.75      ,  0.41317591,  0.11697778,  0.        ])

# %%
import scipy
