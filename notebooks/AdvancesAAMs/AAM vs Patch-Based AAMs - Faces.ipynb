# %%
# %matplotlib inline
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Load training data

# %%
import menpo.io as mio
from menpo.landmark import labeller, ibug_face_68, ibug_face_68_trimesh

training_images = []
for i in mio.import_images('/data/PhD/DataBases/faces/lfpw/trainset/', 
                           max_images=None, verbose=True):
    labeller(i, 'PTS', ibug_face_68)
    labeller(i, 'PTS', ibug_face_68_trimesh)
    i.crop_to_landmarks_proportion_inplace(0.5, group='ibug_face_68')
    if i.n_channels == 3:
        i = i.as_greyscale(mode='luminosity')
    training_images.append(i)
# Out:
# - Loading 811 assets: [                    ] 0%
# - Loading 811 assets: [                    ] 0%
# - Loading 811 assets: [                    ] 0%
# - Loading 811 assets: [                    ] 0%
# - Loading 811 assets: [                    ] 0%
# - Loading 811 assets: [                    ] 0%
# - Loading 811 assets: [                    ] 0%
# - Loading 811 assets: [                    ] 0%
# - Loading 811 assets: [                    ] 1%
# - Loading 811 assets: [                    ] 1%
# - Loading 811 assets: [                    ] 1%
# - Loading 811 assets: [                    ] 1%
# - Loading 811 assets: [                    ] 1%
# - Loading 811 assets: [                    ] 1%
# - Loading 811 assets: [                    ] 1%
# - Loading 811 assets: [                    ] 1%
# - Loading 811 assets: [                    ] 2%
# - Loading 811 assets: [                    ] 2%
# - Loading 811 assets: [                    ] 2%
# - Loading 811 assets: [                    ] 2%
# ...

# %%
from menpo.visualize import browse_images

browse_images(training_images)

# %% [markdown]
# ## Build AAM

# %%
from menpo.fitmultilevel.aam import AAMBuilder
from menpo.transform import ThinPlateSplines

def norm_int(image):
    norm_image = image.copy()
    norm_image.normalize_norm_inplace()
    return norm_image

aam_builder = AAMBuilder(normalization_diagonal=100, 
                         feature_type=None,
                         n_levels=2,
                         trilist=i.landmarks['ibug_face_68_trimesh'].lms.trilist,
                         downscale=2)

aam = aam_builder.build(training_images, 
                        group='ibug_face_68', 
                        verbose=True)
# Out:
# - Computing reference shape
# - Normalizing images size: 0%
# - Normalizing images size: 0%
# - Normalizing images size: 0%
# - Normalizing images size: 0%
# - Normalizing images size: 0%
# - Normalizing images size: 0%
# - Normalizing images size: 0%
# - Normalizing images size: 0%
# - Normalizing images size: 1%
# - Normalizing images size: 1%
# - Normalizing images size: 1%
# - Normalizing images size: 1%
# - Normalizing images size: 1%
# - Normalizing images size: 1%
# - Normalizing images size: 1%
# - Normalizing images size: 1%
# - Normalizing images size: 2%
# - Normalizing images size: 2%
# - Normalizing images size: 2%
# - Normalizing images size: 2%
# - Normalizing images size: 2%
# - Normalizing images size: 2%
# - Normalizing images size: 2%
# - Normalizing images size: 2%
# - Normalizing images size: 3%
# - Normalizing images size: 3%
# - Normalizing images size: 3%
# - Normalizing images size: 3%
# - Normalizing images size: 3%
# - Normalizing images size: 3%
# ...

# %%
print aam
# Out:
# Active Appearance Model
#  - 811 training images.
#  - Warp using CachedPWA transform with 'scipy' interpolation.
#  - Gaussian pyramid with 2 levels and downscale factor of 2.
#    - Each level has a scaled shape model (reference frame).
#    - Pyramid was applied on feature space.
#    - No features extracted. 1 channel per image.
#    - Level 1 (no downscale):
#      - Reference frame of length 3659 (3659 x 1C, 75W x 74H x 1C)
#      - 133 shape components (100.00% of variance)
#      - 810 appearance components (100.00% of variance)
#    - Level 2 (downscale by 2):
#      - Reference frame of length 917 (917 x 1C, 41W x 40H x 1C)
#      - 133 shape components (100.00% of variance)
#      - 810 appearance components (100.00% of variance)

# %%
from menpo.visualize import visualize_aam

visualize_aam(aam)

# %% [markdown]
# ## Build Patch-Based AAM

# %%
from menpo.fitmultilevel.aam import PatchBasedAAMBuilder

pb_aam_builder = PatchBasedAAMBuilder(normalization_diagonal=100, 
                                      patch_shape=(12, 12),
                                      n_levels=2,
                                      feature_type=None,
                                      downscale=2)
pb_aam = pb_aam_builder.build(training_images, 
                              group='ibug_face_68', 
                              verbose=True)
# Out:
# - Computing reference shape
# - Normalizing images size: 0%
# - Normalizing images size: 0%
# - Normalizing images size: 0%
# - Normalizing images size: 0%
# - Normalizing images size: 0%
# - Normalizing images size: 0%
# - Normalizing images size: 0%
# - Normalizing images size: 0%
# - Normalizing images size: 1%
# - Normalizing images size: 1%
# - Normalizing images size: 1%
# - Normalizing images size: 1%
# - Normalizing images size: 1%
# - Normalizing images size: 1%
# - Normalizing images size: 1%
# - Normalizing images size: 1%
# - Normalizing images size: 2%
# - Normalizing images size: 2%
# - Normalizing images size: 2%
# - Normalizing images size: 2%
# - Normalizing images size: 2%
# - Normalizing images size: 2%
# - Normalizing images size: 2%
# - Normalizing images size: 2%
# - Normalizing images size: 3%
# - Normalizing images size: 3%
# - Normalizing images size: 3%
# - Normalizing images size: 3%
# - Normalizing images size: 3%
# - Normalizing images size: 3%
# ...

# %%
print pb_aam
# Out:
# Patch-Based Active Appearance Model
#  - 811 training images.
#  - Warp using ThinPlateSplines transform with 'scipy' interpolation.
#  - Gaussian pyramid with 2 levels and downscale factor of 2.
#    - Each level has a scaled shape model (reference frame).
#    - Patch size is 12W x 12H.
#    - Pyramid was applied on feature space.
#    - No features extracted. 1 channel per image.
#    - Level 1 (no downscale):
#      - Reference frame of length 4322 (4322 x 1C, 99W x 98H x 1C)
#      - 133 shape components (100.00% of variance)
#      - 810 appearance components (100.00% of variance)
#    - Level 2 (downscale by 2):
#      - Reference frame of length 1808 (1808 x 1C, 65W x 64H x 1C)
#      - 133 shape components (100.00% of variance)
#      - 810 appearance components (100.00% of variance)

# %%
from menpo.visualize import visualize_aam

visualize_aam(pb_aam)

# %% [markdown]
# ## Load test data

# %%
import menpo.io as mio
from menpo.landmark import labeller, ibug_face_68, ibug_face_68_trimesh

test_images = []
for i in mio.import_images('/data/PhD/DataBases/faces/lfpw/testset/', 
                           max_images=None, verbose=True):
    labeller(i, 'PTS', ibug_face_68)
    labeller(i, 'PTS', ibug_face_68_trimesh)
    i.crop_to_landmarks_proportion_inplace(0.5, group='ibug_face_68')
    if i.n_channels == 3:
        i = i.as_greyscale(mode='luminosity')
    test_images.append(i)
# Out:
# - Loading 224 assets: [                    ] 0%
# - Loading 224 assets: [                    ] 0%
# - Loading 224 assets: [                    ] 1%
# - Loading 224 assets: [                    ] 1%
# - Loading 224 assets: [                    ] 2%
# - Loading 224 assets: [                    ] 2%
# - Loading 224 assets: [                    ] 3%
# - Loading 224 assets: [                    ] 3%
# - Loading 224 assets: [                    ] 4%
# - Loading 224 assets: [                    ] 4%
# - Loading 224 assets: [                    ] 4%
# - Loading 224 assets: [=                   ] 5%
# - Loading 224 assets: [=                   ] 5%
# - Loading 224 assets: [=                   ] 6%
# - Loading 224 assets: [=                   ] 6%
# - Loading 224 assets: [=                   ] 7%
# - Loading 224 assets: [=                   ] 7%
# - Loading 224 assets: [=                   ] 8%
# - Loading 224 assets: [=                   ] 8%
# - Loading 224 assets: [=                   ] 8%
# ...

# %%
from menpo.visualize import browse_images

browse_images(test_images)

# %% [markdown]
# ## Build Fitters

# %%
from menpo.fitmultilevel.aam import LucasKanadeAAMFitter
                                              
fitter = LucasKanadeAAMFitter(aam, n_shape=[3, 6, 12], n_appearance=100)
print fitter
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-117-0270a9a02f1b> in <module>()
#       1 from menpo.fitmultilevel.aam import LucasKanadeAAMFitter
#       2
# ----> 3 fitter = LucasKanadeAAMFitter(aam, n_shape=[3, 6, 12], n_appearance=100)
#       4 print fitter
#
# /data/pythondev/src/menpo/menpo/fitmultilevel/aam/base.pyc in __init__(self, aam, algorithm, md_transform, global_transform, n_shape, n_appearance, **kwargs)
#     192                      md_transform=md_transform,
#     193                      global_transform=global_transform, n_shape=n_shape,
# --> 194                      n_appearance=n_appearance, **kwargs)
#     195
#     196     @property
#
# /data/pythondev/src/menpo/menpo/fitmultilevel/aam/base.pyc in _set_up(self, algorithm, residual, md_transform, global_transform, n_shape, n_appearance, **kwargs)
# ...

# %%
from menpo.fitmultilevel.aam import LucasKanadeAAMFitter
                                              
pb_fitter = LucasKanadeAAMFitter(pb_aam, n_shape=[4, 10], n_appearance=200)
print pb_fitter
# Out:
# Patch-Based Active Appearance Model Fitter
#  - Lucas-Kanade Alternating-IC
#  - Transform is OrthoMDTransform and residual is SSD.
#  - 811 training images.
#  - Gaussian pyramid with 2 levels and downscale factor of 2.
#    - Each level has a scaled shape model (reference frame).
#    - Pyramid was applied on feature space.
#    - No features extracted. 1 channel per image.
#    - Level 1 (no downscale):
#      - Reference frame of length 4322 (4322 x 1C, 99W x 98H x 1C)
#      - 14 motion components
#      - 400 active appearance components (99.25% of original variance)
#    - Level 2 (downscale by 2):
#      - Reference frame of length 1808 (1808 x 1C, 65W x 64H x 1C)
#      - 8 motion components
#      - 400 active appearance components (99.72% of original variance)

# %% [markdown]
# ## Fit test data

# %%
fitting_results = []
pb_fitting_results = []

for j, i in enumerate(test_images):
    gt_s = i.landmarks['ibug_face_68'].lms
    s = fitter.perturb_shape(gt_s, noise_std=0.03, rotation=True)
    
    #fr = fitter.fit(i, s, gt_shape=gt_s)
    pb_fr = pb_fitter.fit(i, s, gt_shape=gt_s)
    
    #fitting_results.append(fr)
    pb_fitting_results.append(pb_fr)
    
    print 'Image: ', j
    print 'aam-fitter:', fr
    print 'pb-aam-fitter:', pb_fr
# Out:
# Image:  0
# aam-fitter: Initial error: 0.0434
# Final error: 0.0264
# pb-aam-fitter: Initial error: 0.0594
# Final error: 0.0203
# Image:
#  1
# aam-fitter: Initial error: 0.0434
# Final error: 0.0264
# pb-aam-fitter: Initial error: 0.0535
# Final error: 0.0290
# Image:
#  2
# aam-fitter: Initial error: 0.0434
# Final error: 0.0264
# pb-aam-fitter: Initial error: 0.0437
# Final error: 0.0285
# Image:
#  3
# aam-fitter: Initial error: 0.0434
# Final error: 0.0264
# pb-aam-fitter: Initial error: 0.0783
# Final error: 0.0275
# Image:
#  4
# aam-fitter: Initial error: 0.0434
# Final error: 0.0264
# pb-aam-fitter: Initial error: 0.0779
# Final error: 0.0453
# Image:
#  5
# aam-fitter: Initial error: 0.0434
# Final error: 0.0264
# pb-aam-fitter: Initial error: 0.0503
# Final error: 0.0319
# Image:
#  6
# aam-fitter: Initial error: 0.0434
# Final error: 0.0264
# pb-aam-fitter: Initial error: 0.0736
# Final error: 0.0179
# Image:
#  7
# aam-fitter: Initial error: 0.0434
# ...

# %% [markdown]
# ## Compare CED graphs

# %%
initial_errors = [fr.initial_error() for fr in pb_fitting_results]

final_errors = [fr.final_error() for fr in fitting_results]
pb_final_errors = [pb_fr.final_error() for pb_fr in pb_fitting_results]

# %%
from menpo.visualize import plot_ced

plot_ced([final_errors, pb_final_errors], initial_errors=initial_errors)

# %%
fitted_images = [fr.fitted_image for fr in fitting_results]

# %%
from menpo.visualize import browse_fitted_images

browse_fitted_images(fitted_images)

# %%
pb_fitted_images = [pb_fr.fitted_image for pb_fr in pb_fitting_results]

# %%
from menpo.visualize import browse_fitted_images

browse_fitted_images(pb_fitted_images)
