of 811)
# Creating importer for <pybug.io.image.PILImporter object at 0x10c9b5690> (788 of 811)
# Creating importer for <pybug.io.image.PILImporter object at 0x10c9b56d0> (789 of 811)
# Creating importer for <pybug.io.image.PILImporter object at 0x10c9b5710> (790 of 811)
# Creating importer for <pybug.io.image.PILImporter object at 0x10c9b5750> (791 of 811)
# Creating importer for <pybug.io.image.PILImporter object at 0x10c9b5790> (792 of 811)
# Creating importer for <pybug.io.image.PILImporter object at 0x10c9b57d0> (793 of 811)
# Creating importer for <pybug.io.image.PILImporter object at 0x10c9b5810> (794 of 811)
# Creating importer for <pybug.io.image.PILImporter object at 0x10c9b5850> (795 of 811)
# Creating importer for <pybug.io.image.PILImporter object at 0x10c9b5890> (796 of 811)
# Creating importer for <pybug.io.image.PILImporter object at 0x10c9b58d0> (797 of 811)
# Creating importer for <pybug.io.image.PILImporter object at 0x10c9b5910> (798 of 811)
# Creating importer for <pybug.io.image.PILImporter object at 0x10c9b5950> (799 of 811)
# Creating importer for <pybug.io.image.PILImporter object at 0x10c9b5990> (800 of 811)
# Creating importer for <pybug.io.image.PILImporter object at 0x10c9b59d0> (801 of 811)
# Creating importer for <pybug.io.image.PILImporter object at 0x10c9b5a10> (802 of 811)
# Creating importer for <pybug.io.image.PILImporter object at 0x10c9b5a50> (803 of 811)
# Creating importer for <pybug.io.image.PILImporter object at 0x10c9b5a90> (804 of 811)
# Creating importer for <pybug.io.image.PILImporter object at 0x10c9b5ad0> (805 of 811)
# Creating importer for <pybug.io.image.PILImporter object at 0x10c9b5b10> (806 of 811)
# Creating importer for <pybug.io.image.PILImporter object at 0x10c9b5b50> (807 of 811)
# Creating importer for <pybug.io.image.PILImporter object at 0x10c9b5b90> (808 of 811)
# Creating importer for <pybug.io.image.PILImporter object at 0x10c9b5bd0> (809 of 811)
# Creating importer for <pybug.io.image.PILImporter object at 0x10c9b5c10> (810 of 811)
# Creating importer for <pybug.io.image.PILImporter object at 0x10c9b5c50> (811 of 811)

# %% [markdown]
# #### 2. Build AAMs

# %%
from pybug.activeappearancemodel.base import AAM
from pybug.activeappearancemodel.builder import aam_builder
from pybug.transform.tps import TPS
from pybug.landmark import ibug_68_trimesh

options = {'triangulation': {'function': ibug_68_trimesh, 'label': 'ibug_68_trimesh'},
           'features': {'type': 'hog', 'options': {'mode': 'sparse'}},
           'max_shape_components': 25,
           'max_appearance_components': 200,
           'n_levels': 2}


aam = aam_builder(images, **options)
# Out:
# - Cropping images
# - Compute reference shape
# - Rescaling images to reference shape
# - Building gaussian pyramid
# - Computing features
# - Building shape model
# Converged after 4 iterations with av. error 9.896260
# - Building reference frame
# - Building appearance models
#  - Level 0
#  - Level 1

# %% [markdown]
# #### 3. View Instance

# %%
aam.instance(np.random.randn(12), np.random.randn(200), level=1).view()

# %% [markdown]
# #### 4. Load Test Data

# %%
# load the training images of the LFPW database as landmarked images using the autoimporter
images = auto_import('/Users/joan/PhD/DataBases/ibug/*.jpg')
images = [i.as_greyscale() if type(i) is RGBImage else i for i in images]

# crop images around their landmarks
for i in images:
    i.crop_to_landmarks_proportion(0.2)
# Out:
# Found 135 files. (0/135) are importable
# Found 135 files. (135/135) are importable
# Creating importer for <pybug.io.image.PILImporter object at 0x116261a90> (1 of 135)
# Creating importer for <pybug.io.image.PILImporter object at 0x116261b50> (2 of 135)
# Creating importer for <pybug.io.image.PILImporter object at 0x116261490> (3 of 135)
# Creating importer for <pybug.io.image.PILImporter object at 0x116261690> (4 of 135)
# Creating importer for <pybug.io.image.PILImporter object at 0x116261650> (5 of 135)
# Creating importer for <pybug.io.image.PILImporter object at 0x116261dd0> (6 of 135)
# Creating importer for <pybug.io.image.PILImporter object at 0x116261450> (7 of 135)
# Creating importer for <pybug.io.image.PILImporter object at 0x1162616d0> (8 of 135)
# Creating importer for <pybug.io.image.PILImporter object at 0x1162619d0> (9 of 135)
# Creating importer for <pybug.io.image.PILImporter object at 0x116261b90> (10 of 135)
# Warning: More than one landmarks was found: ['image_014.pts', 'image_014_01.pts', 'image_014_02.pts']. Taking the first by default
# Creating importer for <pybug.io.image.PILImporter object at 0x1162610d0> (11 of 135)
# Creating importer for <pybug.io.image.PILImporter object at 0x116261910> (12 of 135)
# Creating importer for <pybug.io.image.PILImporter object at 0x1162618d0> (13 of 135)
# Creating importer for <pybug.io.image.PILImporter object at 0x116261c10> (14 of 135)
# Creating importer for <pybug.io.image.PILImporter object at 0x116261850> (15 of 135)
# Creating importer for <pybug.io.image.PILImporter object at 0x116261e10> (16 of 135)
# Creating importer for <pybug.io.image.PILImporter object at 0x116261d10> (17 of 135)
# Creating importer for <pybug.io.image.PILImporter object at 0x116261f10> (18 of 135)
# Creating importer for <pybug.io.image.PILImporter object at 0x116261590> (19 of 135)
# Creating importer for <pybug.io.image.PILImporter object at 0x116261f50> (20 of 135)
# Creating importer for <pybug.io.image.PILImporter object at 0x116261d50> (21 of 135)
# Creating importer for <pybug.io.image.PILImporter object at 0x116261350> (22 of 135)
# Creating importer for <pybug.io.image.PILImporter object at 0x116261e50> (23 of 135)
# Creating importer for <pybug.io.image.PILImporter object at 0x116261a10> (24 of 135)
# Creating importer for <pybug.io.image.PILImporter object at 0x116261a50> (25 of 135)
# Creating importer for <pybug.io.image.PILImporter object at 0x116261250> (26 of 135)
# Creating importer for <pybug.io.image.PILImporter object at 0x116261510> (27 of 135)
# Creating importer for <pybug.io.image.PILImporter object at 0x116261c50> (28 of 135)
# Creating importer for <pybug.io.image.PILImporter object at 0x1162611d0> (29 of 135)
# Creating importer for <pybug.io.image.PILImporter object at 0x116261e90> (30 of 135)
# Creating importer for <pybug.io.image.PILImporter object at 0x116261fd0> (31 of 135)
# Creating importer for <pybug.io.image.PILImporter object at 0x116261390> (32 of 135)
# Creating importer for <pybug.io.image.PILImporter object at 0x116261750> (33 of 135)
# Creating importer for <pybug.io.image.PILImporter object at 0x116261890> (34 of 135)
# Creating importer for <pybug.io.image.PILImporter object at 0x116261b10> (35 of 135)
# Creating importer for <pybug.io.image.PILImporter object at 0x116261cd0> (36 of 135)
# Creating importer for <pybug.io.image.PILImporter object at 0x116261610> (37 of 135)
# Creating importer for <pybug.io.image.PILImporter object at 0x25d6e4650> (38 of 135)
# Creating importer for <pybug.io.image.PILImporter object at 0x25d6e43d0> (39 of 135)
# Creating importer for <pybug.io.image.PILImporter object at 0x25d6e48d0> (40 of 135)
# Creating importer for <pybug.io.image.PILImporter object at 0x25d6e4710> (41 of 135)
# Creating importer for <pybug.io.image.PILImporter object at 0x25d6e4290> (42 of 135)
# Creating importer for <pybug.io.image.PILImporter object at 0x25d6e4310> (43 of 135)
# Creating importer for <pybug.io.image.PILImporter object at 0x25d6e4610> (44 of 135)
# Creating importer for <pybug.io.image.PILImporter object at 0x25d6e4490> (45 of 135)
# Creating importer for <pybug.io.image.PILImporter object at 0x25d6e4fd0> (46 of 135)
# Creating importer for <pybug.io.image.PILImporter object at 0x25d6e46d0> (47 of 135)
# Warning: More than one landmarks was found: ['image_050.pts', 'image_050_01.pts']. Taking the first by default
# Creating importer for <pybug.io.image.PILImporter object at 0x25d6e4210> (48 of 135)
# Creating importer for <pybug.io.image.PILImporter object at 0x25d6e44d0> (49 of 135)
# Creating importer for <pybug.io.image.PILImporter object at 0x25d6e4c10> (50 of 135)
# Creating importer for <pybug.io.image.PILImporter object at 0x25d6e4350> (51 of 135)
# Creating importer for <pybug.io.image.PILImporter object at 0x25d6e4050> (52 of 135)
# Creating importer for <pybug.io.image.PILImporter object at 0x25d6e4bd0> (53 of 135)
# Creating importer for <pybug.io.image.PILImporter object at 0x25d6e4a90> (54 of 135)
# Creating importer for <pybug.io.image.PILImporter object at 0x25d6e4e10> (55 of 135)
# Creating importer for <pybug.io.image.PILImporter object at 0x25d6e4d90> (56 of 135)
# Creating importer for <pybug.io.image.PILImporter object at 0x25d6e
of 135)
# Creating importer for <pybug.io.image.PILImporter object at 0x10c9d9510> (134 of 135)
# Creating importer for <pybug.io.image.PILImporter object at 0x10c9d9210> (135 of 135)

# %%
images[6].landmarks['PTS'].view()

# %% [markdown]
# #### 5. Fit AAM to Test Data

# %%
aam.initialize_lk(n_shape=[3, 6, 12], n_appearance=[250, 250, 250])

# %%
fitted_transforms = aam.lk_fit_landmarked_database(images, runs=1, noise_std=0.0, verbose=True)
# Out:
# - fitting image 1 of 224
#  - run 1 of 1 with error: 0.0130500909017
# - fitting image 2 of 224
#  - run 1 of 1 with error: 0.0162439413055
# - fitting image 3 of 224
#  - run 1 of 1 with error: 0.0239955587664
# - fitting image 4 of 224
#  - run 1 of 1 with error: 0.0169450220609
# - fitting image 5 of 224
#  - run 1 of 1 with error: 0.0426750133551
# - fitting image 6 of 224
#  - run 1 of 1 with error: 0.0194688471304
# - fitting image 7 of 224
#  - run 1 of 1 with error: 0.0150790103984
# - fitting image 8 of 224
#  - run 1 of 1 with error: 0.0223876034203
# - fitting image 9 of 224
#  - run 1 of 1 with error: 0.0280696996207
# - fitting image 10 of 224
#  - run 1 of 1 with error: 0.0182996483803
# - fitting image 11 of 224
#  - run 1 of 1 with error: 0.0461714854297
# - fitting image 12 of 224
#  - run 1 of 1 with error: 0.0311993146161
# - fitting image 13 of 224
#  - run 1 of 1 with error: 0.0148898833273
# - fitting image 14 of 224
#  - run 1 of 1 with error: 0.0146219522947
# - fitting image 15 of 224
#  - run 1 of 1 with error: 0.0216885051329
# - fitting image 16 of 224
#  - run 1 of 1 with error: 0.0179264675281
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-b0c2b6342d19> in <module>()
# ----> 1 fitted_transforms = aam.lk_fit_landmarked_database(images, runs=1, noise_std=0.0, verbose=True, view=True)
#
# /Users/joan/.virtualenvs/pybug/src/pybug/pybug/activeappearancemodel/base.py in lk_fit_landmarked_database(self, images, runs, noise_std, group, max_iters, verbose, view)
#     308                                              noise_std=noise_std,
#     309                                             group=group, max_iters=max_iters,
# --> 310                                             verbose=verbose, view=view))
#     311
#     312         return optimal_transforms
#
# /Users/joan/.virtualenvs/pybug/src/pybug/pybug/activeappearancemodel/base.py in lk_fit_landmarked_image(self, image, runs, noise_std, group, max_iters, verbose, view)
#     275             if view:
#     276                 image.landmarks['initial_{}'.format(j)].view()
# --> 277                 image.landmarks['fitted_{}'.format(j)].view()
#     278                 plt.show()
#     279
#
# /Users/joan/.virtualenvs/pybug/src/pybug/pybug/visualize/base.pyc in view(self, **kwargs)
#     154             The renderer instantiated.
#     155         """
# --> 156         return self._view(**kwargs)
#     157
#     158     @abc.abstractmethod
#
# /Users/joan/.virtualenvs/pybug/src/pybug/pybug/landmark/base.pyc in _view(self, figure_id, new_figure, include_labels, **kwargs)
#     418                                          self._labels_to_masks, self._target)
#     419
# --> 420         return landmark_viewer.render(include_labels=include_labels, **kwargs)
#
# /Users/joan/.virtualenvs/pybug/src/pybug/pybug/visualize/base.pyc in render(self, **kwargs)
#     264                     self.figure_id, self.new_figure,
#     265                     self.group_label, self.pointcloud,
# --> 266                     self.labels_to_masks).render(**kwargs)
#     267             else:
#     268                 return LandmarkViewer2d(self.figure_id, self.new_figure,
#
# /Users/joan/.virtualenvs/pybug/src/pybug/pybug/visualize/base.pyc in render(self, **kwargs)
#      63             Pointer to ``self``.
#      64         """
# ---> 65         return self._render(**kwargs)
#      66
#      67     @abc.abstractmethod
#
# /Users/joan/.virtualenvs/pybug/src/pybug/pybug/visualize/viewmatplotlib.pyc in _render(self, include_labels, **kwargs)
#     238
#     239     def _render(self, include_labels=True, **kwargs):
# --> 240         self._plot_landmarks(include_labels, True, **kwargs)
#     241         return self
#     242
#
# /Users/joan/.virtualenvs/pybug/src/pybug/pybug/visualize/viewmatplotlib.pyc in _plot_landmarks(self, include_labels, image_view, **kwargs)
#     207             kwargs['colour_array'] = [colours[:, i]] * np.sum(pc.points)
#     208             kwargs['label'] = '{0}_{1}'.format(self.group_label, label)
# --> 209             pc.view_on(self.figure_id, image_view=image_view, **kwargs)
#     210
#     211             if include_labels:
#
# /Users/joan/.virtualenvs/pybug/src/pybug/pybug/visualize/base.pyc in view_on(self, figure_id, **kwargs)
#     120             The renderer instantiated.
#     121         """
# --> 122         return self._view(figure_id=figure_id, **kwargs)
#     123
#     124     def view_new(self, **kwargs):
#
# /Users/joan/.virtualenvs/pybug/src/pybug/pybug/shape/pointcloud.pyc in _view(self, figure_id, new_figure, **kwargs)
#     149     def _view(self, figure_id=None, new_figure=False, **kwargs):
#     150         return PointCloudViewer(figure_id, new_figure,
# --> 151                                 self.points).render(**kwargs)
#     152
#     153     def _transform_self_inplace(self, transform):
#
# /Users/joan/.virtualenvs/pybug/src/pybug/pybug/visualize/base.pyc in render(self, **kwargs)
#     320         if self.points.shape[1] == 2:
#     321             return PointCloudViewer2d(self.figure_id, self.new_figure,
# --> 322                                       self.points).render(**kwargs)
#     323         elif self.points.shape[1] == 3:
#     324             return PointCloudViewer3d(self.figure_id, self.new_figure,
#
# /Users/joan/.virtualenvs/pybug/src/pybug/pybug/visualize/base.pyc in render(self, **kwargs)
#      63             Pointer to ``self``.
#      64         """
# ---> 65         return self._render(**kwargs)
#      66
#      67     @abc.abstractmethod
#
# /Users/joan/.virtualenvs/pybug/src/pybug/pybug/visualize/viewmatplotlib.pyc in _render(self, image_view, cmap, colour_array, label, **kwargs)
#     155         points = self.points[:, ::-1] if image_view else self.points
#     156         plt.scatter(points[:, 0], points[:, 1], cmap=cmap,
# --> 157                     c=colour_array, label=label)
#     158         return self
#     159
#
# /usr/local/Cellar/python/2.7.6/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/matplotlib/pyplot.pyc in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, hold, **kwargs)
#    3085         ret = ax.scatter(x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    3086                          vmin=vmin, vmax=vmax, alpha=alpha,
# -> 3087                          linewidths=linewidths, verts=verts, **kwargs)
#    3088         draw_if_interactive()
#    3089     finally:
#
# /usr/local/Cellar/python/2.7.6/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/matplotlib/axes.pyc in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, **kwargs)
#    6276                 colors = None  # use cmap, norm after collection is created
#    6277             else:
# -> 6278                 colors = mcolors.colorConverter.to_rgba_array(c, alpha)
#    6279
#    6280         faceted = kwargs.pop('faceted', None)
#
# /usr/local/Cellar/python/2.7.6/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/matplotlib/colors.pyc in to_rgba_array(self, c, alpha)
#     409             result = np.zeros((nc, 4), dtype=np.float)
#     410             for i, cc in enumerate(c):
# --> 411                 result[i] = self.to_rgba(cc, alpha)
#     412             return result
#     413
#
# /usr/local/Cellar/python/2.7.6/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/matplotlib/colors.pyc in to_rgba(self, arg, alpha)
#     341
#     342         try:
# --> 343             if not cbook.is_string_like(arg) and cbook.iterable(arg):
#     344                 if len(arg) == 4:
#     345                     if [x for x in arg if (float(x) < 0) or (x > 1)]:
#
# /usr/local/Cellar/python/2.7.6/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/matplotlib/cbook.pyc in is_string_like(obj)
#     677             return False
#     678     try:
# --> 679         obj + ''
#     680     except:
#     681         return False
#
# KeyboardInterrupt:

# %% [markdown]
# #### 6. Evaluate Performance

# %%
from pybug.activeappearancemodel.accuracy import plot_ced
from pybug.transform.affine import UniformScale
from __future__ import division

original_landmarks = [i.landmarks['PTS'].lms for i in images]

fitted_landmarks = []
for ft in fitted_transforms:
    for f in ft:
        fitted_landmarks.append(UniformScale(1,2).apply(f[-1].target))

errors = plot_ced(fitted_landmarks, original_landmarks, label='AIC')[0]

fitted_landmarks = []
for ft in fitted_transforms:
    for f in ft:
        fitted_landmarks.append(UniformScale(2,2).apply(f[-2].target))

plot_ced(fitted_landmarks, original_landmarks, label='AIC')

fitted_landmarks = []
for ft in fitted_transforms:
    for f in ft:
        fitted_landmarks.append(UniformScale(4,2).apply(f[-3].target))

plot_ced(fitted_landmarks, original_landmarks, label='AIC');

# %%
np.count_nonzero(np.array(errors) < 0.03) / len(images)
# Out:
# 0.5669642857142857

# %%
aam.

# %%
aam.appearance_model_pyramid = [aam.appearance_model_pyramid]

# %%
from pybug.lucaskanade import AlternatingSymmetricCompositional, AlternatingBidirectionalCompositional, ProbabilisticSymmetricCompositional, ProbabilisticBidirectionalCompositional, ProjectOutSymmetricCompositional
from pybug.lucaskanade.residual import Huber, GemanMcClure, L1L2

aam.initialize_lk(n_shape=[3, 6, 6], n_appearance=[200, 200, 200], lk_algorithm=AlternatingSymmetricCompositional)

# %%
fitted_transforms = aam.lk_fit_landmarked_database(images, runs=1, noise_std=0.00, verbose=True, view=True, max_iters=20)
# Out:
# - fitting image 1 of 135
#  - run 1 of 1 with error: 0.0702212370029
# - fitting image 2 of 135
#  - run 1 of 1 with error: 0.040795527614

# %%
# %load_ext autoreload
# %autoreload 2

# %%
aam.n_levels
# Out:
# 1

# %%
from pybug.activeappearancemodel.builder import compute_features

features = [compute_features(i, 'hog', mode='sparse') for i in images]

# %%
features[0].landmarks['PTS'].view(channels=6)

# %%
from pybug.transform.affine import AffineTransform

images[0].landmarks['new'] = AffineTransform.align(features[0].landmarks['PTS'].lms, images[0].landmarks['PTS'].lms).apply(features[0].landmarks['PTS'].lms)

# %%
images[0].landmarks['new'].view()

# %%
# %timeit images[0].gradient()
# Out:
# 100 loops, best of 3: 3.11 ms per loop

# %%
# %timeit features[0].gradient()
# Out:
# 100 loops, best of 3: 3.99 ms per loop
