# %% [markdown]
# # Test pybug.aam.AAM fitting accuracy

# %%
import pybug.io as pio
from pybug.landmark import labeller, ibug_68_trimesh

training_images = []
# load landmarked imarges
for i in pio.import_images('/vol/atlas/databases/lfpw/trainset/*.png',
                     max_images=811):
    i.crop_to_landmarks_proportion(0.2)
    if i.n_channels == 3:
        training_images.append(i.as_greyscale(mode='luminosity'))
    else:
        training_images.append(i)

# %%
labeller(training_images, 'PTS', ibug_68_trimesh);

# %%
# %matplotlib inline
#visualize the first image
training_images[0].landmarks['PTS'].view_new()

# %%
from pybug.aam.base import aam_builder
from pybug.transform.piecewiseaffine import PiecewiseAffineTransform

# set options
build_options = {'group': 'PTS',  
                 'trilist': training_images[0].landmarks['ibug_68_trimesh'].lms.trilist,
                 'n_levels': 3,
                 'downscale': 1.5,
                 'features': ('igo', {'double_angles': True}),
                 'max_shape_components': 25,
                 'max_appearance_components': 250}
# build aam
aam = aam_builder(training_images, **build_options)
# Out:
# - Computing reference shape
# - Rescaling images to reference shape
# - Setting gaussian pyramid generators
# - Computing features
# - Building shape model
# Converged after 5 iterations with av. error 79.170078
# - Building reference frame
# - Building model pyramids
#  - Level 0
#  - Computing transforms
#  - Warping images
#  - Building appearance model
#  - Level 1
#  - Computing features
#  - Building shape model
#  - Computing transforms
#  - Warping images
#  - Building appearance model
#  - Level 2
#  - Computing features
#  - Building shape model
#  - Computing transforms
#  - Warping images
#  - Building appearance model

# %%
import numpy as np

aam.shape_model_pyramid[0]._components = np.real(aam.shape_model_pyramid[0]._components)
aam.shape_model_pyramid[1]._components = np.real(aam.shape_model_pyramid[1]._components)
aam.shape_model_pyramid[2]._components = np.real(aam.shape_model_pyramid[2]._components)
aam.shape_model_pyramid[0]._eigenvalues = np.real(aam.shape_model_pyramid[0]._eigenvalues)
aam.shape_model_pyramid[1]._eigenvalues = np.real(aam.shape_model_pyramid[1]._eigenvalues)
aam.shape_model_pyramid[2]._eigenvalues = np.real(aam.shape_model_pyramid[2]._eigenvalues)

# low resolution level
# %matplotlib inline
aam.instance(level=0).view() 
# middle resolution level
aam.instance(level=1).view_new()
# highest resolution level
aam.instance().view_new()

# %%
import pybug.io as pio
from pybug.landmark import labeller, ibug_68_points, ibug_68_trimesh

test_images = []
# load landmarked imarges
for i in pio.import_images('/vol/atlas/databases/lfpw/testset/*.png',
                     max_images=224):
    i.crop_to_landmarks_proportion(0.2)
    if i.n_channels == 3:
        test_images.append(i.as_greyscale(mode='luminosity'))
    else:
        test_images.append(i)

# %%
from pybug.lucaskanade.appearance import AlternatingInverseCompositional
from pybug.lucaskanade.residual import LSIntensity
from pybug.transform.modeldriven import OrthoMDTransform
from pybug.transform.affine import SimilarityTransform

# set fitting options. As before we favour 
# clarity by explicitely stating all possible
# options
fitting_setting_options = \
    {'lk_algorithm': AlternatingInverseCompositional,
     'residual': (LSIntensity,),
     'transform_cls': (OrthoMDTransform, SimilarityTransform),
     'n_shape': [3, 6, 12], 
     'n_appearance': [250, 250, 250]}

# initialize Lucas-Kanade aam fitting
aam.initialize_lk(**fitting_setting_options)

# %%
fitting_options = {'group': 'PTS',
                   'label': 'all',
                   'runs': 1, 
                   'noise_std': 0.0,
                   'max_iters': 20,
                   'rotation': False,
                   'verbose': True, 
                   'view': True}

# fit test images
fitting_list = aam.lk_fit_landmarked_database(test_images, **fitting_options)
# Out:
# - fitting image 1 of 224
# error: 0.0147344167041
# - fitting image 2 of 224
# error: 0.0168724329527
# - fitting image 3 of 224
# error: 0.0252349996316
# - fitting image 4 of 224
# error: 0.0168944008572
# - fitting image 5 of 224
# error: 0.0347775754176
# - fitting image 6 of 224
# error: 0.0260092106076
# - fitting image 7 of 224
# error: 0.0163251941188
# - fitting image 8 of 224
# error: 0.0210116139554
# - fitting image 9 of 224
# error: 0.0300527650481
# - fitting image 10 of 224
# error: 0.0178812657609
# - fitting image 11 of 224
# error: 0.0552969431478
# - fitting image 12 of 224
# error: 0.0287423010649
# - fitting image 13 of 224
# error: 0.0157002502888
# - fitting image 14 of 224
# error: 0.0173197586992
# - fitting image 15 of 224
# error: 0.0277723908533
# - fitting image 16 of 224
# error: 0.0183224440905
# - fitting image 17 of 224
# error: 0.0158074304894
# - fitting image 18 of 224
# error: 0.0206102944819
# - fitting image 19 of 224
# error: 0.0164338528482
# - fitting image 20 of 224
# error: 0.0204178204481
# - fitting image 21 of 224
# error: 0.0153551530738
# - fitting image 22 of 224
# error: 0.0243333084227
# - fitting image 23 of 224
# error: 0.0186078960437
# - fitting image 24 of 224
# error: 0.0199879818014
# - fitting image 25 of 224
# error: 0.0277134984206
# - fitting image 26 of 224
# error: 0.0233054410159
# - fitting image 27 of 224
# error: 0.0220043148478
# - fitting image 28 of 224
# error: 0.0259566314548
# - fitting image 29 of 224
# error: 0.0221206278031
# - fitting image 30 of 224
# error: 0.0168849156001
# - fitting image 31 of 224
# error: 0.0137046354619
# - fitting image 32 of 224
# error: 0.0137078467894
# - fitting image 33 of 224
# error: 0.0181048844895
# - fitting image 34 of 224
# error: 0.0194853100014
# - fitting image 35 of 224
# error: 0.0278586071904
# - fitting image 36 of 224
# error: 0.0200148827439
# - fitting image 37 of 224
# error: 0.0176683603193
# - fitting image 38 of 224
# error: 0.0203986905721
# - fitting image 39 of 224
# error: 0.0185619759308
# - fitting image 40 of 224
# error: 0.052713798419
# - fitting image 41 of 224
# error: 0.0155306082579
# - fitting image 42 of 224
# error: 0.0275573390648
# - fitting image 43 of 224
# error: 0.0215018746214
# - fitting image 44 of 224
# error: 0.0275150658207
# - fitting image 45 of 224
# error: 0.0321815454209
# - fitting image 46 of 224
# error: 0.0222007800553
# - fitting image 47 of 224
# error: 0.0610383097993
# - fitting image 48 of 224
# error: 0.0165393054001
# - fitting image 49 of 224
# error: 0.033445197078
# - fitting image 50 of 224
# error: 0.0266131442438
# - fitting image 51 of 224
# error: 0.0175334111945
# - fitting image 52 of 224
# error: 0.0346781943365
# - fitting image 53 of 224
# error: 0.0235560703229
# - fitting image 54 of 224
# error: 0.0499631355206
# - fitting image 55 of 224
# error: 0.0249372484968
# - fitting image 56 of 224
# error: 0.0243875287881
# - fitting image 57 of 224
# error: 0.0222318310698
# - fitting image 58 of 224
# error: 0.0182259849011
# - fitting image 59 of 224
# error: 0.0238814016506
# - fitting image 60 of 224
# error: 0.0197609483375
# - fitting image 61 of 224
# error: 0.0132683800719
# - fitting image 62 of 224
# error: 0.0383640043843
# - fitting image 63 of 224
# error: 0.0181896014097
# - fitting image 64 of 224
# error: 0.026943625733
# - fitting image 65 of 224
# error: 0.0170633769932
# - fitting image 66 of 224
# error: 0.0238093468311
# - fitting image 67 of 224
# error: 0.100527531174
# - fitting image 68 of 224
# error: 0.0517432416885
# - fitting image 69 of 224
# error: 0.0156249345028
# - fitting image 70 of 224
# error: 0.028602488832
# - fitting image 71 of 224
# error: 0.0191230625961
# - fitting image 72 of 224
# error: 0.0231846421859
# - fitting image 73 of 224
# error: 0.0130104673086
# - fitting image 74 of 224
# error: 0.025314934947
# - fitting image 75 of 224
# error: 0.0214921747608
# - fitting image 76 of 224
# error: 0.0170528462491
# - fitting image 77 of 224
# error: 0.015618880366
# - fitting image 78 of 224
# error: 0.018742958698
# - fitting image 79 of 224
# error: 0.0166115914911
# - fitting image 80 of 224
# error: 0.019450688768
# - fitting image 81 of 224
# error: 0.0222867061181
# - fitting image 82 of 224
# error: 0.0142454208207
# - fitting image 83 of 224
# error: 0.0317275112676
# - fitting image 84 of 224
# error: 0.0240062390084
# - fitting image 85 of 224
# error: 0.0232663636616
# - fitting image 86 of 224
# error: 0.0217630704047
# - fitting image 87 of 224
# error: 0.0258529764819
# - fitting image 88 of 224
# error: 0.0163885998721
# - fitting image 89 of 224
# error: 0.0196808534338
# - fitting image 90 of 224
# error: 0.0180203156828
# - fitting image 91 of 224
# error: 0.0173622867045
# - fitting image 92 of 224
# error: 0.0205277773362
# - fitting image 93 of 224
# error: 0.0200180355563
# - fitting image 94 of 224
# error: 0.0133775984877
# - fitting image 95 of 224
# error: 0.0231312527838
# - fitting image 96 of 224
# error: 0.0238556043184
# - fitting image 97 of 224
# error: 0.0223019311948
# - fitting image 98 of 224
# error: 0.0135124940936
# - fitting image 99 of 224
# error: 0.0244954306974
# - fitting image 100 of 224
# error: 0.0228589227725
# - fitting image 101 of 224
# error: 0.029239574826
# - fitting image 102 of 224
# error: 0.024784918678
# - fitting image 103 of 224
# error: 0.0182241807316
# - fitting image 104 of 224
# error: 0.0407148850728
# - fitting image 105 of 224
# error: 0.0215659820393
# - fitting image 106 of 224
# error: 0.0163631726267
# - fitting image 107 of 224
# error: 0.020205570712
# - fitting image 108 of 224
# error: 0.0483281217879
# - fitting image 109 of 224
# error: 0.0220738188105
# - fitting image 110 of 224
# error: 0.0196286350715
# - fitting image 111 of 224
# error: 0.0376431882574
# - fitting image 112 of 224
# error: 0.030324682752
# - fitting image 113 of 224
# error: 0.0200357376903
# - fitting image 114 of 224
# error: 0.0307988519875
# - fitting image 115 of 224
# error: 0.030226269972
# - fitting image 116 of 224
# error: 0.0153227484699
# - fitting image 117 of 224
# error: 0.0231138676108
# - fitting image 118 of 224
# error: 0.0176775774329
# - fitting image 119 of 224
# error: 0.0289000323318
# - fitting image 120 of 224
# error: 0.0326069889899
# - fitting image 121 of 224
# error: 0.0166684698289
# - fitting image 122 of 224
# error: 0.0210755136216
# - fitting image 123 of 224
# error: 0.0261091982758
# - fitting image 124 of 224
# error: 0.0255825794573
# - fitting image 125 of 224
# error: 0.0140883455908
# - fitting image 126 of 224
# error: 0.0161329399641
# - fitting image 127 of 224
# error: 0.0570340350449
# - fitting image 128 of 224
# error: 0.0486364878388
# - fitting image 129 of 224
# error: 0.0200162285699
# - fitting image 130 of 224
# error: 0.0210369439954
# - fitting image 131 of 224
# error: 0.0221112959476
# - fitting image 132 of 224
# error: 0.0225064939218
# - fitting image 133 of 224
# error: 0.0175332812715
# - fitting image 134 of 224
# error: 0.0188329428131
# - fitting image 135 of 224
# error: 0.0217119578271
# - fitting image 136 of 224
# error: 0.0218273168909
# - fitting image 137 of 224
# error: 0.0595697239348
# - fitting image 138 of 224
# error: 0.0415032441937
# - fitting image 139 of 224
# error: 0.0200814663743
# - fitting image 140 of 224
# error: 0.0654841154836
# - fitting image 141 of 224
# error: 0.0389425697638
# - fitting image 142 of 224
# error: 0.021202622456
# - fitting image 143 of 224
# error: 0.0301540922764
# - fitting image 144 of 224
# error: 0.0261260356366
# - fitting image 145 of 224
# error: 0.0324260109148
# - fitting image 146 of 224
# error: 0.0179002591149
# - fitting image 147 of 224
# error: 0.0411398842726
# - fitting image 148 of 224
# error: 0.024248395949
# - fitting image 149 of 224
# error: 0.0186449466781
# - fitting image 150 of 224
# error: 0.0185400308665
# - fitting image 151 of 224
# error: 0.0171151826222
# - fitting image 152 of 224
# error: 0.0291219396319
# - fitting image 153 of 224
# error: 0.0181267763189
# - fitting image 154 of 224
# error: 0.0342261487477
# - fitting image 155 of 224
# error: 0.0435511479644
# - fitting image 156 of 224
# error: 0.0259303074209
# - fitting image 157 of 224
# error: 0.0185977362112
# - fitting image 158 of 224
# error: 0.0243600130004
# - fitting image 159 of 224
# error: 0.0157382409667
# - fitting image 160 of 224
# error: 0.0282463374082
# - fitting image 161 of 224
# error: 0.0325990287237
# - fitting image 162 of 224
# error: 0.0252080784002
# - fitting image 163 of 224
# error: 0.0248539287683
# - fitting image 164 of 224
# error: 0.0300427779482
# - fitting image 165 of 224
# error: 0.0222475168677
# - fitting image 166 of 224
# error: 0.032277974224
# - fitting image 167 of 224
# error: 0.0301204501868
# - fitting image 168 of 224
# error: 0.0230791235566
# - fitting image 169 of 224
# error: 0.0264354234642
# - fitting image 170 of 224
# error: 0.0210427872647
# - fitting image 171 of 224
# error: 0.0180430198324
# - fitting image 172 of 224
# error: 0.0933197899088
# - fitting image 173 of 224
# error: 0.0223581998338
# - fitting image 174 of 224
# error: 0.0399089063065
# - fitting image 175 of 224
# error: 0.0171222847766
# - fitting image 176 of 224
# error: 0.0646394130217
# - fitting image 177 of 224
# error: 0.0174904546431
# - fitting image 178 of 224
# error: 0.0176702094282
# - fitting image 179 of 224
# error: 0.0397849528824
# - fitting image 180 of 224
# error: 0.019122871578
# - fitting image 181 of 224
# error: 0.0238002916854
# - fitting image 182 of 224
# error: 0.0286008718186
# - fitting image 183 of 224
# error: 0.0201834458438
# - fitting image 184 of 224
# error: 0.0183561159733
# - fitting image 185 of 224
# error: 0.0262878948776
# - fitting image 186 of 224
# error: 0.0261367133215
# - fitting image 187 of 224
# error: 0.0200783605251
# - fitting image 188 of 224
# error: 0.024746646536
# - fitting image 189 of 224
# error: 0.0162605083256
# - fitting image 190 of 224
# error: 0.0214450178389
# - fitting image 191 of 224
# error: 0.0195999341002
# - fitting image 192 of 224
# error: 0.028672129878
# - fitting image 193 of 224
# error: 0.0305312306578
# - fitting image 194 of 224
# error: 0.0155244475504
# - fitting image 195 of 224
# error: 0.0163364679423
# - fitting image 196 of 224
# error: 0.0330254892837
# - fitting image 197 of 224
# error: 0.0194179916069
# - fitting image 198 of 224
# error: 0.0271455979783
# - fitting image 199 of 224
# error: 0.0238095500923
# - fitting image 200 of 224
# error: 0.0191692734706
# - fitting image 201 of 224
# error: 0.029993038794
# - fitting image 202 of 224
# error: 0.0220817802841
# - fitting image 203 of 224
# error: 0.022138648679
# - fitting image 204 of 224
# error: 0.0223167368523
# - fitting image 205 of 224
# error: 0.0182424022231
# - fitting image 206 of 224
# error: 0.0371120337037
# - fitting image 207 of 224
# error: 0.0362064053122
# - fitting image 208 of 224
# error: 0.0204513467031
# - fitting image 209 of 224
# error: 0.0161489396735
# - fitting image 210 of 224
# error: 0.0238730754784
# - fitting image 211 of 224
# error: 0.0211714500372
# - fitting image 212 of 224
# error: 0.0175881116631
# - fitting image 213 of 224
# error: 0.0183419721565
# - fitting image 214 of 224
# error: 0.0193250847862
# - fitting image 215 of 224
# error: 0.01817210487
# - fitting image 216 of 224
# error: 0.0142337678681
# - fitting image 217 of 224
# error: 0.0136925245462
# - fitting image 218 of 224
# error: 0.0191696233476
# - fitting image 219 of 224
# error: 0.0120586990846
# - fitting image 220 of 224
# error: 0.0385114634713
# - fitting image 221 of 224
# error: 0.0160176684383
# - fitting image 222 of 224
# error: 0.0143942131361
# - fitting image 223 of 224
# error: 0.0142701185305
# - fitting image 224 of 224
# error: 0.0241994941763

# %%
# %matplotlib inline
fitting_list.plot_error_dist(color='r', marker='o')

# %%
# %matplotlib wx
fitting_list.plot_cumulative_error_dist(color='r', marker='o')

# %%
# %matplotlib wx
aam_fitting = fitting_list[219]
aam_fitting[0].view_warped_images()

# %%
# %matplotlib wx
aam_fitting[0].view_final_fitting()

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
breakingbad = pio.import_builtin_asset('breakingbad.jpg')
breakingbad = breakingbad.as_greyscale(mode='luminosity')
# %matplotlib inline
breakingbad.crop_to_landmarks_proportion(0.2, group='PTS')
breakingbad.landmarks['PTS'].view()

# %%
# fit test images
fitting_list = aam.lk_fit_landmarked_image(breakingbad, **fitting_options)
# Out:
# error: 0.140877025577

# %%
# %matplotlib wx
aam_fitting = fitting_list[0]
aam_fitting.view_final_fitting()
