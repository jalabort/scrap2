# %%
# %matplotlib inline
# %pylab inline
import numpy as np
from menpo.io import import_builtin_asset

img = import_builtin_asset('breakingbad.jpg')
gs_img = img.as_greyscale()
gs_img.crop_to_landmarks_proportion_inplace(0.5)
down_gs_img = gs_img.rescale_landmarks_to_diagonal_range(200)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
img.view()
gs_img.view_new()
down_gs_img.view_new()

# %%
# %timeit down_gs_img.build_mask_around_landmarks(patch_size=(16, 16), group='PTS')
# Out:
# 100 loops, best of 3: 7.4 ms per loop

# %%
down_gs_img.view()
