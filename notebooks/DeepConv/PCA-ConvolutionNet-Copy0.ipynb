# %%
import menpo.io as mio

# load training images
training_images = []
for i in mio.import_images('/data/PhD/DataBases/lfpw/trainset/*', max_images=20, verbose=True):
    # crop image
    i.crop_to_landmarks_proportion_inplace(0.1)
    # convert it to grayscale if needed
    if i.n_channels == 3:
        i = i.as_greyscale(mode='luminosity')
    # append it to the list
    training_images.append(i)
# Out:
# - Loading 20 assets: [=                   ] 5%
# - Loading 20 assets: [==                  ] 10%
# - Loading 20 assets: [===                 ] 15%
# - Loading 20 assets: [====                ] 20%
# - Loading 20 assets: [=====               ] 25%
# - Loading 20 assets: [======              ] 30%
# - Loading 20 assets: [=======             ] 35%
# - Loading 20 assets: [========            ] 40%
# - Loading 20 assets: [=========           ] 45%
# - Loading 20 assets: [==========          ] 50%
# - Loading 20 assets: [===========         ] 55%
# - Loading 20 assets: [============        ] 60%
# - Loading 20 assets: [=============       ] 65%
# - Loading 20 assets: [==============      ] 70%
# - Loading 20 assets: [===============     ] 75%
# - Loading 20 assets: [================    ] 80%
# - Loading 20 assets: [=================   ] 85%
# - Loading 20 assets: [==================  ] 90%
# - Loading 20 assets: [=================== ] 95%
# - Loading 20 assets: [====================] 100%

# %%
from menpo.visualize.widgets import browse_images

# %matplotlib inline
browse_images(training_images)

# %%
diagonal_range = 200
img_shape = (170, 150)
lim_y = img_shape[0] / 2
lim_x = img_shape[1] / 2

training_images = [i.rescale_landmarks_to_diagonal_range(diagonal_range).resize(img_shape) for i in training_images]

# %%
# %matplotlib inline
browse_images(training_images)

# %%
import numpy as np
from menpo.shape import PointCloud
import matplotlib.pylab as plt

plot_size = (6, 6)

patch_shape = (6, 6)
lim = patch_shape[0] / 2

centers = np.meshgrid(range(0, 100, 5), range(0, 100, 5)) 
centers = PointCloud(np.asarray([centers[0].flatten(), centers[1].flatten()]).T)

# %%
img = training_images[0].copy()
img.build_mask_around_landmarks(patch_shape)
img.view()
plt.gcf().set_size_inches(plot_size)

# %% [markdown]
# ## 1st Level

# %%
from menpo.image import Image
from menpo.fitmultilevel.functions import extract_local_patches_fast

patch_images = []
for i in training_images:
    patches = extract_local_patches_fast(i, i.landmarks['PTS'].lms, patch_shape)
    patches -= np.mean(patches, axis=(1, 2))[:, None, None, :]
    for patch in patches:
        patch_img = Image(patch[:, :, 0])
        patch_images.append(patch_img)

# %%
from menpo.model import PCAModel

patch_pca = PCAModel(patch_images, center=False)
patch_pca.n_active_components = 4
print patch_pca
# Out:
# PCA Model
#  - centered:             False
#  - biased:               False
#  - # features:           36
#  - # active components:  4
#  - kept variance:        0.34  87.2%
#  - noise variance:       0.0016  0.4%
#  - total # components:   35
#  - components shape:     (4, 36)

# %%
patch_pcs= [patch_pca.component(j) for j in range(patch_pca.n_active_components)]

# %%
browse_images(patch_pcs)

# %%
expanded_patch_pcs = []
for j in np.arange(patch_pca.n_active_components):
    aux = np.zeros((2*patch_shape[0], 2*patch_shape[1]))
    aux[-lim:, -lim:] = patch_pca.component(j).pixels[:lim, :lim, 0]
    aux[:lim, -lim:] = patch_pca.component(j).pixels[lim:, :lim, 0]
    aux[-lim:, :lim] = patch_pca.component(j).pixels[:lim, lim:, 0]
    aux[:lim, :lim] = patch_pca.component(j).pixels[lim:, lim:, 0]
    expanded_patch_pcs.append(Image(np.fft.fftshift(aux)))

# %%
browse_images(expanded_patch_pcs)

# %%
H1 = 0
fft_patch_pcs = []
for pc in expanded_patch_pcs:
    fft_pc = np.abs(np.fft.fft2(pc.pixels[..., 0]))
    fft_patch_pcs.append(Image(fft_pc[..., None]))
    H1 += fft_pc
H1 = Image(H1[..., None])

# %%
browse_images(fft_patch_pcs)

# %%
H1.view()
plt.gcf().set_size_inches(plot_size)

# %%
patches_expanded = []
for i in patch_images:
    aux = np.zeros((2*patch_shape[0], 2*patch_shape[1]))
    aux[-lim:, -lim:] = i.pixels[:lim, :lim, 0]
    aux[:lim, -lim:] = i.pixels[lim:, :lim, 0]
    aux[-lim:, :lim] = i.pixels[:lim, lim:, 0]
    aux[:lim, :lim] = i.pixels[lim:, lim:, 0]
    patches_expanded.append(Image(np.fft.fftshift(aux)))

# %%
browse_images(patches_expanded)

# %%
patch_responses = []
for i in patches_expanded:
    for fft_pc in fft_patch_pcs:
        fft_i = np.fft.fft2(i.pixels[..., 0])
        filtered_fft_img = Image(fft_i * fft_pc.pixels[..., 0])
        patch_response  = Image(np.real(np.fft.ifft2(filtered_fft_img.pixels[..., 0])[patch_shape[0]/2:-patch_shape[0]/2, patch_shape[1]/2:-patch_shape[1]/2]))
        patch_responses.append(patch_response)

# %%
browse_images(patch_responses)

# %% [markdown]
# ## 2nd Level

# %%
from menpo.model import PCAModel

patch_pca = PCAModel(patch_responses, center=False)
patch_pca.n_active_components = 4
print patch_pca
# Out:
# PCA Model
#  - centered:             False
#  - biased:               False
#  - # features:           36
#  - # active components:  4
#  - kept variance:        0.12  96.7%
#  - noise variance:       0.00013  0.1%
#  - total # components:   36
#  - components shape:     (4, 36)

# %%
patch_pcs= [patch_pca.component(j) for j in range(patch_pca.n_active_components)]

# %%
browse_images(patch_pcs)

# %%
expanded_patch_pcs = []
for j in np.arange(patch_pca.n_active_components):
    aux = np.zeros((2*patch_shape[0], 2*patch_shape[1]))
    aux[-lim:, -lim:] = patch_pca.component(j).pixels[:lim, :lim, 0]
    aux[:lim, -lim:] = patch_pca.component(j).pixels[lim:, :lim, 0]
    aux[-lim:, :lim] = patch_pca.component(j).pixels[:lim, lim:, 0]
    aux[:lim, :lim] = patch_pca.component(j).pixels[lim:, lim:, 0]
    expanded_patch_pcs.append(Image(np.fft.fftshift(aux)))

# %%
browse_images(expanded_patch_pcs)

# %%
H2 = 0
fft_patch_pcs = []
for pc in expanded_patch_pcs:
    fft_pc = np.abs(np.fft.fft2(pc.pixels[..., 0]))
    fft_patch_pcs.append(Image(fft_pc[..., None]))
    H2 += fft_pc
H2 = Image(H2[..., None])

# %%
browse_images(fft_patch_pcs)

# %%
H2.view()
plt.gcf().set_size_inches(plot_size)

# %%
patches_expanded = []
for i in patch_responses:
    aux = np.zeros((2*patch_shape[0], 2*patch_shape[1]))
    aux[-lim:, -lim:] = i.pixels[:lim, :lim, 0]
    aux[:lim, -lim:] = i.pixels[lim:, :lim, 0]
    aux[-lim:, :lim] = i.pixels[:lim, lim:, 0]
    aux[:lim, :lim] = i.pixels[lim:, lim:, 0]
    patches_expanded.append(Image(np.fft.fftshift(aux)))

# %%
browse_images(patches_expanded)

# %%
patch_responses = []
for i in patches_expanded:
    for fft_pc in fft_patch_pcs:
        fft_i = np.fft.fft2(i.pixels[..., 0])
        filtered_fft_img = Image(fft_i * fft_pc.pixels[..., 0])
        patch_response  = Image(np.real(np.fft.ifft2(filtered_fft_img.pixels[..., 0])[patch_shape[0]/2:-patch_shape[0]/2, patch_shape[1]/2:-patch_shape[1]/2]))
        patch_responses.append(patch_response)

# %%
browse_images(patch_responses)

# %% [markdown]
# ## 3rd Level

# %%
del response_images

# %%
from menpo.image import Image
from menpo.fitmultilevel.functions import extract_local_patches_fast

patch_images = []
for i in response_images2:
    patches = extract_local_patches_fast(i, i.landmarks['PTS'].lms, patch_shape)
    patches -= np.mean(patches, axis=(1, 2))[:, None, None, :]
    for patch in patches:
        patch_img = Image(patch[:, :, 0])
        patch_images.append(patch_img)

# %%
from menpo.model import PCAModel

patch_pca = PCAModel(patch_images, center=False)
patch_pca.n_active_components = 12
print patch_pca
# Out:
# PCA Model
#  - centered:             False
#  - biased:               False
#  - # features:           36
#  - # active components:  12
#  - kept variance:        0.021  99.9%
#  - noise variance:       9.9e-07  0.0%
#  - total # components:   35
#  - components shape:     (12, 36)

# %%
patch_pcs= [patch_pca.component(j) for j in range(patch_pca.n_active_components)]

# %%
browse_images(patch_pcs)

# %%
expanded_patch_pcs = []
for j in np.arange(patch_pca.n_active_components):
    aux = np.zeros((img_shape[0]+patch_shape[0], img_shape[1]+patch_shape[1]))
    aux[-lim:, -lim:] = patch_pca.component(j).pixels[:lim, :lim, 0]
    aux[:lim, -lim:] = patch_pca.component(j).pixels[lim:, :lim, 0]
    aux[-lim:, :lim] = patch_pca.component(j).pixels[:lim, lim:, 0]
    aux[:lim, :lim] = patch_pca.component(j).pixels[lim:, lim:, 0]
    expanded_patch_pcs.append(Image(np.fft.fftshift(aux)))

# %%
browse_images(expanded_patch_pcs)

# %%
H3 = 0
fft_patch_pcs = []
for pc in expanded_patch_pcs:
    fft_pc = np.abs(np.fft.fft2(pc.pixels[..., 0]))
    fft_patch_pcs.append(Image(fft_pc[..., None]))
    H3 += fft_pc
H3 = Image(H3[..., None])

# %%
browse_images(fft_patch_pcs)

# %%
H3.view()
plt.gcf().set_size_inches(plot_size)

# %%
expanded_responses = []
for i in response_images2:
    aux = np.zeros((img_shape[0]+patch_shape[0], img_shape[1]+patch_shape[1]))
    aux[-lim_y:, -lim_x:] = i.pixels[:lim_y, :lim_x, 0]
    aux[:lim_y, -lim_x:] = i.pixels[lim_y:, :lim_x, 0]
    aux[-lim_y:, :lim_x] = i.pixels[:lim_y, lim_x:, 0]
    aux[:lim_y, :lim_x] = i.pixels[lim_y:, lim_x:, 0]
    expanded_responses.append(Image(np.fft.fftshift(aux)))

# %%
browse_images(expanded_responses)

# %%
fft_images = []
filtered_fft_images = []
final_response_images = []
for (exp_i, i) in zip(expanded_images, training_images):
    fft_img = Image(np.fft.fft2(exp_i.pixels[..., 0]))
    filtered_fft_img = Image(fft_img.pixels[..., 0] * (H1.pixels[..., 0] * H2.pixels[..., 0] * H3.pixels[..., 0])**2)
    response_img = Image(np.real(np.fft.ifft2(filtered_fft_img.pixels[..., 0])[patch_shape[0]/2:-patch_shape[0]/2, patch_shape[1]/2:-patch_shape[1]/2]))
    response_img.landmarks = i.landmarks
    fft_images.append(fft_img)
    filtered_fft_images.append(filtered_fft_img)
    final_response_images.append(response_img)

# %%
browse_images(final_response_images)

# %%
response_images3 = []
for i, r in zip(expanded_responses, response_images2):
    for fft_pc in fft_patch_pcs:
        fft_img = Image(np.fft.fft2(i.pixels[..., 0]))
        filtered_fft_img = Image(fft_img.pixels[..., 0] * fft_pc.pixels[..., 0])
        response_img = Image(np.real(np.fft.ifft2(filtered_fft_img.pixels[..., 0])[patch_shape[0]/2:-patch_shape[0]/2, patch_shape[1]/2:-patch_shape[1]/2]))
        response_img.landmarks = r.landmarks
        response_images3.append(response_img)

# %%
browse_images(response_images3)

# %% [markdown]
# ### 4th Level

# %%
del response_images2

# %%
from menpo.image import Image
from menpo.fitmultilevel.functions import extract_local_patches_fast

patch_images = []
for i in response_images3:
    patches = extract_local_patches_fast(i, i.landmarks['PTS'].lms, patch_shape)
    patches -= np.mean(patches, axis=(1, 2))[:, None, None, :]
    for patch in patches:
        patch_img = Image(patch[:, :, 0])
        patch_images.append(patch_img)

# %%
from menpo.model import PCAModel

patch_pca = PCAModel(patch_images, center=False)
patch_pca.n_active_components = 12
print patch_pca

# %%
patch_pcs= [patch_pca.component(j) for j in range(patch_pca.n_active_components)]

# %%
browse_images(patch_pcs)

# %%
expanded_patch_pcs = []
for j in np.arange(patch_pca.n_active_components):
    aux = np.zeros((img_shape[0]+patch_shape[0], img_shape[1]+patch_shape[1]))
    aux[-lim:, -lim:] = patch_pca.component(j).pixels[:lim, :lim, 0]
    aux[:lim, -lim:] = patch_pca.component(j).pixels[lim:, :lim, 0]
    aux[-lim:, :lim] = patch_pca.component(j).pixels[:lim, lim:, 0]
    aux[:lim, :lim] = patch_pca.component(j).pixels[lim:, lim:, 0]
    expanded_patch_pcs.append(Image(np.fft.fftshift(aux)))

# %%
browse_images(expanded_patch_pcs)

# %%
H4 = 0
fft_patch_pcs = []
for pc in expanded_patch_pcs:
    fft_pc = np.abs(np.fft.fft2(pc.pixels[..., 0]))
    fft_patch_pcs.append(Image(fft_pc[..., None]))
    H4 += fft_pc
H4 = Image(H4[..., None])

# %%
browse_images(fft_patch_pcs)

# %%
H4.view()
plt.gcf().set_size_inches(plot_size)

# %%
expanded_responses = []
for i in response_images3:
    aux = np.zeros((img_shape[0]+patch_shape[0], img_shape[1]+patch_shape[1]))
    aux[-lim_y:, -lim_x:] = i.pixels[:lim_y, :lim_x, 0]
    aux[:lim_y, -lim_x:] = i.pixels[lim_y:, :lim_x, 0]
    aux[-lim_y:, :lim_x] = i.pixels[:lim_y, lim_x:, 0]
    aux[:lim_y, :lim_x] = i.pixels[lim_y:, lim_x:, 0]
    expanded_responses.append(Image(np.fft.fftshift(aux)))

# %%
browse_images(expanded_responses)

# %%
fft_images = []
filtered_fft_images = []
final_response_images = []
for (exp_i, i) in zip(expanded_images, training_images):
    fft_img = Image(np.fft.fft2(exp_i.pixels[..., 0]))
    filtered_fft_img = Image(fft_img.pixels[..., 0] * (H1.pixels[..., 0] * H2.pixels[..., 0] * H3.pixels[..., 0] * H4.pixels[..., 0])**2)
    response_img = Image(np.real(np.fft.ifft2(filtered_fft_img.pixels[..., 0])[patch_shape[0]/2:-patch_shape[0]/2, patch_shape[1]/2:-patch_shape[1]/2]))
    response_img.landmarks = i.landmarks
    fft_images.append(fft_img)
    filtered_fft_images.append(filtered_fft_img)
    final_response_images.append(response_img)

# %%
browse_images(final_response_images)

# %%
response_images4 = []
for i, r in zip(expanded_responses, response_images3):
    for fft_pc in fft_patch_pcs:
        fft_img = Image(np.fft.fft2(i.pixels[..., 0]))
        filtered_fft_img = Image(fft_img.pixels[..., 0] * fft_pc.pixels[..., 0])
        response_img = Image(np.real(np.fft.ifft2(filtered_fft_img.pixels[..., 0])[patch_shape[0]/2:-patch_shape[0]/2, patch_shape[1]/2:-patch_shape[1]/2]))
        response_img.landmarks = r.landmarks
        response_images4.append(response_img)

# %%
browse_images(response_images4)

# %% [markdown]
# ## 5th Level

# %%
del response_images3

# %%
from menpo.image import Image
from menpo.fitmultilevel.functions import extract_local_patches_fast

patch_images = []
for i in response_images4:
    patches = extract_local_patches_fast(i, i.landmarks['PTS'].lms, patch_shape)
    patches -= np.mean(patches, axis=(1, 2))[:, None, None, :]
    for patch in patches:
        patch_img = Image(patch[:, :, 0])
        patch_images.append(patch_img)

# %%
from menpo.model import PCAModel

patch_pca = PCAModel(patch_images, center=False)
patch_pca.n_active_components = 4
print patch_pca

# %%
patch_pcs= [patch_pca.component(j) for j in range(patch_pca.n_active_components)]

# %%
browse_images(patch_pcs)

# %%
expanded_patch_pcs = []
for j in np.arange(patch_pca.n_active_components):
    aux = np.zeros((img_shape[0]+patch_shape[0], img_shape[1]+patch_shape[1]))
    aux[-lim:, -lim:] = patch_pca.component(j).pixels[:lim, :lim, 0]
    aux[:lim, -lim:] = patch_pca.component(j).pixels[lim:, :lim, 0]
    aux[-lim:, :lim] = patch_pca.component(j).pixels[:lim, lim:, 0]
    aux[:lim, :lim] = patch_pca.component(j).pixels[lim:, lim:, 0]
    expanded_patch_pcs.append(Image(np.fft.fftshift(aux)))

# %%
browse_images(expanded_patch_pcs)

# %%
H5 = 0
fft_patch_pcs = []
for pc in expanded_patch_pcs:
    fft_pc = np.abs(np.fft.fft2(pc.pixels[..., 0]))
    fft_patch_pcs.append(Image(fft_pc[..., None]))
    H5 += fft_pc
H5 = Image(H5[..., None])

# %%
browse_images(fft_patch_pcs)

# %%
H5.view()
plt.gcf().set_size_inches(plot_size)

# %%
expanded_responses = []
for i in response_images4:
    aux = np.zeros((img_shape[0]+patch_shape[0], img_shape[1]+patch_shape[1]))
    aux[-lim_y:, -lim_x:] = i.pixels[:lim_y, :lim_x, 0]
    aux[:lim_y, -lim_x:] = i.pixels[lim_y:, :lim_x, 0]
    aux[-lim_y:, :lim_x] = i.pixels[:lim_y, lim_x:, 0]
    aux[:lim_y, :lim_x] = i.pixels[lim_y:, lim_x:, 0]
    expanded_responses.append(Image(np.fft.fftshift(aux)))

# %%
browse_images(expanded_responses)

# %%
fft_images = []
filtered_fft_images = []
final_response_images = []
for (exp_i, i) in zip(expanded_images, training_images):
    fft_img = Image(np.fft.fft2(exp_i.pixels[..., 0]))
    filtered_fft_img = Image(fft_img.pixels[..., 0] * (H1.pixels[..., 0] * H2.pixels[..., 0] * H3.pixels[..., 0] * H4.pixels[..., 0] * H5.pixels[..., 0])**2)
    response_img = Image(np.real(np.fft.ifft2(filtered_fft_img.pixels[..., 0])[patch_shape[0]/2:-patch_shape[0]/2, patch_shape[1]/2:-patch_shape[1]/2]))
    response_img.landmarks = i.landmarks
    fft_images.append(fft_img)
    filtered_fft_images.append(filtered_fft_img)
    final_response_images.append(response_img)

# %%
browse_images(final_response_images)

# %% [markdown]
# ## Kernels

# %%
Image(np.fft.fftshift(H1.pixels)).view()
plt.gcf().set_size_inches(plot_size)

# %%
Image(np.fft.fftshift(H2.pixels)).view()
plt.gcf().set_size_inches(plot_size)

# %%
Image(np.fft.fftshift(H3.pixels)).view()
plt.gcf().set_size_inches(plot_size)

# %%
Image(np.fft.fftshift(H4.pixels)).view()
plt.gcf().set_size_inches(plot_size)

# %%
Image(np.fft.fftshift(H5.pixels)).view()
plt.gcf().set_size_inches(plot_size)

# %%
Image(np.fft.fftshift(H1.pixels * H2.pixels * H3.pixels * H4.pixels * H5.pixels)).view()
plt.gcf().set_size_inches(plot_size)

# %% [markdown]
# ## Alignment

# %%
H = H1.pixels * H2.pixels
H = H[patch_shape[0]/2:-patch_shape[0]/2, patch_shape[1]/2:-patch_shape[1]/2, 0]

# %%
Image(np.fft.fftshift(H)).view()
plt.gcf().set_size_inches(plot_size)

# %%
H = np.real(np.fft.ifft2(H))

aux = np.zeros((img_shape[0], img_shape[1]), dtype=np.complex)
aux[-lim:, -lim:] = H[:lim, :lim]
aux[:lim, -lim:] = H[lim:, :lim]
aux[-lim:, :lim] = H[:lim, lim:]
aux[:lim, :lim] = H[lim:, lim:]
H = np.fft.fftshift(np.abs(np.fft.fft2(aux)))

# %%
Image(np.fft.fftshift(H)).view()
plt.gcf().set_size_inches(plot_size)

# %%
import pickle

pickle.dump(H, open('/data/PhD/Models/ConvFilt_PCA_NonCent_4x4_try', 'wb' ))
