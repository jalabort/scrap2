# %%
import menpo.io as mio

# load training images
training_images = []
for i in mio.import_images('/Users/joan/PhD/DataBases/lfpw/trainset/*', max_images=50, verbose=True):
    # crop image
    i.crop_to_landmarks_proportion_inplace(0.1)
    # convert it to grayscale if needed
    if i.n_channels == 3:
        i = i.as_greyscale(mode='luminosity')
    # append it to the list
    training_images.append(i)
# Out:
# - Loading 50 assets: [                    ] 2%
# - Loading 50 assets: [                    ] 4%
# - Loading 50 assets: [=                   ] 6%
# - Loading 50 assets: [=                   ] 8%
# - Loading 50 assets: [==                  ] 10%
# - Loading 50 assets: [==                  ] 12%
# - Loading 50 assets: [==                  ] 14%
# - Loading 50 assets: [===                 ] 16%
# - Loading 50 assets: [===                 ] 18%
# - Loading 50 assets: [====                ] 20%
# - Loading 50 assets: [====                ] 22%
# - Loading 50 assets: [====                ] 24%
# - Loading 50 assets: [=====               ] 26%
# - Loading 50 assets: [=====               ] 28%
# - Loading 50 assets: [======              ] 30%
# - Loading 50 assets: [======              ] 32%
# - Loading 50 assets: [======              ] 34%
# - Loading 50 assets: [=======             ] 36%
# - Loading 50 assets: [=======             ] 38%
# - Loading 50 assets: [========            ] 40%
# ...

# %%
img = training_images[35]

# %%
h = img.features.hog()

# %%
import numpy as np
from menpo.image import Image
h = Image(np.median(h.pixels, axis=2))

# %%
h.view()

# %%
hh = h.features.hog()
hh = Image(np.median(hh.pixels, axis=2))
hh.view()

# %%
hhh = hh.features.hog()
hhh = Image(np.median(hhh.pixels, axis=2))
hhh.view()

# %%
hhhh = hhh.features.hog()
hhhh = Image(np.median(hhhh.pixels, axis=2))
hhhh.view()

# %%
hhhhh = hhhh.features.hog()
hhhhh = Image(np.median(hhhhh.pixels, axis=2))
hhhhh.view()
