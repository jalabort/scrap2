# %%
import numpy as np

def linear_discriminant_decomposition(Xs, whiten=False, center=True, bias=False, inplace=False):
    C = len(Xs)
    
    mus = [np.mean(X, axis=0) for X in Xs]
    T = np.mean(np.asarray(mus), axis=0)
    
    Sigmas = []
    Omegas = []
    for (X, mu) in zip(Xs, mus):
        n_samples, n_features = X.shape
        
        if bias:
            N = n_samples
        else:
            N = n_samples - 1.0
        
        X = X - mu
        Sigmas.append(np.dot(X.T, X) / N)
        
        mu = mu - T
        Omegas.append(np.dot(mu[:, None], mu[None, :]) / C)
        
    S = 0
    for Sig in Sigmas:
        S += Sig
        
    O = 0
    for Ome in Omegas:
        O += Ome
        
    C = np.linalg.solve(S, O)
    
    from menpo.math.decomposition import eigenvalue_decomposition
    
    eigenvectors, eigenvalues = eigenvalue_decomposition(C)
        
    return eigenvectors, eigenvalues

# %%
import menpo.io as mio

# load training images
training_images = []
for i in mio.import_images('/data/PhD/DataBases/multipie/*', max_images=50, verbose=True):
    # crop image
    i.crop_to_landmarks_proportion_inplace(0.1)
    # convert it to grayscale if needed
    if i.n_channels == 3:
        i = i.as_greyscale(mode='luminosity')
    # append it to the list
    training_images.append(i)
# Out:
# - Loading 50 assets: [                    ] 2%
# - Loading 50 assets: [                    ] 4%
# - Loading 50 assets: [=                   ] 6%
# - Loading 50 assets: [=                   ] 8%
# - Loading 50 assets: [==                  ] 10%
# - Loading 50 assets: [==                  ] 12%
# - Loading 50 assets: [==                  ] 14%
# - Loading 50 assets: [===                 ] 16%
# - Loading 50 assets: [===                 ] 18%
# - Loading 50 assets: [====                ] 20%
# - Loading 50 assets: [====                ] 22%
# - Loading 50 assets: [====                ] 24%
# - Loading 50 assets: [=====               ] 26%
# - Loading 50 assets: [=====               ] 28%
# - Loading 50 assets: [======              ] 30%
# - Loading 50 assets: [======              ] 32%
# - Loading 50 assets: [======              ] 34%
# - Loading 50 assets: [=======             ] 36%
# - Loading 50 assets: [=======             ] 38%
# - Loading 50 assets: [========            ] 40%
# ...

# %%
from menpo.visualize.widgets import browse_images

# %matplotlib inline
browse_images(training_images)

# %%
diagonal_range = 200
img_shape = (170, 150)
lim_y = img_shape[0] / 2
lim_x = img_shape[1] / 2

training_images = [i.rescale_landmarks_to_diagonal_range(diagonal_range).resize(img_shape) for i in training_images]

# %%
# %matplotlib inline
browse_images(training_images)

# %%
import numpy as np
from menpo.shape import PointCloud
import matplotlib.pylab as plt

plot_size = (6, 6)

patch_shape = (4, 4)
lim = patch_shape[0] / 2

centers = np.meshgrid(range(0, 100, 5), range(0, 100, 5)) 
centers = PointCloud(np.asarray([centers[0].flatten(), centers[1].flatten()]).T)

# %%
img = training_images[0].copy()
img.build_mask_around_landmarks(patch_shape)
img.view()
plt.gcf().set_size_inches(plot_size)

# %% [markdown]
# ## 1st Level

# %%
from menpo.fitmultilevel.functions import extract_local_patches_fast

patch_list = []
for i in training_images:
    patches = extract_local_patches_fast(i, i.landmarks['PTS'].lms, patch_shape)
    patches -= np.mean(patches, axis=(1, 2))[:, None, None, :]
    patch_list.append(patches)
        
patch_classes = []
for j in range(patches.shape[0]):
    patch_images = []
    for patches in patch_list:
        patch_img = patches[j, :, :, 0]
        patch_images.append(patch_img)
    patch_classes.append(np.reshape(np.asarray(patch_images), (-1, np.prod(patch_shape))))

# %%
from menpo.model import PCAModel
from menpo.image import Image

eigenvectors, eigenvalues = linear_discriminant_decomposition(patch_classes)
patch_components = [Image(np.reshape(eigenvectors[:, j], patch_shape)) for j in range(8)]

# %%
np.sum((eigenvalues / np.sum(eigenvalues))[:8])
# Out:
# 0.99999999999999989

# %%
browse_images(patch_components)

# %%
expanded_patch_pcs = []
for j in range(len(patch_components)):
    aux = np.zeros((img_shape[0]+patch_shape[0], img_shape[1]+patch_shape[1]))
    aux[-lim:, -lim:] = patch_components[j].pixels[:lim, :lim, 0]
    aux[:lim, -lim:] = patch_components[j].pixels[lim:, :lim, 0]
    aux[-lim:, :lim] = patch_components[j].pixels[:lim, lim:, 0]
    aux[:lim, :lim] = patch_components[j].pixels[lim:, lim:, 0]
    expanded_patch_pcs.append(Image(np.fft.fftshift(aux)))

# %%
browse_images(expanded_patch_pcs)

# %%
H1 = 0
fft_patch_pcs = []
for pc in expanded_patch_pcs:
    fft_pc = np.abs(np.fft.fft2(pc.pixels[..., 0]))
    fft_patch_pcs.append(Image(fft_pc[..., None]))
    H1 += fft_pc
H1 = Image(H1[..., None])

# %%
browse_images(fft_patch_pcs)

# %%
H1.view()
plt.gcf().set_size_inches(plot_size)

# %%
expanded_images = []
for i in training_images:
    aux = np.zeros((img_shape[0]+patch_shape[0], img_shape[1]+patch_shape[1]))
    aux[-lim_y:, -lim_x:] = i.pixels[:lim_y, :lim_x, 0]
    aux[:lim_y, -lim_x:] = i.pixels[lim_y:, :lim_x, 0]
    aux[-lim_y:, :lim_x] = i.pixels[:lim_y, lim_x:, 0]
    aux[:lim_y, :lim_x] = i.pixels[lim_y:, lim_x:, 0]
    expanded_images.append(Image(np.fft.fftshift(aux)))

# %%
browse_images(expanded_images)

# %%
fft_images = []
filtered_fft_images = []
final_response_images = []
for (exp_i, i) in zip(expanded_images, training_images):
    fft_img = Image(np.fft.fft2(exp_i.pixels[..., 0]))
    filtered_fft_img = Image(fft_img.pixels[..., 0] * H1.pixels[..., 0]**0.5)
    response_img = Image(np.real(np.fft.ifft2(filtered_fft_img.pixels[..., 0])[patch_shape[0]/2:-patch_shape[0]/2, patch_shape[1]/2:-patch_shape[1]/2]))
    response_img.landmarks = i.landmarks
    fft_images.append(fft_img)
    filtered_fft_images.append(filtered_fft_img)
    final_response_images.append(response_img)

# %%
browse_images(final_response_images)

# %%
response_images = []
for (i, fft_i) in zip(training_images, fft_images):
    for fft_pc in fft_patch_pcs:
        filtered_fft_img = Image(fft_i.pixels[..., 0] * fft_pc.pixels[..., 0])
        response_img = Image(np.real(np.fft.ifft2(filtered_fft_img.pixels[..., 0])[patch_shape[0]/2:-patch_shape[0]/2, patch_shape[1]/2:-patch_shape[1]/2]))
        response_img.landmarks = i.landmarks
        response_images.append(response_img)

# %%
browse_images(response_images)

# %% [markdown]
# ## 2nd Level

# %%
from menpo.fitmultilevel.functions import extract_local_patches_fast

patch_list = []
for i in response_images:
    patches = extract_local_patches_fast(i, i.landmarks['PTS'].lms, patch_shape)
    patches -= np.mean(patches, axis=(1, 2))[:, None, None, :]
    patch_list.append(patches)
        
patch_classes = []
for j in range(patches.shape[0]):
    patch_images = []
    for patches in patch_list:
        patch_img = patches[j, :, :, 0]
        patch_images.append(patch_img)
    patch_classes.append(np.reshape(np.asarray(patch_images), (-1, np.prod(patch_shape))))

# %%
from menpo.model import PCAModel
from menpo.image import Image

eigenvectors, eigenvalues = linear_discriminant_decomposition(patch_classes)
patch_components = [Image(np.reshape(eigenvectors[:, j], patch_shape)) for j in range(6)]

# %%
np.sum((eigenvalues / np.sum(eigenvalues))[:8])
# Out:
# 0.99092964155445606

# %%
browse_images(patch_components)

# %%
expanded_patch_pcs = []
for j in range(len(patch_components)):
    aux = np.zeros((img_shape[0]+patch_shape[0], img_shape[1]+patch_shape[1]))
    aux[-lim:, -lim:] = patch_components[j].pixels[:lim, :lim, 0]
    aux[:lim, -lim:] = patch_components[j].pixels[lim:, :lim, 0]
    aux[-lim:, :lim] = patch_components[j].pixels[:lim, lim:, 0]
    aux[:lim, :lim] = patch_components[j].pixels[lim:, lim:, 0]
    expanded_patch_pcs.append(Image(np.fft.fftshift(aux)))

# %%
browse_images(expanded_patch_pcs)

# %%
H2 = 0
fft_patch_pcs = []
for pc in expanded_patch_pcs:
    fft_pc = np.abs(np.fft.fft2(pc.pixels[..., 0]))
    fft_patch_pcs.append(Image(fft_pc[..., None]))
    H2 += fft_pc
H2 = Image(H2[..., None])

# %%
browse_images(fft_patch_pcs)

# %%
H2.view()
plt.gcf().set_size_inches(plot_size)

# %%
expanded_responses = []
for i in response_images:
    aux = np.zeros((img_shape[0]+patch_shape[0], img_shape[1]+patch_shape[1]))
    aux[-lim_y:, -lim_x:] = i.pixels[:lim_y, :lim_x, 0]
    aux[:lim_y, -lim_x:] = i.pixels[lim_y:, :lim_x, 0]
    aux[-lim_y:, :lim_x] = i.pixels[:lim_y, lim_x:, 0]
    aux[:lim_y, :lim_x] = i.pixels[lim_y:, lim_x:, 0]
    expanded_responses.append(Image(np.fft.fftshift(aux)))

# %%
browse_images(expanded_responses)

# %%
fft_images = []
filtered_fft_images = []
final_response_images = []
for (exp_i, i) in zip(expanded_images, training_images):
    fft_img = Image(np.fft.fft2(exp_i.pixels[..., 0]))
    filtered_fft_img = Image(fft_img.pixels[..., 0] * (H1.pixels[..., 0] * H2.pixels[..., 0])**0.5)
    response_img = Image(np.real(np.fft.ifft2(filtered_fft_img.pixels[..., 0])[patch_shape[0]/2:-patch_shape[0]/2, patch_shape[1]/2:-patch_shape[1]/2]))
    response_img.landmarks = i.landmarks
    fft_images.append(fft_img)
    filtered_fft_images.append(filtered_fft_img)
    final_response_images.append(response_img)

# %%
browse_images(final_response_images)

# %%
response_images2 = []
for i, r in zip(expanded_responses, response_images):
    for fft_pc in fft_patch_pcs:
        fft_img = Image(np.fft.fft2(i.pixels[..., 0]))
        filtered_fft_img = Image(fft_img.pixels[..., 0] * fft_pc.pixels[..., 0])
        response_img = Image(np.real(np.fft.ifft2(filtered_fft_img.pixels[..., 0])[patch_shape[0]/2:-patch_shape[0]/2, patch_shape[1]/2:-patch_shape[1]/2]))
        response_img.landmarks = r.landmarks
        response_images2.append(response_img)

# %%
browse_images(response_images2)

# %% [markdown]
# ## 3rd Level

# %%
del response_images

# %%
from menpo.fitmultilevel.functions import extract_local_patches_fast

patch_list = []
for i in response_images2:
    patches = extract_local_patches_fast(i, i.landmarks['PTS'].lms, patch_shape)
    patches -= np.mean(patches, axis=(1, 2))[:, None, None, :]
    patch_list.append(patches)
        
patch_classes = []
for j in range(patches.shape[0]):
    patch_images = []
    for patches in patch_list:
        patch_img = patches[j, :, :, 0]
        patch_images.append(patch_img)
    patch_classes.append(np.reshape(np.asarray(patch_images), (-1, np.prod(patch_shape))))

# %%
from menpo.model import PCAModel
from menpo.image import Image

eigenvectors, eigenvalues = linear_discriminant_decomposition(patch_classes)
patch_components = [Image(np.reshape(eigenvectors[:, j], patch_shape)) for j in range(6)]

# %%
browse_images(patch_components)

# %%
expanded_patch_pcs = []
for j in range(len(patch_components)):
    aux = np.zeros((img_shape[0]+patch_shape[0], img_shape[1]+patch_shape[1]))
    aux[-lim:, -lim:] = patch_components[j].pixels[:lim, :lim, 0]
    aux[:lim, -lim:] = patch_components[j].pixels[lim:, :lim, 0]
    aux[-lim:, :lim] = patch_components[j].pixels[:lim, lim:, 0]
    aux[:lim, :lim] = patch_components[j].pixels[lim:, lim:, 0]
    expanded_patch_pcs.append(Image(np.fft.fftshift(aux)))

# %%
browse_images(expanded_patch_pcs)

# %%
H3 = 0
fft_patch_pcs = []
for pc in expanded_patch_pcs:
    fft_pc = np.abs(np.fft.fft2(pc.pixels[..., 0]))
    fft_patch_pcs.append(Image(fft_pc[..., None]))
    H3 += fft_pc
H3 = Image(H3[..., None])

# %%
browse_images(fft_patch_pcs)

# %%
H3.view()
plt.gcf().set_size_inches(plot_size)

# %%
expanded_responses = []
for i in response_images2:
    aux = np.zeros((img_shape[0]+patch_shape[0], img_shape[1]+patch_shape[1]))
    aux[-lim_y:, -lim_x:] = i.pixels[:lim_y, :lim_x, 0]
    aux[:lim_y, -lim_x:] = i.pixels[lim_y:, :lim_x, 0]
    aux[-lim_y:, :lim_x] = i.pixels[:lim_y, lim_x:, 0]
    aux[:lim_y, :lim_x] = i.pixels[lim_y:, lim_x:, 0]
    expanded_responses.append(Image(np.fft.fftshift(aux)))

# %%
browse_images(expanded_responses)

# %%
fft_images = []
filtered_fft_images = []
final_response_images = []
for (exp_i, i) in zip(expanded_images, training_images):
    fft_img = Image(np.fft.fft2(exp_i.pixels[..., 0]))
    filtered_fft_img = Image(fft_img.pixels[..., 0] * (H1.pixels[..., 0] * H2.pixels[..., 0] * H3.pixels[..., 0])**0.5)
    response_img = Image(np.real(np.fft.ifft2(filtered_fft_img.pixels[..., 0])[patch_shape[0]/2:-patch_shape[0]/2, patch_shape[1]/2:-patch_shape[1]/2]))
    response_img.landmarks = i.landmarks
    fft_images.append(fft_img)
    filtered_fft_images.append(filtered_fft_img)
    final_response_images.append(response_img)

# %%
browse_images(final_response_images)

# %%
response_images3 = []
for i, r in zip(expanded_responses, response_images2):
    for fft_pc in fft_patch_pcs:
        fft_img = Image(np.fft.fft2(i.pixels[..., 0]))
        filtered_fft_img = Image(fft_img.pixels[..., 0] * fft_pc.pixels[..., 0])
        response_img = Image(np.real(np.fft.ifft2(filtered_fft_img.pixels[..., 0])[patch_shape[0]/2:-patch_shape[0]/2, patch_shape[1]/2:-patch_shape[1]/2]))
        response_img.landmarks = r.landmarks
        response_images3.append(response_img)

# %%
browse_images(response_images3)

# %% [markdown]
# ### 4th Level

# %%
del response_images2

# %%
from menpo.fitmultilevel.functions import extract_local_patches_fast

patch_list = []
for i in response_images3:
    patches = extract_local_patches_fast(i, i.landmarks['PTS'].lms, patch_shape)
    patches -= np.mean(patches, axis=(1, 2))[:, None, None, :]
    patch_list.append(patches)
        
patch_classes = []
for j in range(patches.shape[0]):
    patch_images = []
    for patches in patch_list:
        patch_img = patches[j, :, :, 0]
        patch_images.append(patch_img)
    patch_classes.append(np.reshape(np.asarray(patch_images), (-1, np.prod(patch_shape))))

# %%
from menpo.model import PCAModel
from menpo.image import Image

eigenvectors, eigenvalues = linear_discriminant_decomposition(patch_classes)
patch_components = [Image(np.reshape(eigenvectors[:, j], patch_shape)) for j in range(8)]

# %%
browse_images(patch_components)

# %%
expanded_patch_pcs = []
for j in range(len(patch_components)):
    aux = np.zeros((img_shape[0]+patch_shape[0], img_shape[1]+patch_shape[1]))
    aux[-lim:, -lim:] = patch_components[j].pixels[:lim, :lim, 0]
    aux[:lim, -lim:] = patch_components[j].pixels[lim:, :lim, 0]
    aux[-lim:, :lim] = patch_components[j].pixels[:lim, lim:, 0]
    aux[:lim, :lim] = patch_components[j].pixels[lim:, lim:, 0]
    expanded_patch_pcs.append(Image(np.fft.fftshift(aux)))

# %%
browse_images(expanded_patch_pcs)

# %%
H4 = 0
fft_patch_pcs = []
for pc in expanded_patch_pcs:
    fft_pc = np.abs(np.fft.fft2(pc.pixels[..., 0]))
    fft_patch_pcs.append(Image(fft_pc[..., None]))
    H4 += fft_pc
H4 = Image(H4[..., None])

# %%
browse_images(fft_patch_pcs)

# %%
H4.view()
plt.gcf().set_size_inches(plot_size)

# %%
expanded_responses = []
for i in response_images3:
    aux = np.zeros((img_shape[0]+patch_shape[0], img_shape[1]+patch_shape[1]))
    aux[-lim_y:, -lim_x:] = i.pixels[:lim_y, :lim_x, 0]
    aux[:lim_y, -lim_x:] = i.pixels[lim_y:, :lim_x, 0]
    aux[-lim_y:, :lim_x] = i.pixels[:lim_y, lim_x:, 0]
    aux[:lim_y, :lim_x] = i.pixels[lim_y:, lim_x:, 0]
    expanded_responses.append(Image(np.fft.fftshift(aux)))

# %%
browse_images(expanded_responses)

# %%
fft_images = []
filtered_fft_images = []
final_response_images = []
for (exp_i, i) in zip(expanded_images, training_images):
    fft_img = Image(np.fft.fft2(exp_i.pixels[..., 0]))
    filtered_fft_img = Image(fft_img.pixels[..., 0] * (H1.pixels[..., 0] * H2.pixels[..., 0] * H3.pixels[..., 0] * H4.pixels[..., 0])**0.5)
    response_img = Image(np.real(np.fft.ifft2(filtered_fft_img.pixels[..., 0])[patch_shape[0]/2:-patch_shape[0]/2, patch_shape[1]/2:-patch_shape[1]/2]))
    response_img.landmarks = i.landmarks
    fft_images.append(fft_img)
    filtered_fft_images.append(filtered_fft_img)
    final_response_images.append(response_img)

# %%
browse_images(final_response_images)

# %%
#response_images4 = []
#for i, r in zip(expanded_responses, response_images3):
#    for fft_pc in fft_patch_pcs:
#        fft_img = Image(np.fft.fft2(i.pixels[..., 0]))
#        filtered_fft_img = Image(fft_img.pixels[..., 0] * fft_pc.pixels[..., 0])
#        response_img = Image(np.real(np.fft.ifft2(filtered_fft_img.pixels[..., 0])[patch_shape[0]/2:-patch_shape[0]/2, patch_shape[1]/2:-patch_shape[1]/2]))
#        response_img.landmarks = r.landmarks
#        response_images4.append(response_img)

# %%
#browse_images(response_images4)

# %% [markdown]
# ## Kernels

# %%
Image(np.fft.fftshift(H1.pixels)).view()
plt.gcf().set_size_inches(plot_size)

# %%
Image(np.fft.fftshift(H2.pixels)).view()
plt.gcf().set_size_inches(plot_size)

# %%
Image(np.fft.fftshift(H3.pixels)).view()
plt.gcf().set_size_inches(plot_size)

# %%
Image(np.fft.fftshift(H4.pixels)).view()
plt.gcf().set_size_inches(plot_size)

# %%
Image(np.fft.fftshift(H1.pixels * H2.pixels * H3.pixels * H4.pixels)).view()
plt.gcf().set_size_inches(plot_size)

# %% [markdown]
# ## Alignment

# %%
H = H1.pixels * H2.pixels * H3.pixels * H4.pixels
H = H[patch_shape[0]/2:-patch_shape[0]/2, patch_shape[1]/2:-patch_shape[1]/2, 0]

# %%
import pickle

pickle.dump(H, open('/data/PhD/Models/ConvFilt_LDA_4x4', 'wb' ))
