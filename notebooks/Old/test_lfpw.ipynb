of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40cb650> (120 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40cb690> (121 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40cb6d0> (122 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40cb710> (123 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40cb750> (124 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40cb790> (125 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40cb7d0> (126 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40cb810> (127 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40cb850> (128 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40cb890> (129 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40cb8d0> (130 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40cb910> (131 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40cb950> (132 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40cb990> (133 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40cb9d0> (134 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40cba10> (135 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40cba50> (136 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40cba90> (137 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40cbad0> (138 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40cbb10> (139 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40cbb50> (140 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40cbb90> (141 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40cbbd0> (142 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40cbc10> (143 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40cbc50> (144 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40cbc90> (145 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40cbcd0> (146 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40cbd10> (147 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40cbd50> (148 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40cbd90> (149 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40cbdd0> (150 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40cbe10> (151 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40cbe50> (152 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40cbe90> (153 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40cbed0> (154 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40cbf10> (155 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40cbf50> (156 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40cbf90> (157 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40cbfd0> (158 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40d0050> (159 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40d0090> (160 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40d00d0> (161 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40d0110> (162 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40d0150> (163 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40d0190> (164 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40d01d0> (165 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40d0210> (166 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40d0250> (167 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40d0290> (168 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40d02d0> (169 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40d0310> (170 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40d0350> (171 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40d0390> (172 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40d03d0> (173 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40d0410> (174 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40d0450> (175 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40d0490> (176 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40d04d0> (177 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40d0510> (178 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40d0550> (179 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40d0590> (180 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40d05d0> (181 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40d0610> (182 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40d0650> (183 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40d0690> (184 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40d06d0> (185 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40d0710> (186 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40d0750> (187 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40d0790> (188 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40d07d0> (189 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40d0810> (190 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40d0850> (191 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40d0890> (192 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40d08d0> (193 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40d0910> (194 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40d0950> (195 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40d0990> (196 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40d09d0> (197 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40d0a10> (198 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40d0a50> (199 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40d0a90> (200 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40d0ad0> (201 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40d0b10> (202 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40d0b50> (203 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40d0b90> (204 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40d0bd0> (205 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40d0c10> (206 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40d0c50> (207 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40d0c90> (208 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40d0cd0> (209 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40d0d10> (210 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40d0d50> (211 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40d0d90> (212 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40d0dd0> (213 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40d0e10> (214 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40d0e50> (215 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40d0e90> (216 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40d0ed0> (217 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40d0f10> (218 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40d0f50> (219 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40d0f90> (220 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40d0fd0> (221 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40d5050> (222 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40d5090> (223 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x40d50d0> (224 of 224)

# %%
from pybug.transform.affine import Translation

# extract shape data. -1 because the annotation are 1 based
translation = Translation(np.array([-1, -1]))
for img in images:
    translation.apply_inplace(img.landmarks['PTS'].lms)

# %%
from pybug.landmark.labels import labeller, ibug_68_points

# label the landmarks using the ibug's "standard" 68 points mark-up
labeller(images, 'PTS', ibug_68_points);

# %%
import pickle

# load a previously buid AAM
aam = pickle.load(open('/vol/atlas/aams/lfpw_pwa_multi', "rb"))

ref_frame_list = aam["ref_frame_list"]
appearance_model_list = aam["appearance_model_list"]
shape_model_list = aam["shape_model_list"]

# %%
#data = sio.loadmat('/data/matlab/aams/aamtoolbox/data.mat')
#f = data['f']

# %%
from pybug.transform.modeldriven import OrthoMDTransform
from pybug.transform.affine import SimilarityTransform
from pybug.transform.piecewiseaffine import PiecewiseAffineTransform

source_1 = ref_frame_list[0].landmarks['ibug_68_trimesh'].lms
source_2 = ref_frame_list[1].landmarks['ibug_68_trimesh'].lms
source_3 = ref_frame_list[2].landmarks['ibug_68_trimesh'].lms

dummy_similarity_transform = SimilarityTransform.from_vector(np.array([0, 0, 0, 0]))
global_transform = dummy_similarity_transform

md_transform_list = []
for sm, rf in zip(shape_model_list, ref_frame_list):
    md_transform_list.append(OrthoMDTransform(sm,
                                              PiecewiseAffineTransform,
                                              source=rf.landmarks['ibug_68_trimesh'].lms, 
                                              global_transform=global_transform))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-9bea566bd01f> in <module>()
#      15                                               PiecewiseAffineTransform,
#      16                                               source=rf.landmarks['ibug_68_trimesh'].lms,
# ---> 17                                               global_transform=global_transform))
#
# /vol/atlas/homes/ja310/.virtualenvs/pybug/src/pybug/pybug/transform/modeldriven.pyc in __init__(self, model, transform_cls, source, weights, global_transform, composition)
#     755                  weights=None, global_transform=None, composition='both'):
#     756         # 1. Construct similarity model from the mean of the model
# --> 757         self.similarity_model = SimilarityModel(model.mean)
#     758         # 2. orthonormalize model and similarity model
#     759         model = deepcopy(model)
#
# /vol/atlas/homes/ja310/.virtualenvs/pybug/src/pybug/pybug/model/linear.pyc in mean(self)
#     351         :type: ``self.instance_class``
#     352         """
# --> 353         return self.template_instance.from_vector(self._mean)
#     354
#     355     @property
#
# AttributeError: 'NoneType' object has no attribute 'from_vector'

# %%
pza = shape_model_list[0]
pza.samples[0]

# %%
from copy import deepcopy
from pybug.lucaskanade.residual import LSIntensity
from pybug.lucaskanade.appearance import (AlternatingForwardAdditive, 
                                          AlternatingForwardCompositional,
                                          AlternatingInverseCompositional)

# standard Least Squares Residual
residual = LSIntensity()

# forward additive
fa_multi = AlternatingForwardAdditive(appearance_model_list, 
                                      residual, 
                                      deepcopy(md_transform_list),
                                      interpolator='c')
# forwad compositional
fc_multi = AlternatingForwardCompositional(appearance_model_list, 
                                           residual, 
                                           deepcopy(md_transform_list),
                                           interpolator='c')
# inverse compositional
ic_multi = AlternatingInverseCompositional(appearance_model_list, 
                                           residual, 
                                           deepcopy(md_transform_list),
                                           interpolator='c')

# %%
level = 2
noise_scale =  0.01

global_transform_list = []
for img in images:
    global_transform = SimilarityTransform.align(shape_model_list[level].mean, 
                                                 img.landmarks['PTS'].lms)
    global_trans_params = global_transform.as_vector()
    # kill rotation
    global_trans_params[1] = 0
    # add Gaussian noise
    # global_trans_params += noise_scale * np.random.randn(4)
    global_transform_list.append(global_transform.from_vector(global_trans_params))


ini_md_trans = [OrthoMDTransform(shape_model_list[level], 
                                  PiecewiseAffineTransform, 
                                  source=ref_frame_list[level].landmarks['PTS'].lms, 
                                  global_transform=gt)
                for gt in global_transform_list]

# %%
from pybug.image import MaskedNDImage

gs_images = [img.as_greyscale() for img in images]
nd_images = [MaskedNDImage(img.pixels, mask=img.mask) for img in gs_images]

shapes = [img.landmarks['PTS'].lms for img in images]

# %% [markdown]
# ### . Fit

# %%
fa_multi_result = [deepcopy(fa_multi.align(img, deepcopy(t), max_iters=50)) 
                   for t, img in zip(ini_md_trans, nd_images)]

# %%
fc_multi_result = [deepcopy(fc_multi.align(img, deepcopy(t), max_iters=50)) 
                   for t, img in zip(ini_md_trans, nd_images)]

# %%
ic_multi_result = fc_multic_multi

# %%
ic_multi_result = [deepcopy(ic_multi.align(img, deepcopy(t), max_iters=50)) 
                   for t, img in zip(ini_md_trans, nd_images)]

# %%
from __future__ import division

def compute_p2pe(fitted, ground_truth):
    return np.mean(np.sqrt(np.sum((fitted - ground_truth) ** 2, axis=-1)))

def compute_rame(fitted, ground_truth):
    face_size = np.mean(np.max(ground_truth, axis=0) - np.min(ground_truth, axis=0))
    return compute_p2pe(fitted, ground_truth) / face_size

# %%
initial_shapes = [t.target for t in ini_md_trans]
initial_error = np.array([compute_rame(f.points, s.points)
                          for f, s in zip(initial_shapes, shapes)])

fitted_shapes = [t.target for t in ic_multi_result]
fc_error = np.array([compute_rame(f.points, s.points)
                     for f, s in zip(fitted_shapes, shapes)])

# %%
from __future__ import division

stop = 0.05
num = 50

xs = np.linspace(0,stop,num=num)
n_fittings = len(ic_multi_result)

fc_cumulative_error = np.zeros_like(xs)
for i, limit in enumerate(xs):
    fc_cumulative_error[i] = (np.count_nonzero(fc_error < limit) / 
                              n_fittings)

initial_cumulative_error = np.zeros_like(xs)
for i, limit in enumerate(xs):
    initial_cumulative_error[i] = (np.count_nonzero(initial_error < limit) / 
                                   n_fittings)

plot(xs, fc_cumulative_error, 'ro-')
plot(xs, initial_cumulative_error, 'b^-')
gcf().set_size_inches((10,10))

# %%
print 'mean: {}'.format(np.mean(fc_error))
print 'median: {}'.format(np.median(fc_error))
print fc_cumulative_error[-1]
# Out:
# mean: 0.0338430211365
# median: 0.0281787040065
# 0.870535714286

# %%
xs[-10]
# Out:
# 0.040816326530612249

# %%
i = 88

images[i].landmarks['gf'] = fitted_shapes[i]
images[i].landmarks['gf'].view_new()
gcf().set_size_inches((10,10))

images[i].landmarks['gf'] = initial_shapes[i]
images[i].landmarks['gf'].view_new()
gcf().set_size_inches((10,10))

# %%
np.diag(ic_multi._H)
# Out:
# array([ 0.06684964,  0.03894708,  0.07322222,  0.047766  ,  0.04421378,
#         0.02725412,  0.05873439,  0.04420276,  0.03320345,  0.04647541,
#         0.02098465,  0.03120039,  0.07514639,  0.05098848,  0.02207497,
#         0.02967952])
