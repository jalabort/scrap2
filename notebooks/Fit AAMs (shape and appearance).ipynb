# %% [markdown]
# # AAMs for Image Alignment - shape and appearance
#
# ### 1. Load the data
#
# Use the **autoimporter** to automatically load the *annotated* test images of the *Labelled Faces Parts in the Wild (LFPW)* dataset:

# %%
from pybug.io import auto_import
from pybug.landmark.labels import (labeller, ibug_68_points, 
                                    ibug_68_contour, ibug_68_trimesh)
from pybug.shape import PointCloud

# load the training images of the LFPW database as landmarked images using the autoimporter
images = auto_import('/Users/joan/PhD/DataBases/lfpw/testset/' + '*.png')
shapes = [img.landmarks['PTS'].lms for img in images]
# Out:
# Found 224 files. (0/224) are importable
# Found 224 files. (224/224) are importable
# Creating importer for <pybug.io.image.PILImporter object at 0x107e80090> (1 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e80110> (2 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e80150> (3 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e80190> (4 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e801d0> (5 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e80210> (6 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e80250> (7 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e80290> (8 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e802d0> (9 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e80310> (10 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e80350> (11 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e80390> (12 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e803d0> (13 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e80410> (14 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e80450> (15 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e80490> (16 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e804d0> (17 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e80510> (18 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e80550> (19 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e80590> (20 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e805d0> (21 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e80610> (22 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e80650> (23 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e80690> (24 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e806d0> (25 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e80710> (26 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e80750> (27 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e80790> (28 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e807d0> (29 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e80810> (30 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e80850> (31 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e80890> (32 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e808d0> (33 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e80910> (34 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e80950> (35 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e80990> (36 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e809d0> (37 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e80a10> (38 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e80a50> (39 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e80a90> (40 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e80ad0> (41 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e80b10> (42 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e80b50> (43 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e80b90> (44 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e80bd0> (45 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e80c10> (46 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e80c50> (47 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e80c90> (48 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e80cd0> (49 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e80d10> (50 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e80d50> (51 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e80d90> (52 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e80dd0> (53 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e80e10> (54 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e80e50> (55 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e80e90> (56 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e80ed0> (57 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e80f10> (58 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e80f50> (59 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e80f90> (60 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e80fd0> (61 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e8b050> (62 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e8b090> (63 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e8b0d0> (64 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e8b110> (65 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e8b150> (66 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e8b190> (67 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e8b1d0> (68 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e8b210> (69 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e8b250> (70 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e8b290> (71 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e8b2d0> (72 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e8b310> (73 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e8b350> (74 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e8b390> (75 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e8b3d0> (76 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e8b410> (77 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e8b450> (78 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e8b490> (79 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e8b4d0> (80 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e8b510> (81 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e8b550> (82 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e8b590> (83 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e8b5d0> (84 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e8b610> (85 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e8b650> (86 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e8b690> (87 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e8b6d0> (88 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e8b710> (89 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e8b750> (90 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e8b790> (91 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e8b7d0> (92 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e8b810> (93 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e8b850> (94 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e8b890> (95 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e8b8d0> (96 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e8b910> (97 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e8b950> (98 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e8b990> (99 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e8b9d0> (100 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e8ba10> (101 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e8ba50> (102 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e8ba90> (103 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e8bad0> (104 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e8bb10> (105 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e8bb50> (106 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e8bb90> (107 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e8bbd0> (108 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e8bc10> (109 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e8bc50> (110 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e8bc90> (111 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e8bcd0> (112 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e8bd10> (113 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e8bd50> (114 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e8bd90> (115 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e8bdd0> (116 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e8be10> (117 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e8be50> (118 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e8be90> (119 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e8bed0> (120 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e8bf10> (121 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e8bf50> (122 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e8bf90> (123 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e8bfd0> (124 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e95050> (125 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e95090> (126 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e950d0> (127 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e95110> (128 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e95150> (129 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e95190> (130 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e951d0> (131 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e95210> (132 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e95250> (133 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e95290> (134 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e952d0> (135 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e95310> (136 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e95350> (137 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e95390> (138 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e953d0> (139 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e95410> (140 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e95450> (141 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e95490> (142 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e954d0> (143 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e95510> (144 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e95550> (145 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e95590> (146 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e955d0> (147 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e95610> (148 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e95650> (149 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e95690> (150 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e956d0> (151 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e95710> (152 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e95750> (153 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e95790> (154 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e957d0> (155 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e95810> (156 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e95850> (157 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e95890> (158 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e958d0> (159 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e95910> (160 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e95950> (161 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e95990> (162 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e959d0> (163 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e95a10> (164 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e95a50> (165 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e95a90> (166 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e95ad0> (167 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e95b10> (168 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e95b50> (169 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e95b90> (170 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e95bd0> (171 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e95c10> (172 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e95c50> (173 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e95c90> (174 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e95cd0> (175 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e95d10> (176 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e95d50> (177 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e95d90> (178 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e95dd0> (179 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e95e10> (180 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e95e50> (181 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e95e90> (182 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e95ed0> (183 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e95f10> (184 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e95f50> (185 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e95f90> (186 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e95fd0> (187 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e99050> (188 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e99090> (189 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e990d0> (190 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e99110> (191 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e99150> (192 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e99190> (193 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e991d0> (194 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e99210> (195 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e99250> (196 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e99290> (197 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e992d0> (198 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e99310> (199 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e99350> (200 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e99390> (201 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e993d0> (202 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e99410> (203 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e99450> (204 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e99490> (205 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e994d0> (206 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e99510> (207 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e99550> (208 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e99590> (209 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e995d0> (210 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e99610> (211 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e99650> (212 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e99690> (213 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e996d0> (214 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e99710> (215 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e99750> (216 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e99790> (217 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e997d0> (218 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e99810> (219 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e99850> (220 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e99890> (221 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e998d0> (222 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e99910> (223 of 224)
# Creating importer for <pybug.io.image.PILImporter object at 0x107e99950> (224 of 224)

# %% [markdown]
# Use **pickle** to load a previously build *AAM*:

# %%
import pickle

# load a previously buid AAM
aam = pickle.load(open('/Users/joan/PhD/Models/lfpw_pwa_multi', "rb"))

reference_frame = aam["ref_frame_list"][-1]
appearance_model = aam["appearance_model_list"][-1]
shape_model = aam["shape_model_list"][-1]

# %%
appearance_model.trim_components(n_components=51)
shape_model.trim_components(n_components=11)
appearance_model.n_components = 50
shape_model.n_components = 10

# %% [markdown]
# ### 2. Fit
#
# Randomly select an image to fit:

# %%
import numpy as np

# select a test image at random
ind = np.random.randint(len(images))
test_image = images[ind].as_greyscale()
test_shape = shapes[ind]

# %%
from pybug.image import MaskedNDImage
test_image2 = MaskedNDImage(test_image.pixels, mask=test_image.mask)
test_image2.landmarks = test_image.landmarks
test_image = test_image2

# %%
test_image.landmarks.view()
gcf().set_size_inches((10,10))

# %%
test_shape.view()

# %% [markdown]
# Visualize ground truth landmarks and warped appearance for the selected test image:

# %%
from pybug.transform.piecewiseaffine import PiecewiseAffineTransform
from pybug.shape import TriMesh

source = reference_frame.landmarks['ibug_68_trimesh'].lms

template_pwa = PiecewiseAffineTransform(source, test_shape)
template = test_image.warp_to(reference_frame.mask, template_pwa)

test_image.landmarks["ground_truth"] = test_shape
test_image.landmarks['ground_truth'].view_new()
gcf().set_size_inches((10,10))

template.landmarks['reference'] = source
template.landmarks['reference'].view_new()
gcf().set_size_inches((6,6))

# %% [markdown]
# Initialize the fitting procedure by perturbing the true scale and translation parameters of the manually annotated shape:

# %%
from pybug.transform.affine import SimilarityTransform
import numpy as np

# create a transform in the model space to perturb the fitting
model_transform = SimilarityTransform.from_vector(0.0 * np.random.randn(4)) 
#print 'pertubation of the mean:'
#print model_transform

# perturb the mean by the transform, and find the optimal (incorrect) transform from the 
# model to the ground truth test_shape
peturbed_mean = model_transform.apply(shape_model.mean)
# this transform is obviously non-optimal (because of the pertubation, and the error is
# not dependent on the scale of the target, as we performed the pertubation in model space.
initial_global_transform  = SimilarityTransform.align(peturbed_mean, test_shape)
#print '\ninital transform we will set:'
#print initial_global_transform

optimal_global_transform  = SimilarityTransform.align(shape_model.mean, test_shape)
#print '\nthe optimal transform is:'
#print optimal_global_transform

# %% [markdown]
# Build a Model Driven Transform using the AAM's shape model and Piece Wise Affine (PWA) warps:

# %%
from pybug.transform.modeldriven import OrthoMDTransform
from pybug.transform.affine import SimilarityTransform

model_driven_transform = OrthoMDTransform(shape_model, PiecewiseAffineTransform, initial_global_transform, source=source)

# %%
test_image.landmarks['initial'] = model_driven_transform.target
test_image.landmarks["initial"].view_new()
gcf().set_size_inches((10,10))

initial_warped_image = test_image.warp_to(template.mask, model_driven_transform)
initial_warped_image.landmarks['reference'] =  source
initial_warped_image.landmarks['reference'].view_new()
gcf().set_size_inches((6,6))

# %% [markdown]
# Build three "fitter" objects using the three variations of the Project Out algorithm:

# %%
from pybug.lucaskanade.residual import (LSIntensity, ECC, GaborFourier, 
                                        GradientImages, GradientCorrelation)
from pybug.lucaskanade.appearance import (AlternatingForwardAdditive, AlternatingForwardCompositional,
                                           AlternatingInverseCompositional)
from copy import deepcopy

# standard Least Squares Residual
residual = LSIntensity()

# forward additive
fa = AlternatingForwardAdditive(appearance_model, residual, deepcopy(model_driven_transform))
# forward compositional
fc = AlternatingForwardCompositional(appearance_model, residual, deepcopy(model_driven_transform))
# inverse compositional
ic = AlternatingInverseCompositional(appearance_model, residual, deepcopy(model_driven_transform))

# %% [markdown]
# Fit the image using all three different methods:

# %%
# %prun optimal_transform_1 = fa.align(test_image, model_driven_transform.as_vector(), max_iters=50)

# %%
# %prun optimal_transform_2 = fc.align(test_image, model_driven_transform.as_vector(), max_iters=50)

# %%
# %prun optimal_transform_3 = ic.align(test_image, model_driven_transform.as_vector(), max_iters=50)

# %% [markdown]
# Visualize the results:

# %%
fitted_appearance_1 = test_image.warp_to(template.mask, optimal_transform_1)
fitted_appearance_2 = test_image.warp_to(template.mask, optimal_transform_2)
fitted_appearance_3 = test_image.warp_to(template.mask, optimal_transform_3)

fitted_appearance_1.landmarks['reference'] = source
fitted_appearance_1.landmarks['reference'].view_new()

fitted_appearance_2.landmarks['reference'] = source
fitted_appearance_2.landmarks['reference'].view_new()

fitted_appearance_3.landmarks['reference'] = source
fitted_appearance_3.landmarks['reference'].view_new()

# %%
test_image.landmarks['fa'] = optimal_transform_1.target
test_image.landmarks['fc'] = optimal_transform_2.target
test_image.landmarks['ic'] = optimal_transform_3.target

test_image.landmarks['fa'].view_new()

test_image.landmarks['fc'].view_new()

test_image.landmarks['ic'].view_new()

# %%
from pybug.transform.modeldriven import GlobalMDTransform
from pybug.transform import SimilarityTransform
import numpy as np

ini_md_trans = []

for s in shapes:
    sim_trans_params = SimilarityTransform.align(shape_model.mean, s).as_vector()
    sim_trans_params[1] = 0
    sim_trans = SimilarityTransform.from_vector(sim_trans_params)
    ini_md_trans.append(GlobalMDTransform(shape_model, PiecewiseAffineTransform, sim_trans, source=source))

# %%
from pybug.image import MaskedNDImage
gs_images = [MaskedNDImage(img.as_greyscale().pixels) for img in images]

# %%
opt_trans_alternating = [deepcopy(ic.align(img, mdtrans.as_vector(), max_iters=75)) 
                         for img, mdtrans in zip(gs_images, ini_md_trans)]

# %%
def compute_rmse(fitted, ground_truth):
    return np.sqrt(np.mean((fitted.flatten() - ground_truth.flatten()) ** 2))

  
def compute_p2pe(fitted, ground_truth):
    return np.mean(np.sqrt(np.sum((fitted - ground_truth) ** 2, axis=-1)))


def compute_rame(fitted, ground_truth):
    face_size = mean(np.max(ground_truth, axis=0) - np.min(ground_truth, axis=0))
    return compute_p2pe(fitted, ground_truth) / face_size


def compute_me17(fitted, ground_truth, leye, reye):
    return (compute_p2pe(fitted, ground_truth) / 
            compute_p2pe(leye, reye))

# %%
shapes_alternating = [t.target for t in opt_trans_alternating]
error = np.array([compute_rame(a.points, s.points) for a, s in zip(shapes_alternating, shapes)])

# %%
from __future__ import division

stop = 0.05
step = 0.001

xs = np.arange(0, stop, step)
cumulative_error = np.zeros_like(xs)

for i, limit in enumerate(xs):
    cumulative_error[i] = (np.count_nonzero(error < limit) / len(images))

plot(xs, cumulative_error)

# %%
(np.count_nonzero(error < 0.04) / len(images))
# Out:
# 0.5223214285714286

# %%
ind = 4
images[ind].landmarks['f'] = opt_trans_alternating[ind].target
images[ind].landmarks['f'].view()
gcf().set_size_inches((10,10))
