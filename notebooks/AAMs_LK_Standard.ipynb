# %% [markdown]
# #### 1. Load Training Data

# %%
from pybug.io import auto_import
from pybug.image import RGBImage, MaskedNDImage

images = auto_import('/Users/joan/PhD/DataBases/lfpw/trainset/*.png', max_images=811)
images = [i.as_greyscale() if type(i) is RGBImage else i for i in images]

# %% [markdown]
# #### 2. Build AAMs

# %%
from pybug.activeappearancemodel.base import AAM
from pybug.activeappearancemodel.builder import aam_builder
from pybug.transform.tps import TPS
from pybug.landmark import ibug_68_trimesh

options = {'triangulation': {'function': ibug_68_trimesh, 'label': 'ibug_68_trimesh'},
           'features': {'type': 'igo', 'options': {'double_angles': True}},
           'max_shape_components': 25,
           'max_appearance_components': 500,
           'n_levels': 3}


aam = aam_builder(images, **options)

# %%
import pickle

obj = pickle.load(open('/Users/joan/PhD/Models/lfpw_igo', "rb"))
aam = obj["aam"]

# %% [markdown]
# #### 3. View Instance

# %%
aam.instance(np.random.randn(12), np.random.randn(200), level=1).view()

# %% [markdown]
# #### 4. Load Test Data

# %%
from pybug.io import auto_import
from pybug.image import RGBImage

# load the training images of the LFPW database as landmarked images using the autoimporter
images = auto_import('/Users/joan/PhD/DataBases/afw/*.jpg')
images = [i.as_greyscale() if type(i) is RGBImage else i for i in images]

# crop images around their landmarks
for i in images:
    i.crop_to_landmarks_proportion(0.2)
# Out:
# Found 337 files. (0/337) are importable
# Found 337 files. (337/337) are importable
# Creating importer for <pybug.io.image.PILImporter object at 0x121a1ca10> (1 of 337)
# Creating importer for <pybug.io.image.PILImporter object at 0x121a1ce90> (2 of 337)
# Creating importer for <pybug.io.image.PILImporter object at 0x121a1c110> (3 of 337)
# Creating importer for <pybug.io.image.PILImporter object at 0x121a1cc50> (4 of 337)
# Creating importer for <pybug.io.image.PILImporter object at 0x121a1c7d0> (5 of 337)
# Creating importer for <pybug.io.image.PILImporter object at 0x121a1c710> (6 of 337)
# Creating importer for <pybug.io.image.PILImporter object at 0x121f23650> (7 of 337)
# Creating importer for <pybug.io.image.PILImporter object at 0x121f23ad0> (8 of 337)
# Creating importer for <pybug.io.image.PILImporter object at 0x121f23890> (9 of 337)
# Creating importer for <pybug.io.image.PILImporter object at 0x1215c8a50> (10 of 337)
# ...

# %%
images[6].landmarks['PTS'].view()

# %% [markdown]
# #### 5. Fit AAM to Test Data

# %%
aam.initialize_lk(n_shape=[3, 6, 12], n_appearance=[250, 250, 250])

# %%
fitted_transforms = aam.lk_fit_landmarked_database(images, runs=1, noise_std=0.0, verbose=True)

# %% [markdown]
# #### 6. Evaluate Performance

# %%
from pybug.activeappearancemodel.accuracy import plot_ced
from pybug.transform.affine import UniformScale
from __future__ import division

original_landmarks = [i.landmarks['PTS'].lms for i in images]

fitted_landmarks = []
for ft in fitted_transforms:
    for f in ft:
        fitted_landmarks.append(UniformScale(1,2).apply(f[-1].target))

errors = plot_ced(fitted_landmarks, original_landmarks, label='AIC')[0]

fitted_landmarks = []
for ft in fitted_transforms:
    for f in ft:
        fitted_landmarks.append(UniformScale(2,2).apply(f[-2].target))

plot_ced(fitted_landmarks, original_landmarks, label='AIC')

fitted_landmarks = []
for ft in fitted_transforms:
    for f in ft:
        fitted_landmarks.append(UniformScale(4,2).apply(f[-3].target))

plot_ced(fitted_landmarks, original_landmarks, label='AIC');

# %%
np.count_nonzero(np.array(errors) < 0.03) / len(images)

# %%
aam.

# %%
aam.appearance_model_pyramid = [aam.appearance_model_pyramid]

# %%
from pybug.lucaskanade import AlternatingSymmetricCompositional, AlternatingBidirectionalCompositional, ProbabilisticSymmetricCompositional, ProbabilisticBidirectionalCompositional, ProjectOutSymmetricCompositional
from pybug.lucaskanade.residual import Huber, GemanMcClure, L1L2

aam.initialize_lk(n_shape=[3, 6, 6], n_appearance=[200, 200, 200], lk_algorithm=AlternatingSymmetricCompositional)

# %%
fitted_transforms = aam.lk_fit_landmarked_database(images, runs=1, noise_std=0.02, verbose=True, view=True, max_iters=20)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-dc3a3a852479> in <module>()
# ----> 1 fitted_transforms = aam.lk_fit_landmarked_database(images, runs=1, noise_std=0.02, verbose=True, view=True, max_iters=20)
#
# /Users/joan/.virtualenvs/pybug/src/pybug/pybug/activeappearancemodel/base.pyc in lk_fit_landmarked_database(self, images, runs, noise_std, group, max_iters, verbose, view)
#     312                                              noise_std=noise_std,
#     313                                             group=group, max_iters=max_iters,
# --> 314                                             verbose=verbose, view=view))
#     315
#     316         return optimal_transforms
#
# /Users/joan/.virtualenvs/pybug/src/pybug/pybug/activeappearancemodel/base.pyc in lk_fit_landmarked_image(self, image, runs, noise_std, group, max_iters, verbose, view)
# ...

# %%
# %load_ext autoreload
# %autoreload 2

# %%
aam.n_levels

# %%
from pybug.activeappearancemodel.builder import compute_features

features = [compute_features(i, 'hog', mode='sparse') for i in images]

# %%
features[0].landmarks['PTS'].view(channels=6)

# %%
from pybug.transform.affine import AffineTransform

images[0].landmarks['new'] = AffineTransform.align(features[0].landmarks['PTS'].lms, images[0].landmarks['PTS'].lms).apply(features[0].landmarks['PTS'].lms)

# %%
images[0].landmarks['new'].view()

# %%
# %timeit images[0].gradient()

# %%
# %timeit features[0].gradient()
