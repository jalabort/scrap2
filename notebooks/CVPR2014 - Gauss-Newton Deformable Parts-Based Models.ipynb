# %%
# %matplotlib inline
# %pylab inline
import menpo.io as mio

# load training images
training_images = []
for i in mio.import_images('/Users/joan/PhD/DataBases/lfpw/trainset/*.png', max_images=500, 
                           verbose=True):
    # crop image
    i.crop_to_landmarks_proportion_inplace(0.5)
    # convert it to grayscale if needed
    if i.n_channels == 3:
        i = i.as_greyscale(mode='luminosity')
    # append it to the list
    training_images.append(i)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# - Loading 500 assets: [                    ] 0%
# - Loading 500 assets: [                    ] 0%
# - Loading 500 assets: [                    ] 0%
# - Loading 500 assets: [                    ] 0%
# - Loading 500 assets: [                    ] 1%
# - Loading 500 assets: [                    ] 1%
# - Loading 500 assets: [                    ] 1%
# - Loading 500 assets: [                    ] 1%
# - Loading 500 assets: [                    ] 1%
# - Loading 500 assets: [                    ] 2%
# - Loading 500 assets: [                    ] 2%
# - Loading 500 assets: [                    ] 2%
# - Loading 500 assets: [                    ] 2%
# - Loading 500 assets: [                    ] 2%
# - Loading 500 assets: [                    ] 3%
# - Loading 500 assets: [                    ] 3%
# - Loading 500 assets: [                    ] 3%
# - Loading 500 assets: [                    ] 3%
# ...

# %%
from menpo.visualize.widgets import browse_images

#visualize the first image
browse_images(training_images)

# %%
img = training_images[0]
img = img.rescale_landmarks_to_diagonal_range(200)
img.build_mask_around_landmarks((8, 8))
img.view()

# %%
from menpo.fitmultilevel.aam.builder import PartsBasedAAMBuilder, PartsBasedAAMBuilder2
from menpo.image import Image
from skimage.feature import daisy

def daisy_features(image):
    pixels = daisy(image.pixels[..., -1], step=1, rings=1, radius=8, histograms=0)
    img = Image(pixels)
    img.landmarks = image.landmarks
    return img

parts_aam = PartsBasedAAMBuilder(normalization_diagonal=200, feature_type=None, patch_shape=(16, 16)).build(training_images, verbose=True)
# Out:
# - Computing reference shape
# - Normalizing images size: 0%
# - Normalizing images size: 0%
# - Normalizing images size: 0%
# - Normalizing images size: 0%
# - Normalizing images size: 1%
# - Normalizing images size: 1%
# - Normalizing images size: 1%
# - Normalizing images size: 1%
# - Normalizing images size: 1%
# - Normalizing images size: 2%
# - Normalizing images size: 2%
# - Normalizing images size: 2%
# - Normalizing images size: 2%
# - Normalizing images size: 2%
# - Normalizing images size: 3%
# - Normalizing images size: 3%
# - Normalizing images size: 3%
# - Normalizing images size: 3%
# - Normalizing images size: 3%
# - Normalizing images size: 4%
# - Normalizing images size: 4%
# - Normalizing images size: 4%
# - Normalizing images size: 4%
# - Normalizing images size: 4%
# - Normalizing images size: 5%
# - Normalizing images size: 5%
# - Normalizing images size: 5%
# - Normalizing images size: 5%
# - Normalizing images size: 5%
# - Normalizing images size: 6%
# ...

# %%
am = parts_aam.appearance_models[0]
lam = am[25]

# %%
from menpo.image import Image

Image(lam.mean.pixels[...]).view()

# %%
import menpo.io as pio
from menpo.landmark import labeller, ibug_68_trimesh

# load test images
test_images = []
for i in pio.import_images('/Users/joan/PhD/DataBases/afw/*', max_images=10,
                           verbose=True):
    # crop image
    i.crop_to_landmarks_proportion_inplace(0.5)
    # label it
    labeller(i, 'PTS', ibug_68_trimesh)
    # convert it to grayscale if needed
    if i.n_channels == 3:
        i = i.as_greyscale(mode='luminosity')
    # append it to the list
    test_images.append(i)
# Out:
# - Loading 10 assets: [==                  ] 10%
# - Loading 10 assets: [====                ] 20%
# - Loading 10 assets: [======              ] 30%
# - Loading 10 assets: [========            ] 40%
# - Loading 10 assets: [==========          ] 50%
# - Loading 10 assets: [============        ] 60%
# - Loading 10 assets: [==============      ] 70%
# - Loading 10 assets: [================    ] 80%
# - Loading 10 assets: [==================  ] 90%
# - Loading 10 assets: [====================] 100%

# %%
from __future__ import division
import numpy as np
import scipy

from menpo.image import Image
from menpo.fit.lucaskanade.partsbased.base import PartsBasedLucasKanade
from menpo.fitmultilevel.functions import extract_local_patches_fast


class AlternatingForward_(PartsBasedLucasKanade):
    r"""
    """
    def __init__(self, appearance_model, pdm, patch_shape, eps=10**-10):
        super(AlternatingForward_, self).__init__(
            appearance_model, pdm, patch_shape, eps=eps)

    def _set_up(self):
        # Jacobian
        self._dS_dp = self.transform.d_dp([])

        # Prior
        #sim_prior = np.zeros((4,))
        #pdm_prior = 1 / self.transform.model.eigenvalues
        #self._prior = np.hstack((sim_prior, pdm_prior))

    def _fit(self, fitting_result, max_iters=20):
        # Initial error > eps
        error = self.eps + 1
        n_iters = 0

        image = fitting_result.image
        gradient = image.gradient()
        target = self.transform.target

        am = self.appearance_model
        
        for m in am:
            m.n_active_components = 3

        while n_iters < max_iters and error > self.eps:

            pi = []
            # extract parts-based image
            patches = extract_local_patches_fast(
                image, target, patch_shape=self.patch_shape)
            for patch in patches:
                pi.append(Image(patch))
            
            parts_image = Image(patches)

            template = np.zeros_like(parts_image.pixels)
            for k, (m, p) in enumerate(zip(am, pi)):
                # reconstruct parts-based image
                template[k, ...] = m.reconstruct(p).pixels
                
            
            # compute parts-based image error
            parts_error = parts_image.pixels - template
            parts_error = parts_error[:, None, ...]

            # extract parts-based gradient
            parts_gradient = extract_local_patches_fast(
                gradient, target, patch_shape=self.patch_shape)
            parts_gradient = np.reshape(
                parts_gradient, (parts_image.shape[0],)+(1,)+parts_image.shape[1:]+(-1,2))

            # compute steepest-descent images
            J = np.einsum('ijklmn, ion -> ijklmo', parts_gradient, self._dS_dp)

            # compute steepest descent parameter updates
            sd_delta_p = np.einsum('ijklmn, ijklm -> n', J, parts_error)

            # compute hessian
            H = np.einsum('ijklmo, ijklmr -> or', J, J)

            # compute parameter updates
            delta_p = -scipy.linalg.solve(H, sd_delta_p)

            # update pdm parameters
            parameters = self.transform.as_vector() + delta_p
            fitting_result.parameters.append(parameters)
            self.transform.from_vector_inplace(parameters)
            target = self.transform.target

            # test convergence
            error = np.abs(scipy.linalg.norm(delta_p))
            n_iters += 1

        fitting_result.fitted = True
        return fitting_result

# %%
class AlternatingInverse_(PartsBasedLucasKanade):
    r"""
    """
    def __init__(self, appearance_model, pdm, patch_shape, eps=10**-10):
        super(AlternatingInverse_, self).__init__(
            appearance_model, pdm, patch_shape, eps=eps)

    def _set_up(self):
        # Jacobian
        self._dS_dp = self.transform.d_dp([])

        # Prior
        #sim_prior = np.zeros((4,))
        #pdm_prior = 1 / self.transform.model.eigenvalues
        #self._prior = np.hstack((sim_prior, pdm_prior))

    def _fit(self, fitting_result, max_iters=20):
        # Initial error > eps
        error = self.eps + 1
        n_iters = 0

        image = fitting_result.image
        target = self.transform.target

        am = self.appearance_model

        while n_iters < max_iters and error > self.eps:

            # extract parts-based image
            patches = extract_local_patches_fast(
                image, target, patch_shape=self.patch_shape)
            parts_image = Image(patches)

            # reconstruct parts-based image
            template = am.reconstruct(parts_image)

            # compute parts-based image error
            parts_error = template.pixels - parts_image.pixels
            parts_error = parts_error[:, None, ...]


            a = template.pixels.swapaxes(0, 1).swapaxes(1, 2)
            a = np.reshape(a, self.patch_shape+(-1,))
            g = Image(a).gradient()
            g = np.reshape(g.pixels, self.patch_shape+(-1, image.n_channels, 2))
            g = g.swapaxes(2, 1).swapaxes(1, 0)


            parts_gradient = np.reshape(g, (parts_image.shape[0],)+(1,)+parts_image.shape[1:]+(-1, 2))


            # compute steepest-descent images
            J = np.einsum('ijklmn, ion -> ijklmo', parts_gradient, self._dS_dp)

            # compute steepest descent parameter updates
            sd_delta_p = np.einsum('ijklmn, ijklm -> n', J, parts_error)

            # compute hessian
            H = np.einsum('ijklmo, ijklmr -> or', J, J)

            # compute parameter updates
            delta_p = scipy.linalg.solve(H, sd_delta_p)

            # update pdm parameters
            parameters = self.transform.as_vector() + delta_p
            fitting_result.parameters.append(parameters)
            self.transform.from_vector_inplace(parameters)
            target = self.transform.target

            # test convergence
            error = np.abs(scipy.linalg.norm(delta_p))
            n_iters += 1

        fitting_result.fitted = True
        return fitting_result

# %%
class AlternatingSymmetric_(PartsBasedLucasKanade):
    r"""
    """
    def __init__(self, appearance_model, pdm, patch_shape, eps=10**-10):
        super(AlternatingSymmetric_, self).__init__(
            appearance_model, pdm, patch_shape, eps=eps)

    def _set_up(self):
        # Jacobian
        self._dS_dp = self.transform.d_dp([])

        # Prior
        #sim_prior = np.zeros((4,))
        #pdm_prior = 1 / self.transform.model.eigenvalues
        #self._prior = np.hstack((sim_prior, pdm_prior))

    def _fit(self, fitting_result, max_iters=20):
        # Initial error > eps
        error = self.eps + 1
        n_iters = 0

        image = fitting_result.image
        gradient = image.gradient()
        target = self.transform.target

        am = self.appearance_model

        while n_iters < max_iters and error > self.eps:

            # extract parts-based image
            patches = extract_local_patches_fast(
                image, target, patch_shape=self.patch_shape)
            parts_image = Image(patches)

            # reconstruct parts-based image
            template = am.reconstruct(parts_image)

            # compute parts-based image error
            parts_error = template.pixels - parts_image.pixels
            parts_error = parts_error[:, None, ...]
            
            
            # extract parts-based gradient
            parts_gradient = extract_local_patches_fast(
                gradient, target, patch_shape=self.patch_shape)
            parts_gradient1 = np.reshape(
                parts_gradient, (parts_image.shape[0],)+(1,)+parts_image.shape[1:]+(-1,2))

            a = template.pixels.swapaxes(0, 1).swapaxes(1, 2)
            a = np.reshape(a, self.patch_shape+(-1,))
            g = Image(a).gradient()
            g = np.reshape(g.pixels, self.patch_shape+(-1, image.n_channels, 2))
            g = g.swapaxes(2, 1).swapaxes(1, 0)

            parts_gradient2 = np.reshape(g, (parts_image.shape[0],)+(1,)+parts_image.shape[1:]+(-1, 2))
            

            # compute steepest-descent images
            J1 = np.einsum('ijklmn, ion -> ijklmo', parts_gradient1, self._dS_dp)
            J2 = np.einsum('ijklmn, ion -> ijklmo', parts_gradient2, self._dS_dp)
            
            J = 0.5 * (J1 + J2)

            # compute steepest descent parameter updates
            sd_delta_p = np.einsum('ijklmn, ijklm -> n', J, parts_error)

            # compute hessian
            H = np.einsum('ijklmo, ijklmr -> or', J, J)

            # compute parameter updates
            delta_p = scipy.linalg.solve(H, sd_delta_p)

            # update pdm parameters
            parameters = self.transform.as_vector() + delta_p
            fitting_result.parameters.append(parameters)
            self.transform.from_vector_inplace(parameters)
            target = self.transform.target

            # test convergence
            error = np.abs(scipy.linalg.norm(delta_p))
            n_iters += 1

        fitting_result.fitted = True
        return fitting_result

# %%
class AlternatingSymmetric2_(PartsBasedLucasKanade):
    r"""
    """
    def __init__(self, appearance_model, pdm, patch_shape, eps=10**-10):
        super(AlternatingSymmetric2_, self).__init__(
            appearance_model, pdm, patch_shape, eps=eps)

    def _set_up(self):
        # Jacobian
        self._dS_dp = self.transform.d_dp([])

        # Prior
        #sim_prior = np.zeros((4,))
        #pdm_prior = 1 / self.transform.model.eigenvalues
        #self._prior = np.hstack((sim_prior, pdm_prior))

    def _fit(self, fitting_result, max_iters=20):
        # Initial error > eps
        error = self.eps + 1
        n_iters = 0

        image = fitting_result.image
        gradient = image.gradient()
        target = self.transform.target

        am = self.appearance_model

        while n_iters < max_iters and error > self.eps:

            # extract parts-based image
            patches = extract_local_patches_fast(
                image, target, patch_shape=self.patch_shape)
            parts_image = Image(patches)

            # reconstruct parts-based image
            template = am.reconstruct(parts_image)

            # compute parts-based image error
            parts_error = template.pixels - parts_image.pixels
            parts_error = parts_error[:, None, ...]
            
            
            # extract parts-based gradient
            parts_gradient = extract_local_patches_fast(
                gradient, target, patch_shape=self.patch_shape)
            parts_gradient1 = np.reshape(
                parts_gradient, (parts_image.shape[0],)+(1,)+parts_image.shape[1:]+(-1,2))

            a = template.pixels.swapaxes(0, 1).swapaxes(1, 2)
            a = np.reshape(a, self.patch_shape+(-1,))
            g = Image(a).gradient()
            g = np.reshape(g.pixels, self.patch_shape+(-1, image.n_channels, 2))
            g = g.swapaxes(2, 1).swapaxes(1, 0)

            parts_gradient2 = np.reshape(g, (parts_image.shape[0],)+(1,)+parts_image.shape[1:]+(-1, 2))
            
            # compute steepest-descent images
            J1 = np.einsum('ijklmn, ion -> ijklmo', parts_gradient1, self._dS_dp)
            H1 = np.einsum('ijklmo, ijklmr -> or', J1, J1)
            inv_H1 = np.linalg.inv(H1)
            pseudo1 = np.einsum('or, ijklmo -> ijklmr', inv_H1, J1)
            
            J2 = np.einsum('ijklmn, ion -> ijklmo', parts_gradient2, self._dS_dp)
            H2 = np.einsum('ijklmo, ijklmr -> or', J2, J2)
            inv_H2 = np.linalg.inv(H2)
            pseudo2 = np.einsum('or, ijklmr -> ijklmo', inv_H2, J2)
            
            pseudo = 0.5 * (pseudo1 + pseudo2)
            
            # compute parameter updates
            delta_p  = np.einsum('ijklmn, ijklm -> n', pseudo, parts_error)
            
            # update pdm parameters
            parameters = self.transform.as_vector() + delta_p
            fitting_result.parameters.append(parameters)
            self.transform.from_vector_inplace(parameters)
            target = self.transform.target

            # test convergence
            error = np.abs(scipy.linalg.norm(delta_p))
            n_iters += 1

        fitting_result.fitted = True
        return fitting_result

# %%
class AlternatingBidirectional_(PartsBasedLucasKanade):
    r"""
    """
    def __init__(self, appearance_model, pdm, patch_shape, eps=10**-10):
        super(AlternatingBidirectional_, self).__init__(
            appearance_model, pdm, patch_shape, eps=eps)

    def _set_up(self):
        # Jacobian
        self._dS_dp = self.transform.d_dp([])

        # Prior
        #sim_prior = np.zeros((4,))
        #pdm_prior = 1 / self.transform.model.eigenvalues
        #self._prior = np.hstack((sim_prior, pdm_prior))

    def _fit(self, fitting_result, max_iters=20):
        # Initial error > eps
        error = self.eps + 1
        n_iters = 0

        image = fitting_result.image
        gradient = image.gradient()
        target = self.transform.target

        am = self.appearance_model
        n_params = self.transform.n_parameters

        while n_iters < max_iters and error > self.eps:

            # extract parts-based image
            patches = extract_local_patches_fast(
                image, target, patch_shape=self.patch_shape)
            parts_image = Image(patches)

            # reconstruct parts-based image
            template = am.reconstruct(parts_image)

            # compute parts-based image error
            parts_error = template.pixels - parts_image.pixels
            parts_error = parts_error[:, None, ...]
            
            
            # extract parts-based gradient
            parts_gradient = extract_local_patches_fast(
                gradient, target, patch_shape=self.patch_shape)
            parts_gradient1 = np.reshape(
                parts_gradient, (parts_image.shape[0],)+(1,)+parts_image.shape[1:]+(-1,2))

            a = template.pixels.swapaxes(0, 1).swapaxes(1, 2)
            a = np.reshape(a, self.patch_shape+(-1,))
            g = Image(a).gradient()
            g = np.reshape(g.pixels, self.patch_shape+(-1, image.n_channels, 2))
            g = g.swapaxes(2, 1).swapaxes(1, 0)

            parts_gradient2 = np.reshape(g, (parts_image.shape[0],)+(1,)+parts_image.shape[1:]+(-1, 2))
            
            # compute steepest-descent images
            J1 = np.einsum('ijklmn, ion -> ijklmo', parts_gradient1, self._dS_dp)
            J2 = np.einsum('ijklmn, ion -> ijklmo', parts_gradient2, self._dS_dp)
            
            J = np.concatenate((J1, J2), axis=5)
            
            # compute steepest descent parameter updates
            sd_delta_p = np.einsum('ijklmn, ijklm -> n', J, parts_error)

            # compute hessian
            H = np.einsum('ijklmo, ijklmr -> or', J, J)

            # compute parameter updates
            delta_p = scipy.linalg.solve(H, sd_delta_p)

            # update pdm parameters
            parameters = self.transform.as_vector() + delta_p[:n_params] + delta_p[n_params:]
            fitting_result.parameters.append(parameters)
            self.transform.from_vector_inplace(parameters)
            target = self.transform.target

            # test convergence
            error = np.abs(scipy.linalg.norm(delta_p))
            n_iters += 1

        fitting_result.fitted = True
        return fitting_result

# %%
class AlternatingForward_SD_(PartsBasedLucasKanade):
    r"""
    """
    def __init__(self, appearance_model, pdm, patch_shape, eps=10**-10):
        super(AlternatingForward_SD_, self).__init__(
            appearance_model, pdm, patch_shape, eps=eps)

    def _set_up(self):
        # Jacobian
        self._dS_dp = self.transform.d_dp([])

        # Prior
        #sim_prior = np.zeros((4,))
        #pdm_prior = 1 / self.transform.model.eigenvalues
        #self._prior = np.hstack((sim_prior, pdm_prior))

    def _fit(self, fitting_result, max_iters=20):
        # Initial error > eps
        error = self.eps + 1
        n_iters = 0

        image = fitting_result.image
        gradient = image.gradient()
        target = self.transform.target

        am = self.appearance_model

        while n_iters < max_iters and error > self.eps:

            # extract parts-based image
            patches = extract_local_patches_fast(
                image, target, patch_shape=self.patch_shape)
            parts_image = Image(patches)

            # reconstruct parts-based image
            template = am.reconstruct(parts_image)

            # compute parts-based image error
            parts_error = parts_image.pixels - template.pixels
            parts_error = parts_error[:, None, ...]

            # extract parts-based gradient
            parts_gradient = extract_local_patches_fast(
                gradient, target, patch_shape=self.patch_shape)
            parts_gradient = np.reshape(
                parts_gradient, (parts_image.shape[0],)+(1,)+parts_image.shape[1:]+(-1,2))

            # compute steepest-descent images
            J = np.einsum('ijklmn, ion -> ijklmo', parts_gradient, self._dS_dp)

            # compute steepest descent parameter updates
            delta_p = -np.einsum('ijklmn, ijklm -> n', J, parts_error)

            # update pdm parameters
            parameters = self.transform.as_vector() + delta_p
            fitting_result.parameters.append(parameters)
            self.transform.from_vector_inplace(parameters)
            target = self.transform.target

            # test convergence
            error = np.abs(scipy.linalg.norm(delta_p))
            n_iters += 1

        fitting_result.fitted = True
        return fitting_result

# %%
class AlternatingInverse_SD_(PartsBasedLucasKanade):
    r"""
    """
    def __init__(self, appearance_model, pdm, patch_shape, eps=10**-10):
        super(AlternatingInverse_SD_, self).__init__(
            appearance_model, pdm, patch_shape, eps=eps)

    def _set_up(self):
        # Jacobian
        self._dS_dp = self.transform.d_dp([])

        # Prior
        #sim_prior = np.zeros((4,))
        #pdm_prior = 1 / self.transform.model.eigenvalues
        #self._prior = np.hstack((sim_prior, pdm_prior))

    def _fit(self, fitting_result, max_iters=20):
        # Initial error > eps
        error = self.eps + 1
        n_iters = 0

        image = fitting_result.image
        target = self.transform.target

        am = self.appearance_model

        while n_iters < max_iters and error > self.eps:

            # extract parts-based image
            patches = extract_local_patches_fast(
                image, target, patch_shape=self.patch_shape)
            parts_image = Image(patches)

            # reconstruct parts-based image
            template = am.reconstruct(parts_image)

            # compute parts-based image error
            parts_error = template.pixels - parts_image.pixels
            parts_error = parts_error[:, None, ...]


            a = template.pixels.swapaxes(0, 1).swapaxes(1, 2)
            a = np.reshape(a, self.patch_shape+(-1,))
            g = Image(a).gradient()
            g = np.reshape(g.pixels, self.patch_shape+(-1, image.n_channels, 2))
            g = g.swapaxes(2, 1).swapaxes(1, 0)


            parts_gradient = np.reshape(g, (parts_image.shape[0],)+(1,)+parts_image.shape[1:]+(-1, 2))


            # compute steepest-descent images
            J = np.einsum('ijklmn, ion -> ijklmo', parts_gradient, self._dS_dp)

            # compute steepest descent parameter updates
            delta_p = np.einsum('ijklmn, ijklm -> n', J, parts_error)

            # update pdm parameters
            parameters = self.transform.as_vector() + delta_p
            fitting_result.parameters.append(parameters)
            self.transform.from_vector_inplace(parameters)
            target = self.transform.target

            # test convergence
            error = np.abs(scipy.linalg.norm(delta_p))
            n_iters += 1

        fitting_result.fitted = True
        return fitting_result

# %%
class AlternatingSymmetric_SD_(PartsBasedLucasKanade):
    r"""
    """
    def __init__(self, appearance_model, pdm, patch_shape, eps=10**-10):
        super(AlternatingSymmetric_SD_, self).__init__(
            appearance_model, pdm, patch_shape, eps=eps)

    def _set_up(self):
        # Jacobian
        self._dS_dp = self.transform.d_dp([])

        # Prior
        #sim_prior = np.zeros((4,))
        #pdm_prior = 1 / self.transform.model.eigenvalues
        #self._prior = np.hstack((sim_prior, pdm_prior))

    def _fit(self, fitting_result, max_iters=20):
        # Initial error > eps
        error = self.eps + 1
        n_iters = 0

        image = fitting_result.image
        gradient = image.gradient()
        target = self.transform.target

        am = self.appearance_model

        while n_iters < max_iters and error > self.eps:

            # extract parts-based image
            patches = extract_local_patches_fast(
                image, target, patch_shape=self.patch_shape)
            parts_image = Image(patches)

            # reconstruct parts-based image
            template = am.reconstruct(parts_image)

            # compute parts-based image error
            parts_error = template.pixels - parts_image.pixels
            parts_error = parts_error[:, None, ...]
            
            
            # extract parts-based gradient
            parts_gradient = extract_local_patches_fast(
                gradient, target, patch_shape=self.patch_shape)
            parts_gradient1 = np.reshape(
                parts_gradient, (parts_image.shape[0],)+(1,)+parts_image.shape[1:]+(-1,2))

            a = template.pixels.swapaxes(0, 1).swapaxes(1, 2)
            a = np.reshape(a, self.patch_shape+(-1,))
            g = Image(a).gradient()
            g = np.reshape(g.pixels, self.patch_shape+(-1, image.n_channels, 2))
            g = g.swapaxes(2, 1).swapaxes(1, 0)

            parts_gradient2 = np.reshape(g, (parts_image.shape[0],)+(1,)+parts_image.shape[1:]+(-1, 2))
            

            # compute steepest-descent images
            J1 = np.einsum('ijklmn, ion -> ijklmo', parts_gradient1, self._dS_dp)
            J2 = np.einsum('ijklmn, ion -> ijklmo', parts_gradient2, self._dS_dp)
            
            J = 0.5 * (J1 + J2)

            # compute steepest descent parameter updates
            delta_p = np.einsum('ijklmn, ijklm -> n', J, parts_error)

            # update pdm parameters
            parameters = self.transform.as_vector() + delta_p
            fitting_result.parameters.append(parameters)
            self.transform.from_vector_inplace(parameters)
            target = self.transform.target

            # test convergence
            error = np.abs(scipy.linalg.norm(delta_p))
            n_iters += 1

        fitting_result.fitted = True
        return fitting_result

# %%
class AlternatingInverse_LM_(PartsBasedLucasKanade):
    r"""
    """
    def __init__(self, appearance_model, pdm, patch_shape, eps=10**-10):
        super(AlternatingInverse_LM_, self).__init__(
            appearance_model, pdm, patch_shape, eps=eps)

    def _set_up(self):
        # Jacobian
        self._dS_dp = self.transform.d_dp([])

        # Prior
        #sim_prior = np.zeros((4,))
        #pdm_prior = 1 / self.transform.model.eigenvalues
        #self._prior = np.hstack((sim_prior, pdm_prior))

    def _fit(self, fitting_result, max_iters=20):
        # Initial error > eps
        err = self.eps + 1
        n_iters = 0

        image = fitting_result.image
        target = self.transform.target

        am = self.appearance_model
        n_params = self.transform.n_parameters
        d = 0.01
        
        # extract parts-based image
        patches = extract_local_patches_fast(
            image, target, patch_shape=self.patch_shape)
        parts_image = Image(patches)
        
        # reconstruct parts-based image
        template = am.reconstruct(parts_image)
        
        # compute parts-based image error
        parts_error = template.pixels - parts_image.pixels
        parts_error = parts_error[:, None, ...]
        
        error = np.sum(parts_error.ravel() ** 2)

        while n_iters < max_iters and err > self.eps:

            a = template.pixels.swapaxes(0, 1).swapaxes(1, 2)
            a = np.reshape(a, self.patch_shape+(-1,))
            g = Image(a).gradient()
            g = np.reshape(g.pixels, self.patch_shape+(-1, image.n_channels, 2))
            g = g.swapaxes(2, 1).swapaxes(1, 0)

            parts_gradient = np.reshape(g, (parts_image.shape[0],)+(1,)+parts_image.shape[1:]+(-1, 2))

            # compute steepest-descent images
            J = np.einsum('ijklmn, ion -> ijklmo', parts_gradient, self._dS_dp)

            # compute steepest descent parameter updates
            sd_delta_p = np.einsum('ijklmn, ijklm -> n', J, parts_error)

            # compute hessian
            H1 = np.einsum('ijklmo, ijklmr -> or', J, J)
            
            line_search = True
            
            while n_iters < max_iters:
                
                H = H1 + d * np.eye(n_params) #np.diag(np.diag(H1))

                # compute parameter updates
                delta_p = scipy.linalg.solve(H, sd_delta_p)

                # update pdm parameters
                parameters = self.transform.as_vector() + delta_p
                self.transform.from_vector_inplace(parameters)
                target = self.transform.target

                # CHECK

                # extract parts-based image
                new_patches = extract_local_patches_fast(
                    image, target, patch_shape=self.patch_shape)
                new_parts_image = Image(new_patches)
                # compute parts-based image error
                new_parts_error = template.pixels - new_parts_image.pixels
                new_parts_error = new_parts_error[:, None, ...]
                # error
                new_error = np.sum(new_parts_error.ravel() ** 2)
                
                n_iters += 1

                if new_error < error:
                    print 'no_line'
                    
                    # accept step
                    d /= 2     
                    break
                else:
                    print 'line'
                    
                    d *= 2
                    
            patches = new_patches
            parts_image = new_parts_image

            # reconstruct parts-based image
            template = am.reconstruct(parts_image)

            # compute parts-based image error
            parts_error = template.pixels - parts_image.pixels
            parts_error = parts_error[:, None, ...]

            error = np.sum(parts_error.ravel() ** 2)

            # test convergence
            err = np.abs(scipy.linalg.norm(delta_p))

            fitting_result.parameters.append(parameters)
            
            
        fitting_result.fitted = True
        return fitting_result

# %%
class AlternatingInverse_N_(PartsBasedLucasKanade):
    r"""
    """
    def __init__(self, appearance_model, pdm, patch_shape, eps=10**-10):
        super(AlternatingInverse_N_, self).__init__(
            appearance_model, pdm, patch_shape, eps=eps)

    def _set_up(self):
        # Jacobian
        self._dS_dp = self.transform.d_dp([])

        # Prior
        #sim_prior = np.zeros((4,))
        #pdm_prior = 1 / self.transform.model.eigenvalues
        #self._prior = np.hstack((sim_prior, pdm_prior))

    def _fit(self, fitting_result, max_iters=20):
        # Initial error > eps
        error = self.eps + 1
        n_iters = 0

        image = fitting_result.image
        target = self.transform.target

        am = self.appearance_model

        while n_iters < max_iters and error > self.eps:

            # extract parts-based image
            patches = extract_local_patches_fast(
                image, target, patch_shape=self.patch_shape)
            parts_image = Image(patches)

            # reconstruct parts-based image
            template = am.reconstruct(parts_image)

            # compute parts-based image error
            parts_error = template.pixels - parts_image.pixels
            parts_error = parts_error[:, None, ...]


            a = template.pixels.swapaxes(0, 1).swapaxes(1, 2)
            a = np.reshape(a, self.patch_shape+(-1,))
            g = Image(a).gradient()
            gg = g.gradient()
            g = np.reshape(g.pixels, self.patch_shape+(-1, image.n_channels, 2))
            gg = np.reshape(gg.pixels, self.patch_shape+(-1, image.n_channels, 2, 2))
            g = g.swapaxes(2, 1).swapaxes(1, 0)
            gg = gg.swapaxes(2, 1).swapaxes(1, 0)


            parts_gradient = np.reshape(g, (parts_image.shape[0],)+(1,)+parts_image.shape[1:]+(-1, 2))
            parts_gg = np.reshape(gg, (parts_image.shape[0],)+(1,)+parts_image.shape[1:]+(-1, 2, 2))


            # compute steepest-descent images
            J = np.einsum('ijklmn, ion -> ijklmo', parts_gradient, self._dS_dp)

            # compute steepest descent parameter updates
            sd_delta_p = np.einsum('ijklmn, ijklm -> n', J, parts_error)
            
            # compute steepest-descent images
            JJ = np.einsum('ijklmpn, ion -> ijklmop', parts_gg, self._dS_dp)
            # compute steepest-descent images
            JJ = np.einsum('ijklmop, irp -> ijklmor', JJ, self._dS_dp)
            # compute steepest descent parameter updates
            HH = np.einsum('ijklmor, ijklm -> or', JJ, parts_error)

            # compute hessian
            H = np.einsum('ijklmo, ijklmr -> or', J, J) + HH

            # compute parameter updates
            delta_p = scipy.linalg.solve(H, sd_delta_p)

            # update pdm parameters
            parameters = self.transform.as_vector() + delta_p
            fitting_result.parameters.append(parameters)
            self.transform.from_vector_inplace(parameters)
            target = self.transform.target

            # test convergence
            error = np.abs(scipy.linalg.norm(delta_p))
            n_iters += 1

        fitting_result.fitted = True
        return fitting_result

# %%
class AlternatingSymmetric_N_(PartsBasedLucasKanade):
    r"""
    """
    def __init__(self, appearance_model, pdm, patch_shape, eps=10**-10):
        super(AlternatingSymmetric_N_, self).__init__(
            appearance_model, pdm, patch_shape, eps=eps)

    def _set_up(self):
        # Jacobian
        self._dS_dp = self.transform.d_dp([])

        # Prior
        #sim_prior = np.zeros((4,))
        #pdm_prior = 1 / self.transform.model.eigenvalues
        #self._prior = np.hstack((sim_prior, pdm_prior))

    def _fit(self, fitting_result, max_iters=20):
        # Initial error > eps
        error = self.eps + 1
        n_iters = 0

        image = fitting_result.image
        gradient = image.gradient()
        gg2 = gradient.gradient()
        target = self.transform.target

        am = self.appearance_model

        while n_iters < max_iters and error > self.eps:

            # extract parts-based image
            patches = extract_local_patches_fast(
                image, target, patch_shape=self.patch_shape)
            parts_image = Image(patches)

            # reconstruct parts-based image
            template = am.reconstruct(parts_image)

            # compute parts-based image error
            parts_error = template.pixels - parts_image.pixels
            parts_error = parts_error[:, None, ...]


            a = template.pixels.swapaxes(0, 1).swapaxes(1, 2)
            a = np.reshape(a, self.patch_shape+(-1,))
            g = Image(a).gradient()
            gg = g.gradient()
            g = np.reshape(g.pixels, self.patch_shape+(-1, image.n_channels, 2))
            gg = np.reshape(gg.pixels, self.patch_shape+(-1, image.n_channels, 2, 2))
            g = g.swapaxes(2, 1).swapaxes(1, 0)
            gg = gg.swapaxes(2, 1).swapaxes(1, 0)


            parts_gradient1 = np.reshape(g, (parts_image.shape[0],)+(1,)+parts_image.shape[1:]+(-1, 2))
            parts_gg1 = np.reshape(gg, (parts_image.shape[0],)+(1,)+parts_image.shape[1:]+(-1, 2, 2))
            
            # extract parts-based gradient
            parts_gradient = extract_local_patches_fast(
                gradient, target, patch_shape=self.patch_shape)
            parts_gradient2 = np.reshape(
                parts_gradient, (parts_image.shape[0],)+(1,)+parts_image.shape[1:]+(-1, 2))
            
            parts_gradient = extract_local_patches_fast(
                gg2, target, patch_shape=self.patch_shape)
            parts_gg2 = np.reshape(
                parts_gradient, (parts_image.shape[0],)+(1,)+parts_image.shape[1:]+(-1 ,2, 2))

            
            parts_gradient = (parts_gradient1 + parts_gradient2)
            parts_gg = (parts_gg1 + parts_gg2)

            # compute steepest-descent images
            J = np.einsum('ijklmn, ion -> ijklmo', parts_gradient, self._dS_dp)

            # compute steepest descent parameter updates
            sd_delta_p = np.einsum('ijklmn, ijklm -> n', J, parts_error)
            
            # compute steepest-descent images
            JJ = np.einsum('ijklmpn, ion -> ijklmop', parts_gg, self._dS_dp)
            # compute steepest-descent images
            JJ = np.einsum('ijklmop, irp -> ijklmor', JJ, self._dS_dp)
            # compute steepest descent parameter updates
            HH = np.einsum('ijklmor, ijklm -> or', JJ, parts_error)

            # compute hessian
            H = np.einsum('ijklmo, ijklmr -> or', J, J) + HH

            # compute parameter updates
            delta_p = scipy.linalg.solve(H, sd_delta_p)

            # update pdm parameters
            parameters = self.transform.as_vector() + 2*delta_p
            fitting_result.parameters.append(parameters)
            self.transform.from_vector_inplace(parameters)
            target = self.transform.target

            # test convergence
            error = np.abs(scipy.linalg.norm(delta_p))
            n_iters += 1

        fitting_result.fitted = True
        return fitting_result

# %%
from menpo.fitmultilevel.aam.base import LucasKanadePartsBasedAAMFitter

fitter = LucasKanadePartsBasedAAMFitter(parts_aam, algorithm=AlternatingInverse_N_, n_shape=[3, 6, 12], n_appearance=[100, 100, 100])

# %%
fitting_results = []
for j, i in enumerate(test_images[:10]):
    gt_s = i.landmarks['PTS'].lms
    s = fitter.perturb_shape(gt_s)
    print 'Image: ', j
    fr = fitter.fit(i, s, gt_shape=gt_s, max_iters=50)
    fitting_results.append(fr)
# Out:
# Image:  0
# Image:
#  1
# Image:
#  2
# Image:
#  3
# Image:
#  4
# Image:
#  5
# Image:
#  6
# Image:
#  7
# Image:
#  8
# Image:
#  9

# %%
final_images = [fr.final_image for fr in fitting_results]

# %%
from menpo.visualize.widgets import browse_final_images

browse_final_images(final_images)

# %%
final_errors = [fr.final_error() for fr in fitting_results]

# %%
from menpo.visualize.widgets import plot_error_evolution_graph

fr = fitting_results[1]

plot_error_evolution_graph(fr.errors())

# %%
import line_profiler
import IPython

ip = IPython.get_ipython()
ip.define_magic('lprun', line_profiler.magic_lprun)

# %%
from menpo.fit.lucaskanade.partsbased.appearance import AlternatingForward
from menpo.model.modelinstance import OrthoPDM

# %%
# %lprun -f AlternatingForward_._fit fitter.fit(i, s, gt_shape=gt_s)

# %%
# %timeit fitter.fit(i, s, gt_shape=gt_s)
# Out:
# 1 loops, best of 3: 486 ms per loop
