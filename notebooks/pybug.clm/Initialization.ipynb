# %%
import pybug.io as pio
from pybug.landmark import labeller, ibug_68_points, ibug_68_trimesh

training_images = []
# load landmarked imarges
for i in pio.import_images('/data/PhD/DataBases/lfpw/trainset/*.png', max_images=811):
    i.crop_to_landmarks_proportion(0.4)
    if i.n_channels == 3:
        training_images.append(i.as_greyscale(mode='luminosity'))
    else:
        training_images.append(i)

# %%
# visualize the first image
# %matplotlib inline
training_images[0].landmarks['PTS'].view()

# %%
image = training_images[0]

def hog_closure(image):
    return image.features.hog(mode='sparse')

# %matplotlib inline
a = hog_closure(training_images[0])
a.landmarks['PTS'].view(channels=0)

# %%
from pybug.aam.base import aam_builder
from pybug.transform.piecewiseaffine import PiecewiseAffineTransform
from pybug.image import Image

# label images
labeller(training_images, 'PTS', ibug_68_trimesh);

# build aam
aam = aam_builder(training_images, 
                  group='PTS', 
                  trilist=training_images[0].landmarks['ibug_68_trimesh'].lms.trilist, 
                  n_levels=3, 
                  downscale=1.1, 
                  feature_type=hog_closure, 
                  max_shape_components=25, 
                  max_appearance_components=250)
# Out:
# - Rescaling images
# - Setting gaussian pyramid generators
# - Building model pyramids
#  - Level 0
#   - Computing feature_type
#   - Building shape model
# Converged after 4 iterations with av. error 9.893616
#   - Building reference frame
#   - Computing transforms
#   - Warping images
#   - Building appearance model
#  - Level 1
#   - Computing feature_type
#   - Computing transforms
#   - Warping images
#   - Building appearance model
#  - Level 2
#   - Computing feature_type
#   - Computing transforms
#   - Warping images
#   - Building appearance model

# %%
# %matplotlib inline
a.build_mask_around_landmarks((5, 5), group='PTS')
a.landmarks['PTS'].view(channels=0)

# %%
from sklearn import svm
from sklearn import linear_model 
from pybug.asm.base import asm_builder

def classifier_closure(X, y):
    clf1 = svm.LinearSVC(class_weight='auto')
    clf1.fit(X, y)
    y_pred = clf1.decision_function(X)
    clf2 = linear_model.LogisticRegression(class_weight='auto')
    clf2.fit(y_pred[..., None], y)
    return clf1, clf2

# build aam
asm = asm_builder(training_images, group='PTS', patch_size=(5, 5), n_levels=3,
                  downscale=1.1, scaled_shape_models=False, feature_type=hog_closure, 
                  classifier_type=classifier_closure, max_shape_components=25)
# Out:
# - Rescaling images
# - Setting gaussian pyramid generators
# - Building model pyramids
#  - Level 0
#   - Computing feature_type
#   - Building shape model
# Converged after 4 iterations with av. error 9.890574
#   - Building classifiers
#    - classifier: 0
#    - classifier: 1
#    - classifier: 2
#    - classifier: 3
#    - classifier: 4
#    - classifier: 5
#    - classifier: 6
#    - classifier: 7
#    - classifier: 8
#    - classifier: 9
#    - classifier: 10
#    - classifier: 11
#    - classifier: 12
#    - classifier: 13
#    - classifier: 14
#    - classifier: 15
#    - classifier: 16
#    - classifier: 17
#    - classifier: 18
#    - classifier: 19
#    - classifier: 20
#    - classifier: 21
#    - classifier: 22
#    - classifier: 23
#    - classifier: 24
#    - classifier: 25
#    - classifier: 26
#    - classifier: 27
#    - classifier: 28
#    - classifier: 29
#    - classifier: 30
#    - classifier: 31
#    - classifier: 32
#    - classifier: 33
#    - classifier: 34
# ...

# %%
del training_images

# %%
from pybug.asam.base import ASAM

asam = ASAM(asm.shape_models, aam.appearance_models, aam.transform_cls,
            asm.classifiers, hog_closure, asm.reference_shape, asm.downscale,
            asm.patch_size, aam.interpolator)

asam.scaled_shape_models = True

# %%
breakingbad = pio.import_builtin_asset('breakingbad.jpg')
breakingbad = breakingbad.as_greyscale(mode='luminosity')
breakingbad.crop_to_landmarks_proportion(0.4, group='PTS')

# %matplotlib inline
breakingbad.landmarks['PTS'].view()

# %%
import pybug.io as pio
from pybug.landmark import labeller, ibug_68_points, ibug_68_trimesh

test_images = []
# load landmarked imarges
for i in pio.import_images('/data/PhD/DataBases/ibug/*.jpg'):
    i.crop_to_landmarks_proportion(0.4)
    if i.n_channels == 3:
        test_images.append(i.as_greyscale(mode='luminosity'))
    else:
        test_images.append(i)

# %%
import pybug.io as pio
from pybug.landmark import labeller, ibug_68_points, ibug_68_trimesh

color_images = []
# load landmarked imarges
for i in pio.import_images('/data/PhD/DataBases/ibug/*.jpg'):
    i.crop_to_landmarks_proportion(0.4)
    color_images.append(i)

# %%
from pybug.asm.fitter import RlmsASMFitter

asm_fitter = RlmsASMFitter(asm, n_shape=[3, 6, 12])

# %%
ind=129
# fit test images
asm_fitting = asm_fitter.fit_image(test_images[ind], group='PTS', noise_std=0.04, max_iters=50)
# Out:
# Initial error: 0.120640163549
# Final error: 0.0892699237149

# %%
import matplotlib.pyplot as plt
import numpy as np

col = 'r'
mark = ''
lw = 3

# %matplotlib inline
color_images[ind].view()
s = asm_fitting.gt_shape.points
plt.axis('off')
plt.hold(True)
plt.plot(s[:17,1], s[:17,0], color=col, marker=mark, linewidth=lw)
plt.plot(s[17:22,1], s[17:22,0], color=col, marker=mark, linewidth=lw)
plt.plot(s[22:27,1], s[22:27,0], color=col, marker=mark, linewidth=lw)
plt.plot(s[27:31,1], s[27:31,0], color=col, marker=mark, linewidth=lw)
plt.plot(s[31:36,1], s[31:36,0], color=col, marker=mark, linewidth=lw)
plt.plot(np.hstack((s[36:42,1], s[36,1])), np.hstack((s[36:42,0],s[36,0])), color=col, marker=mark, linewidth=lw)
plt.plot(np.hstack((s[42:48,1], s[42,1])), np.hstack((s[42:48,0],s[42,0])), color=col, marker=mark, linewidth=lw)
plt.plot(np.hstack((s[48:60,1], s[48,1])), np.hstack((s[48:60,0],s[48,0])), color=col, marker=mark, linewidth=lw)
plt.plot(np.hstack((s[60:67,1], s[60,1])), np.hstack((s[60:67,0],s[60,0])), color=col, marker=mark, linewidth=lw)
plt.gcf().set_size_inches(3*plt.gcf().get_size_inches())

# %%
import matplotlib.pyplot as plt
import numpy as np

col = 'r'
mark = ''
lw = 3

# %matplotlib inline
color_images[ind].view()
s = asm_fitting.initial_shape.points
plt.axis('off')
plt.hold(True)
plt.plot(s[:17,1], s[:17,0], color=col, marker=mark, linewidth=lw)
plt.plot(s[17:22,1], s[17:22,0], color=col, marker=mark, linewidth=lw)
plt.plot(s[22:27,1], s[22:27,0], color=col, marker=mark, linewidth=lw)
plt.plot(s[27:31,1], s[27:31,0], color=col, marker=mark, linewidth=lw)
plt.plot(s[31:36,1], s[31:36,0], color=col, marker=mark, linewidth=lw)
plt.plot(np.hstack((s[36:42,1], s[36,1])), np.hstack((s[36:42,0],s[36,0])), color=col, marker=mark, linewidth=lw)
plt.plot(np.hstack((s[42:48,1], s[42,1])), np.hstack((s[42:48,0],s[42,0])), color=col, marker=mark, linewidth=lw)
plt.plot(np.hstack((s[48:60,1], s[48,1])), np.hstack((s[48:60,0],s[48,0])), color=col, marker=mark, linewidth=lw)
plt.plot(np.hstack((s[60:67,1], s[60,1])), np.hstack((s[60:67,0],s[60,0])), color=col, marker=mark, linewidth=lw)
plt.gcf().set_size_inches(3*plt.gcf().get_size_inches())

# %%
# fit test images
aam_fitting = lk_aam_fitter.fit_image(test_images[98], group='PTS', noise_std=0.00, max_iters=50)
# Out:
# Initial error: 0.0802382707812
# Final error: 0.0374729728373

# %%
# %matplotlib inline
aam_fitting.view_initialization()

# %%
# fit test images
aam_fitting = lk_aam_fitter.fit_image(breakingbad, group='PTS', noise_std=0.01, max_iters=50)
# Out:
# Initial error: 0.12155523606
# Final error: 0.0558831874959

# %%
# %matplotlib inline
aam_fitting.view_initialization()

# %%
# fit test images
aam_fitting = lk_aam_fitter.fit_image(breakingbad, group='PTS', noise_std=0.0, max_iters=50)
# Out:
# Initial error: 0.119949854257
# Final error: 0.0557818757789

# %%
# %matplotlib inline
aam_fitting.view_initialization()
