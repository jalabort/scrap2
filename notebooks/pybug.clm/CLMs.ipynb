# %%
import pybug.io as pio
from pybug.landmark import labeller, ibug_68_points, ibug_68_trimesh

training_images = []
# load landmarked imarges
for i in pio.import_images('/data/PhD/DataBases/lfpw/trainset/*.png', max_images=811):
    i.crop_to_landmarks_proportion(0.4)
    if i.n_channels == 3:
        training_images.append(i.as_greyscale(mode='luminosity'))
    else:
        training_images.append(i)

# %%
# visualize the first image
# %matplotlib inline
training_images[0].landmarks['PTS'].view()

# %%
image = training_images[0]

def hog_closure(image):
    return image.features.hog(mode='sparse')

# %matplotlib inline
a = hog_closure(training_images[0])
a.build_mask_around_landmarks((8, 8))
a.landmarks['PTS'].view(channels=0)

# %%
from sklearn import svm
from sklearn import linear_model 
from pybug.asm.base import asm_builder

def classifier_closure(X, y):
    clf1 = svm.LinearSVC(class_weight='auto')
    clf1.fit(X, y)
    y_pred = clf1.decision_function(X)
    clf2 = linear_model.LogisticRegression(class_weight='auto')
    clf2.fit(y_pred[..., None], y)
    return clf1, clf2

# build aam
asm = asm_builder(training_images, group='PTS', patch_size=(8, 8), n_levels=3,
                  downscale=1.1, scaled_shape_models=False, feature_type=hog_closure, 
                  classifier_type=classifier_closure, max_shape_components=25)
# Out:
# - Rescaling images
# - Setting gaussian pyramid generators
# - Building model pyramids
#  - Level 0
#   - Computing feature_type
#   - Building shape model
# Converged after 4 iterations with av. error 9.890574
#   - Building classifiers
#    - classifier: 0
#    - classifier: 1
#    - classifier: 2
#    - classifier: 3
#    - classifier: 4
#    - classifier: 5
#    - classifier: 6
#    - classifier: 7
#    - classifier: 8
#    - classifier: 9
#    - classifier: 10
#    - classifier: 11
#    - classifier: 12
#    - classifier: 13
#    - classifier: 14
#    - classifier: 15
#    - classifier: 16
#    - classifier: 17
#    - classifier: 18
#    - classifier: 19
#    - classifier: 20
#    - classifier: 21
#    - classifier: 22
#    - classifier: 23
#    - classifier: 24
#    - classifier: 25
#    - classifier: 26
#    - classifier: 27
#    - classifier: 28
#    - classifier: 29
#    - classifier: 30
#    - classifier: 31
#    - classifier: 32
#    - classifier: 33
#    - classifier: 34
#    - classifier: 35
#    - classifier: 36
#    - classifier: 37
#    - classifier: 38
#    - classifier: 39
#    - classifier: 40
#    - classifier: 41
#    - classifier: 42
#    - classifier: 43
#    - classifier: 44
#    - classifier: 45
#    - classifier: 46
#    - classifier: 47
#    - classifier: 48
#    - classifier: 49
#    - classifier: 50
#    - classifier: 51
#    - classifier: 52
#    - classifier: 53
#    - classifier: 54
#    - classifier: 55
#    - classifier: 56
#    - classifier: 57
#    - classifier: 58
#    - classifier: 59
#    - classifier: 60
#    - classifier: 61
#    - classifier: 62
#    - classifier: 63
#    - classifier: 64
#    - classifier: 65
#    - classifier: 66
#    - classifier: 67
#  - Level 1
#   - Computing feature_type
#   - Building classifiers
#    - classifier: 0
#    - classifier: 1
#    - classifier: 2
#    - classifier: 3
#    - classifier: 4
#    - classifier: 5
#    - classifier: 6
#    - classifier: 7
#    - classifier: 8
#    - classifier: 9
#    - classifier: 10
#    - classifier: 11
#    - classifier: 12
#    - classifier: 13
#    - classifier: 14
#    - classifier: 15
#    - classifier: 16
#    - classifier: 17
#    - classifier: 18
#    - classifier: 19
#    - classifier: 20
#    - classifier: 21
#    - classifier: 22
#    - classifier: 23
#    - classifier: 24
#    - classifier: 25
#    - classifier: 26
#    - classifier: 27
#    - classifier: 28
#    - classifier: 29
#    - classifier: 30
#    - classifier: 31
#    - classifier: 32
#    - classifier: 33
#    - classifier: 34
#    - classifier: 35
#    - classifier: 36
#    - classifier: 37
#    - classifier: 38
#    - classifier: 39
#    - classifier: 40
#    - classifier: 41
#    - classifier: 42
#    - classifier: 43
#    - classifier: 44
#    - classifier: 45
#    - classifier: 46
#    - classifier: 47
#    - classifier: 48
#    - classifier: 49
#    - classifier: 50
#    - classifier: 51
#    - classifier: 52
#    - classifier: 53
#    - classifier: 54
#    - classifier: 55
#    - classifier: 56
#    - classifier: 57
#    - classifier: 58
#    - classifier: 59
#    - classifier: 60
#    - classifier: 61
#    - classifier: 62
#    - classifier: 63
#    - classifier: 64
#    - classifier: 65
#    - classifier: 66
#    - classifier: 67
#  - Level 2
#   - Computing feature_type
#   - Building classifiers
#    - classifier: 0
#    - classifier: 1
#    - classifier: 2
#    - classifier: 3
#    - classifier: 4
#    - classifier: 5
#    - classifier: 6
#    - classifier: 7
#    - classifier: 8
#    - classifier: 9
#    - classifier: 10
#    - classifier: 11
#    - classifier: 12
#    - classifier: 13
#    - classifier: 14
#    - classifier: 15
#    - classifier: 16
#    - classifier: 17
#    - classifier: 18
#    - classifier: 19
#    - classifier: 20
#    - classifier: 21
#    - classifier: 22
#    - classifier: 23
#    - classifier: 24
#    - classifier: 25
#    - classifier: 26
#    - classifier: 27
#    - classifier: 28
#    - classifier: 29
#    - classifier: 30
#    - classifier: 31
#    - classifier: 32
#    - classifier: 33
#    - classifier: 34
#    - classifier: 35
#    - classifier: 36
#    - classifier: 37
#    - classifier: 38
#    - classifier: 39
#    - classifier: 40
#    - classifier: 41
#    - classifier: 42
#    - classifier: 43
#    - classifier: 44
#    - classifier: 45
#    - classifier: 46
#    - classifier: 47
#    - classifier: 48
#    - classifier: 49
#    - classifier: 50
#    - classifier: 51
#    - classifier: 52
#    - classifier: 53
#    - classifier: 54
#    - classifier: 55
#    - classifier: 56
#    - classifier: 57
#    - classifier: 58
#    - classifier: 59
#    - classifier: 60
#    - classifier: 61
#    - classifier: 62
#    - classifier: 63
#    - classifier: 64
#    - classifier: 65
#    - classifier: 66
#    - classifier: 67

# %%
import pybug.io as pio
from pybug.landmark import labeller, ibug_68_points, ibug_68_trimesh

test_images = []
# load landmarked imarges
for i in pio.import_images('/data/PhD/DataBases/afw/*.jpg'):
    i.crop_to_landmarks_proportion(0.3)
    if i.n_channels == 3:
        test_images.append(i.as_greyscale(mode='luminosity'))
    else:
        test_images.append(i)

# %%
import matplotlib.pyplot as plt

# %matplotlib inline
plt.imshow((asm.response_image(test_images[0], level=0).pixels[:,:,0]))

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from pybug.asm.fitter import RlmsASMFitter

rlms_asm_fitter = RlmsASMFitter(asm, n_shape=[3, 6, 12])

# %%
# %matplotlib inline
asm_fitting = rlms_asm_fitter.fit_image(test_images[2], group='PTS', noise_std=0.04, max_iters=50)
# Out:
# Initial error: 0.118210829065
# Final error: 0.066686577766

# %%
# %matplotlib inline
asm_fitting.view_initialization()

# %%
# %matplotlib inline
asm_fitting.view_final_fitting()

# %%
# %matplotlib wx
asm_fitting.view()
asm_fitting.n_iters
# Out:
# 49

# %%
# %matplotlib inline
asm_fittings.plot_error_dist(color_list=['b', 'black'], marker_list=['*', 'o'])

# %%
# %matplotlib inline
asm_fittings.plot_cumulative_error_dist(color_list=['b', 'black'], marker_list=['*', 'o'])

# %%
# %matplotlib wx
asm_fitting.view()
asm_fitting.n_iters

# %%
asm_fitting.view_initialization()
asm_fitting.view_final_fitting()

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
