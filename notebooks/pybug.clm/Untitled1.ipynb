# %%
import pybug.io as pio
from pybug.landmark import labeller, ibug_68_points, ibug_68_trimesh

training_images = []
# load landmarked imarges
for i in pio.import_images('/Users/joan/PhD/DataBases/lfpw/trainset/*.png', max_images=411):
    i.crop_to_landmarks_proportion(0.3)
    if i.n_channels == 3:
        training_images.append(i.as_greyscale(mode='luminosity'))
    else:
        training_images.append(i)

# %%
# visualize the first image
# %matplotlib inline
training_images[0].landmarks['PTS'].view()

# %%
image = training_images[0]

# %%
def hog_closure(image):
    return image.features.hog(cell_size=4, window_step_horizontal=1, window_step_vertical=1)

hog_closure(training_images[0]).pixels.shape
# Out:
# (270, 287, 36)

# %%
from sklearn import svm
from sklearn import linear_model 
from pybug.asm.base import asm_builder

def hog_closure(image):
    return image.features.hog(cell_size=4, window_step_horizontal=1, window_step_vertical=1)

def classifier_closure(X, y):
    clf = svm.LinearSVC(class_weight='auto')
    clf.fit(X, y)
    return clf

# build aam
asm = asm_builder(training_images, group='PTS', patch_size=(16, 16), n_levels=1,
                  feature_type=hog_closure, classifier_type=classifier_closure,
                  max_shape_components=25)
# Out:
# - Rescaling images
# - Setting gaussian pyramid generators
# - Building model pyramids
#  - Level 0
#   - Computing feature_type
#   - Building shape model
# Converged after 4 iterations with av. error 78.571559
#   - Building classifiers
#    - classifier: 0
#    - classifier: 1
#    - classifier: 2
#    - classifier: 3
#    - classifier: 4
#    - classifier: 5
#    - classifier: 6
#    - classifier: 7
#    - classifier: 8
#    - classifier: 9
#    - classifier: 10
#    - classifier: 11
#    - classifier: 12
#    - classifier: 13
#    - classifier: 14
#    - classifier: 15
#    - classifier: 16
#    - classifier: 17
#    - classifier: 18
#    - classifier: 19
#    - classifier: 20
#    - classifier: 21
#    - classifier: 22
#    - classifier: 23
#    - classifier: 24
#    - classifier: 25
#    - classifier: 26
#    - classifier: 27
#    - classifier: 28
#    - classifier: 29
#    - classifier: 30
#    - classifier: 31
#    - classifier: 32
#    - classifier: 33
#    - classifier: 34
#    - classifier: 35
#    - classifier: 36
#    - classifier: 37
#    - classifier: 38
#    - classifier: 39
#    - classifier: 40
#    - classifier: 41
#    - classifier: 42
#    - classifier: 43
#    - classifier: 44
#    - classifier: 45
#    - classifier: 46
#    - classifier: 47
#    - classifier: 48
#    - classifier: 49
#    - classifier: 50
#    - classifier: 51
#    - classifier: 52
#    - classifier: 53
#    - classifier: 54
#    - classifier: 55
#    - classifier: 56
#    - classifier: 57
#    - classifier: 58
#    - classifier: 59
#    - classifier: 60
#    - classifier: 61
#    - classifier: 62
#    - classifier: 63
#    - classifier: 64
#    - classifier: 65
#    - classifier: 66
#    - classifier: 67

# %%
breakingbad = pio.import_builtin_asset('einstein.jpg')
#breakingbad = breakingbad.as_greyscale(mode='luminosity')
breakingbad.crop_to_landmarks_proportion(0.3, group='PTS')

# %%
# %matplotlib inline
breakingbad.landmarks['PTS'].view()

# %%
asm.downscale=1.1

import matplotlib.pyplot as plt
# %matplotlib inline
plt.imshow((asm.response_image(training_images[0], level=0).pixels[:,:,35]))

# %%
from pybug.asm.fitter import RlmsASMFitter

asm.classifiers = [asm.classifiers[0]]
asm.shape_models = [asm.shape_models[0]]

rlms_asm_fitting = RlmsASMFitter(asm, n_shape=[12])

# %%
# %matplotlib inline
asm_fitting = rlms_asm_fitting.fit_image(training_images[1], group='PTS', view=True, max_iters=10)
# Out:
# Initial error: 0.0357807508694
# Final error: 0.10871544965

# %%
# %matplotlib qt 
asm_fitting.view()

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
